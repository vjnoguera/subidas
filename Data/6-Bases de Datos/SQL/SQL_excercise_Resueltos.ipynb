# %%
import pandas as pd
import sqlite3
import os
os.getcwd()
os.listdir("./data")
# Out:
# ['chinook.db']

# %%
# es muy importante que la dirección sea correcta, o generaremos una tabla vacía nueva en la  dirección en la que estemos
# Conectamos con la base de datos chinook.db
connection = sqlite3.connect("data/chinook.db")

# Obtenemos un cursor que utilizaremos para hacer las queries
crsr = connection.cursor()

# %%
'''Con esta funciójn estamos conectando con el archivo que tenemos en nuestro ordenador, dentro del a carpeta data'''
# Con esta función leemos los datos y lo pasamos a un DataFrame de Pandas
def sql_query(query):

    # Ejecuta la query
    crsr.execute(query)

    # Almacena los datos de la query 
    ans = crsr.fetchall()

    # Obtenemos los nombres de las columnas de la tabla
    names = [description[0] for description in crsr.description]

    return pd.DataFrame(ans,columns=names)

# %%
#1
query = '''
SELECT FirstName
FROM customers
WHERE Country LIKE "Brazil"
'''

sql_query(query)
# Out:
#    FirstName
# 0       Luís
# 1    Eduardo
# 2  Alexandre
# 3    Roberto
# 4   Fernanda

# %%
#2
query = '''
SELECT FirstName
FROM customers
WHERE Country LIKE "Brazil"
'''

sql_query(query)

# %%
query = '''
SELECT Title
FROM employees
WHERE Title LIKE "Sales%"
'''

sql_query(query)
# Out:
#                  Title
# 0        Sales Manager
# 1  Sales Support Agent
# 2  Sales Support Agent
# 3  Sales Support Agent

# %%
query = '''
SELECT tracks.Composer as Composer, tracks.Name as Cancion, albums.Title as Title, artists.Name as Name
FROM tracks INNER JOIN albums
ON tracks.AlbumId = albums.AlbumId

INNER JOIN artists
ON artists.ArtistId = albums.ArtistId
WHERE artists.Name LIKE '%AC/DC%'


'''

sql_query(query)
# Out:
#                                      Composer  \
# 0   Angus Young, Malcolm Young, Brian Johnson
# 1   Angus Young, Malcolm Young, Brian Johnson
# 2   Angus Young, Malcolm Young, Brian Johnson
# 3   Angus Young, Malcolm Young, Brian Johnson
# 4   Angus Young, Malcolm Young, Brian Johnson
# 5   Angus Young, Malcolm Young, Brian Johnson
# 6   Angus Young, Malcolm Young, Brian Johnson
# 7   Angus Young, Malcolm Young, Brian Johnson
# 8   Angus Young, Malcolm Young, Brian Johnson
# 9   Angus Young, Malcolm Young, Brian Johnson
# 10                                      AC/DC
# 11                                      AC/DC
# 12                                      AC/DC
# 13                                      AC/DC
# 14                                      AC/DC
# 15                                      AC/DC
# 16                                      AC/DC
# 17                                      AC/DC
#
#                                     Cancion  \
# ...

# %%
query = '''
SELECT FirstName, LastName,CustomerId,Country
FROM customers
WHERE Country <> "USA"
'''

sql_query(query)
# Out:
#     FirstName      LastName  CustomerId         Country
# 0        Luís     Gonçalves           1          Brazil
# 1      Leonie        Köhler           2         Germany
# 2    François      Tremblay           3          Canada
# 3       Bjørn        Hansen           4          Norway
# 4   František   Wichterlová           5  Czech Republic
# 5      Helena          Holý           6  Czech Republic
# 6      Astrid        Gruber           7         Austria
# 7        Daan       Peeters           8         Belgium
# 8        Kara       Nielsen           9         Denmark
# 9     Eduardo       Martins          10          Brazil
# 10  Alexandre         Rocha          11          Brazil
# 11    Roberto       Almeida          12          Brazil
# 12   Fernanda         Ramos          13          Brazil
# 13       Mark       Philips          14          Canada
# 14   Jennifer      Peterson          15          Canada
# 15     Robert         Brown          29          Canada
# ...

# %%
query = '''
SELECT *
FROM employees
'''

sql_query(query)
# Out:
#    EmployeeId  LastName FirstName                Title  ReportsTo  \
# 0           1     Adams    Andrew      General Manager        NaN
# 1           2   Edwards     Nancy        Sales Manager        1.0
# 2           3   Peacock      Jane  Sales Support Agent        2.0
# 3           4      Park  Margaret  Sales Support Agent        2.0
# 4           5   Johnson     Steve  Sales Support Agent        2.0
# 5           6  Mitchell   Michael           IT Manager        1.0
# 6           7      King    Robert             IT Staff        6.0
# 7           8  Callahan     Laura             IT Staff        6.0
#
#              BirthDate             HireDate                      Address  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00          11120 Jasper Ave NW
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00                 825 8 Ave SW
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00                1111 6 Ave SW
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00             683 10 Street SW
# ...

# %%
query = '''
SELECT FirstName,LastName,Address, City, State,Country,Email
FROM employees
WHERE title LIKE "Sales%"
'''

sql_query(query)

# query = '''
# SELECT Title
# FROM employees
# WHERE Title LIKE "Sales%"
# '''

# sql_query(query)

# query = '''
# SELECT tracks.Composer as Composer, tracks.Name as Cancion, albums.Title as Title, artists.Name as Name
# FROM tracks INNER JOIN albums
# ON tracks.AlbumId = albums.AlbumId

# INNER JOIN artists
# ON artists.ArtistId = albums.ArtistId
# WHERE Title LIKE "Sales%"


# '''

# sql_query(query)
# Out:
#   FirstName LastName           Address     City State Country  \
# 0     Nancy  Edwards      825 8 Ave SW  Calgary    AB  Canada
# 1      Jane  Peacock     1111 6 Ave SW  Calgary    AB  Canada
# 2  Margaret     Park  683 10 Street SW  Calgary    AB  Canada
# 3     Steve  Johnson      7727B 41 Ave  Calgary    AB  Canada
#
#                       Email
# 0     nancy@chinookcorp.com
# 1      jane@chinookcorp.com
# 2  margaret@chinookcorp.com
# 3     steve@chinookcorp.com

# %%
query = '''
SELECT *
FROM invoices
'''
sql_query(query)
# Out:
#      InvoiceId  CustomerId          InvoiceDate  \
# 0            1           2  2009-01-01 00:00:00
# 1            2           4  2009-01-02 00:00:00
# 2            3           8  2009-01-03 00:00:00
# 3            4          14  2009-01-06 00:00:00
# 4            5          23  2009-01-11 00:00:00
# ..         ...         ...                  ...
# 407        408          25  2013-12-05 00:00:00
# 408        409          29  2013-12-06 00:00:00
# 409        410          35  2013-12-09 00:00:00
# 410        411          44  2013-12-14 00:00:00
# 411        412          58  2013-12-22 00:00:00
#
#                                BillingAddress BillingCity BillingState  \
# 0                     Theodor-Heuss-Straße 34   Stuttgart         None
# 1                            Ullevålsveien 14        Oslo         None
# 2                             Grétrystraat 63    Brussels         None
# 3                              8210 111 ST NW    Edmonton           AB
# ...

# %%
query = '''
SELECT DISTINCT BillingCountry	
FROM invoices
'''
sql_query(query)
# Out:
#     BillingCountry
# 0          Germany
# 1           Norway
# 2          Belgium
# 3           Canada
# 4              USA
# 5           France
# 6          Ireland
# 7   United Kingdom
# 8        Australia
# 9            Chile
# 10           India
# 11          Brazil
# 12        Portugal
# 13     Netherlands
# 14           Spain
# 15          Sweden
# 16  Czech Republic
# 17         Finland
# 18         Denmark
# 19           Italy
# 20          Poland
# 21         Austria
# 22         Hungary
# 23       Argentina

# %%
query = '''
SELECT DISTINCT State
FROM customers
WHERE Country LIKE "USA"
'''
sql_query(query)
# Out:
#    State
# 0     CA
# 1     WA
# 2     NY
# 3     NV
# 4     FL
# 5     MA
# 6     IL
# 7     WI
# 8     TX
# 9     AZ
# 10    UT

# %%
query = '''
SELECT Quantity
FROM invoice_items
WHERE InvoiceId LIKE "37"
'''

sql_query(query)
# Out:
#    Quantity
# 0         1
# 1         1
# 2         1
# 3         1

# %%
query = '''
SELECT SUM(tracks.Name) as TOT_SONGS, artists.Name
FROM tracks INNER JOIN albums
ON tracks.AlbumId = albums.AlbumId

INNER JOIN artists
ON artists.ArtistId = albums.ArtistId
WHERE artists.Name LIKE "AC/DC"



'''

# sql_query(query)

# query = '''
# SELECT genres.Name as `GENERO MUSICAL`, SUM(tracks.unitprice) as TOT_PRICE
# FROM tracks INNER JOIN genres ON tracks.GenreId = genres.GenreId
# GROUP BY tracks.GenreId
# ORDER BY TOT_PRICE DESC
# LIMIT 10;
# '''

sql_query(query)
# Out:
#    TOT_SONGS   Name
# 0        0.0  AC/DC
