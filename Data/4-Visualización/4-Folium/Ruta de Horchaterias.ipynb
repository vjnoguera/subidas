# %%
# route

# map
map_plot_route = folium.Map(location=[39.44348997513218, -0.4154629308025986], zoom_start=12)

# route_locs = ['Los Angeles', 'Las Vegas', 'Denver', 'Chicago', 'Manhattan']
# can use list of lists or list of tuples
route_lats_longs = [[39.43055030281372, -0.4169491487248162],
                    [39.44459427937192, -0.3895199799755384], 
                    [39.47455579740041, -0.3514849341040615], 
                    [39.47497457200068, -0.37795707909851484], 
                    [39.48193682405381, -0.3571944831898718],
                    [39.49329580572751, -0.3573122291380177],
                    [39.495454746449646, -0.35476900874481965],
                    [39.49212684281515, -0.32567201896062953],
                    [39.48561766927919, -0.3256162292538369],
                    [39.46392126073503, -0.32312313601119114],
                    ]

# add route to map
folium.PolyLine(route_lats_longs).add_to(map_plot_route)

folium.Marker(location=[39.43055030281372, -0.4169491487248162], 
              popup='popup', 
              icon=folium.Icon(color='green', icon='hippo', prefix='fa')).add_to(map_plot_route)

folium.Marker(location=[39.44459427937192, -0.3895199799755384], 
              popup='popup', 
              icon=folium.Icon(color='black', icon='poo', prefix='fa')).add_to(map_plot_route)
folium.Marker(location=[39.47455579740041, -0.3514849341040615], 
              popup='popup', 
              icon=folium.Icon(color='blue', icon='poo', prefix='fa')).add_to(map_plot_route)
folium.Marker(location=[39.47497457200068, -0.37795707909851484], 
              popup='popup', 
              icon=folium.Icon(color='red', icon='star', prefix='fa')).add_to(map_plot_route)
folium.Marker(location=[39.48193682405381, -0.3571944831898718], 
              popup='popup', 
              icon=folium.Icon(color='pink', icon='bomb', prefix='fa')).add_to(map_plot_route)
folium.Marker(location=[39.49329580572751, -0.3573122291380177], 
              popup='popup', 
              icon=folium.Icon(color='grey', icon='heart', prefix='fa')).add_to(map_plot_route)
folium.Marker(location=[39.495454746449646, -0.35476900874481965], 
              popup='popup', 
              icon=folium.Icon(color='purple', icon='check', prefix='fa')).add_to(map_plot_route)
folium.Marker(location=[39.49212684281515, -0.32567201896062953], 
              popup='popup', 
              icon=folium.Icon(color='green', icon='bolt', prefix='fa')).add_to(map_plot_route)
folium.Marker(location=[39.48561766927919, -0.3256162292538369], 
              popup='popup', 
              icon=folium.Icon(color='brown', icon='fire', prefix='fa')).add_to(map_plot_route)
folium.Marker(location=[39.46392126073503, -0.32312313601119114], 
              popup='popup', 
              icon=folium.Icon(color='beige', icon='fish', prefix='fa')).add_to(map_plot_route)


# display map
map_plot_route
