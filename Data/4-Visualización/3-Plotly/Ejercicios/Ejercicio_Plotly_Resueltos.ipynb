# %% [markdown]
# # Interactive Visualization Lab - Superstore Dataset
#
# Complete the following set of exercises to solidify your knowledge of interactive visualization using Plotly, Cufflinks, and IPyWidgets.

# %%
import matplotlib.pyplot as plt
import numpy as np
import plotly as py
import pandas as pd
import plotly.graph_objects as go

# %%
pip install openpyxl
# Out:
# ...
#    ---------------------------------------- 0.0/250.0 kB ? eta -:--:--
#    --------- ------------------------------ 61.4/250.0 kB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 250.0/250.0 kB 3.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Acostumbraros a realizar siempre estas 3 comprobaciones del df

# %%
sp = pd.read_excel(r"C:\Users\Victor\Desktop\Data2 - copia\2-Data_Analysis\4-Visualización\3-Plotly\Ejercicios\data\Sample - Superstore.xlsx")

# %%
sp.describe()
# Out:
#                           Order Date                      Ship Date  \
# count                           9994                           9994
# mean   2016-04-30 00:07:12.259355648  2016-05-03 23:06:58.571142912
# min              2014-01-03 00:00:00            2014-01-07 00:00:00
# 25%              2015-05-23 00:00:00            2015-05-27 00:00:00
# 50%              2016-06-26 00:00:00            2016-06-29 00:00:00
# 75%              2017-05-14 00:00:00            2017-05-18 00:00:00
# max              2017-12-30 00:00:00            2018-01-05 00:00:00
# std                              NaN                            NaN
#
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# ...

# %% [markdown]
# ## 1. Create an interactive bar chart showing total sales by State for2014.

# %%
sp1 = sp.loc[sp.loc[:,"Order Date"].dt.year==2014]
sp1.groupby("State")[["Sales"]].sum().reset_index()
# Out:
#              State       Sales
# 0          Alabama   6139.0900
# 1          Arizona   8295.2350
# 2         Arkansas   6302.6900
# 3       California  91303.5310
# 4         Colorado   6502.2940
# 5      Connecticut   2794.0200
# 6         Delaware   4786.0300
# 7          Florida  34248.2605
# 8          Georgia   4540.1000
# 9            Idaho    465.2160
# 10        Illinois  16202.7070
# 11         Indiana   2936.8100
# 12            Iowa   1190.8400
# 13          Kansas   1319.7900
# 14        Kentucky   8280.4600
# 15       Louisiana   2534.9200
# 16           Maine    617.1200
# 17        Maryland   1701.2500
# 18   Massachusetts   9900.1060
# 19        Michigan   6172.2510
# 20       Minnesota  15883.3300
# 21     Mississippi   2055.1600
# 22        Missouri   1648.0300
# 23         Montana    424.4880
# 24        Nebraska    210.0200
# 25          Nevada   2561.2100
# 26   New Hampshire    504.4800
# 27      New Jersey   4192.2800
# 28      New Mexico    708.0120
# ...

# %%
# prepare data frames
sp1_1 = sp1.groupby("State")[["Sales"]].sum().reset_index()
# import graph objects as "go"
# import plotly.graph_objects as go

# create trace1 
trace1 = go.Bar(x = sp1_1['State'],
               y = sp1_1['Sales'],
               name = 'Sales Relation',
               marker = dict(color = 'rgba(255, 174, 255, 0.5)',
                            line = dict(color='rgb(0,0,0)', width = 1.5)),
               text = sp1_1['State'])

# trace2 = go.Bar(x = df2014['university_name'],
#                y = df2014['teaching'],
#                name = 'teaching',
#                marker = dict(color = 'rgba(255, 255, 128, 0.5)',
#                             line = dict(color='rgb(0,0,0)', width = 1.5)),
#                text = df2014['country'])



data = [trace1]

layout = go.Layout(barmode = "group")

fig = go.Figure(data = data, layout = layout)

fig

# %%
# Out:
# <div>                            <div id="b5aac7de-02d8-4d0d-b6ba-2657b3e92015" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b5aac7de-02d8-4d0d-b6ba-2657b3e92015")) {                    Plotly.newPlot(                        "b5aac7de-02d8-4d0d-b6ba-2657b3e92015",                        [{"x":["California","New York","Texas","Florida","Washington","Virginia","Pennsylvania","Illinois","Minnesota","Ohio","Massachusetts","North Carolina","Arizona","Kentucky","Colorado","Arkansas","Michigan","Alabama","Rhode Island","Wisconsin","Oregon","Delaware","Georgia","New Jersey","Tennessee","Utah","Indiana","Connecticut","Oklahoma","Nevada","Louisiana","South Carolina","Mississippi","Maryland","Missouri","Kansas","Iowa","New Mexico","Maine","New Hampshire","I
# ...

# %% [markdown]
# ## 2. Create an interactive line chart showing Sales and Profit in 2014.

# %%
sp1 = sp1.sort_values("Order Date")
sp1
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 7980  CA-2014-103800 2014-01-03 2014-01-07  Standard Class    DP-13000
# 739   CA-2014-112326 2014-01-04 2014-01-08  Standard Class    PO-19195
# 740   CA-2014-112326 2014-01-04 2014-01-08  Standard Class    PO-19195
# 741   CA-2014-112326 2014-01-04 2014-01-08  Standard Class    PO-19195
# 1759  CA-2014-141817 2014-01-05 2014-01-12  Standard Class    MB-18085
# ...              ...        ...        ...             ...         ...
# 7679  CA-2014-133592 2014-12-31 2015-01-07  Standard Class    KM-16375
# 4558  CA-2014-127383 2014-12-31 2015-01-05  Standard Class    CM-11815
# 2006  CA-2014-111150 2014-12-31 2015-01-04  Standard Class    RW-19630
# 2341  US-2014-143231 2014-12-31 2015-01-03     First Class    GM-14455
# 7680  CA-2014-133592 2014-12-31 2015-01-07  Standard Class    KM-16375
#
#          Customer Name      Segment        Country          City  \
# ...

# %%
# prepare data frame
# df = timesData.iloc[:100,:]

# import graph objects as "go"
# import plotly.graph_objects as go

# Creating trace1
trace1 = go.Scatter(
                    x = sp1.loc[:,"Order Date"].sort_values(ascending=True)
,
                    y = sp1['Sales'],
                    name = 'Sales',# es importante siempre ponerle un nombre a la traza
                    mode= 'lines',
                    marker = dict(color = 'rgba(16, 112, 2, 0.8)'),# el color siempre se introduce como diccionario, y podemos utilizar el rgba o poner el nombre "green"
                    text = sp1['Sales'])

# Creating trace2
trace2 = go.Scatter(
                    x = sp1.loc[:,"Order Date"].sort_values(ascending=True)
,
                    y = sp1['Profit'],
                    name = 'Profits',
                    mode= 'lines',
                    marker = dict(color = 'rgba(80, 26, 80, 0.8)'),
                    text = sp1['Profit'])

''' el gráfico siempre tendra, data y layout'''
data = [trace1, trace2]

layout = dict(title = 'Sales and Profit in 2014', # existe un objeto go.layout que requiere los mismos elemento y puede ser incluso mas interesante
             xaxis= dict(title= 'World Rank',ticklen= 5)
           )

fig = go.Figure(data = data, layout=layout)

fig

# %%
# Out:
# <div>                            <div id="46002775-0fac-4811-9d67-410858326341" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("46002775-0fac-4811-9d67-410858326341")) {                    Plotly.newPlot(                        "46002775-0fac-4811-9d67-410858326341",                        [{"name":"Sales","x":["2014-01-03T00:00:00","2014-01-04T00:00:00","2014-01-05T00:00:00","2014-01-06T00:00:00","2014-01-07T00:00:00","2014-01-09T00:00:00","2014-01-10T00:00:00","2014-01-11T00:00:00","2014-01-13T00:00:00","2014-01-14T00:00:00","2014-01-15T00:00:00","2014-01-16T00:00:00","2014-01-18T00:00:00","2014-01-19T00:00:00","2014-01-20T00:00:00","2014-01-21T00:00:00","2014-01-23T00:00:00","2014-01-26T00:00:00","2014-01-27T00:00:00","2014-01-28T00:00:00","2014-
# ...

# %% [markdown]
# ## 3. Create a set of 3 interactive histograms showing the distributions of quantity per order for the following states: California, New York and Texas.

# %%
from plotly.subplots import make_subplots

sp3t= sp.loc[sp.loc[:,"State"]=="Texas"]
sp3_1 = sp3t.groupby("Order ID")[["Quantity"]].value_counts().reset_index()
sp3c= sp.loc[sp.loc[:,"State"]=="California"]
sp3_2 = sp3c.groupby("Order ID")[["Quantity"]].value_counts().reset_index()
sp3n= sp.loc[sp.loc[:,"State"]=="New York"]
sp3_3 = sp3n.groupby("Order ID")[["Quantity"]].value_counts().reset_index()
fig = make_subplots(rows=2, cols=3)

trace0 = go.Histogram(x=sp3_1.loc[:,"Quantity"], nbinsx=15)
trace1 = go.Histogram(x=sp3_2.loc[:,"Quantity"], nbinsx = 15)
trace2 = go.Histogram(x=sp3_3.loc[:,"Quantity"], nbinsx=15)
# trace3 = go.Histogram(x=x,
#                       xbins=dict(
#                       start='1969-11-15',
#                       end='1972-03-31',
#                       size='M18'), # M18 stands for 18 months
#                       autobinx=False
#                      )
# trace4 = go.Histogram(x=x,
#                       xbins=dict(
#                       start='1969-11-15',
#                       end='1972-03-31',
#                       size='M4'), # 4 months bin size
#                       autobinx=False
#                       )
# trace5 = go.Histogram(x=x,
#                       xbins=dict(
#                       start='1969-11-15',
#                       end='1972-03-31',
#                       size= 'M2'), # 2 months
#                       autobinx = False
                    #   )

fig.append_trace(trace0, 1, 1)
fig.append_trace(trace1, 1, 2)
fig.append_trace(trace2, 1, 3)
# fig.append_trace(trace3, 2, 2)
# fig.append_trace(trace4, 3, 1)
# fig.append_trace(trace5, 3, 2)

fig.show()


# trace1 = go.Histogram(x = sp3_1.loc[:,"Quantity"],
#                      opacity = 0.9,
#                      name = 'Texas',
#                      marker = dict(color = 'green'))

# trace2 = go.Histogram(x = sp3_2.loc[:,"Quantity"],
#                      opacity = 0.9,
#                      name = 'California',
#                      marker = dict(color = 'red'))

# trace3 = go.Histogram(x = sp3_3.loc[:,"Quantity"],
#                      opacity = 0.9,
#                      name = 'New York',
#                      marker = dict(color = 'blue'))

# data = [trace1, trace2, trace3]
# layout = go.Layout(barmode='overlay',
#                    title=' Quantity per order and Country',
#                    xaxis=dict(title='Quanity'),
#                    yaxis=dict( title='Order'),
# )
# fig = go.Figure(data=data, layout=layout)
# fig

# %%
# Out:
# <div>                            <div id="9dc077a7-11f5-4e19-bb2c-7d13a4f95d6c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9dc077a7-11f5-4e19-bb2c-7d13a4f95d6c")) {                    Plotly.newPlot(                        "9dc077a7-11f5-4e19-bb2c-7d13a4f95d6c",                        [{"name":"California","x":[2,7,4,6,3,5,9,4,2,3,4,2,3,2,2,6,3,4,5,1,3,2,1,3,2,3,3,1,4,2,3,6,14,3,3,3,7,7,4,6,1,3,2,7,8,7,4,6,3,2,2,1,13,2,4,7,3,3,2,1,5,2,6,1,1,2,4,2,3,3,4,7,3,5,3,5,7,1,9,1,13,2,8,5,4,1,2,3,2,4,6,7,5,6,3,2,5,5,8,4,2,9,3,2,3,2,1,3,2,2,2,4,5,3,7,3,14,4,2,4,2,3,5,8,5,3,5,4,2,7,1,5,3,3,2,10,4,3,4,9,3,3,4,1,2,2,2,4,5,1,2,2,2,7,4,3,4,4,2,2,2,6,2,2,4,3,12,6,7,3,3,2,2,2,4,2,2,4,2,2,2,3,5,3,4,5,2,3,12,1,4,2,4,7,3,1,9,2,5,4,3,1,3,3,2,1,2,2,3,2,4,1,2,1,1,3,5,
# ...

# %% [markdown]
# ## 4. Create an interactive stacked bar chart showing the revenue by state (bars) for each of the products categories for California, New York and Texas.

# %%
sp4 = sp.loc[sp.loc[:,"State"].isin(["Texas","New York","California"])]
sp4_1 = sp4.groupby(["State","Category"],as_index=False)[["Sales"]].sum()# es imprescindible meterse en el as_index=False para eliminar el multiindice que se nos generaría
sp4_1
# Out:
#         State         Category        Sales
# 0  California        Furniture  156064.6015
# 1  California  Office Supplies  142351.9480
# 2  California       Technology  159271.0820
# 3    New York        Furniture   93372.7290
# 4    New York  Office Supplies   90020.0420
# 5    New York       Technology  127483.5000
# 6       Texas        Furniture   60593.2918
# 7       Texas  Office Supplies   44490.5300
# 8       Texas       Technology   65104.2240

# %%
import plotly.express as px
fig = px.bar(sp4_1, x="Category", y = "Sales", color = "State")
fig.show()

# %%
sp4_1 = sp4.groupby(["State","Category"]).size().reset_index().pivot(columns='State',
                                                                                  index='Category',
                                                                                  values=0)
sp4_1.plot(kind='bar', stacked=True);

# %%
# Out:
#         State         Category        Sales
# 0  California        Furniture  156064.6015
# 1  California  Office Supplies  142351.9480
# 2  California       Technology  159271.0820
# 3    New York        Furniture   93372.7290
# 4    New York  Office Supplies   90020.0420
# 5    New York       Technology  127483.5000
# 6       Texas        Furniture   60593.2918
# 7       Texas  Office Supplies   44490.5300
# 8       Texas       Technology   65104.2240

# %%
# Out:
# <div>                            <div id="d21dd30f-3b13-48c4-b1b8-dab1cdcc436b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d21dd30f-3b13-48c4-b1b8-dab1cdcc436b")) {                    Plotly.newPlot(                        "d21dd30f-3b13-48c4-b1b8-dab1cdcc436b",                        [{"alignmentgroup":"True","hovertemplate":"State=California<br>Category=%{x}<br>Sales=%{y}<extra></extra>","legendgroup":"California","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"California","offsetgroup":"California","orientation":"v","showlegend":true,"textposition":"auto","x":["Furniture","Office Supplies","Technology"],"xaxis":"x","y":[156064.60150000002,142351.948,159271.082],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"S
# ...

# %% [markdown]
# ## 5. Create an interactive line chart showing sale by day for California.

# %%
sp5 = sp.loc[sp.loc[:,"State"]=="California"]
sp5
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 2     CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 5     CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6     CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7     CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 8     CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# ...              ...        ...        ...             ...         ...
# 9986  CA-2016-125794 2016-09-29 2016-10-03  Standard Class    ML-17410
# 9990  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9993  CA-2017-119914 2017-05-04 2017-05-09    Second Class    CC-12220
#
#         Customer Name    Segment        Country         City       State  \
# ...

# %%
sp5_1 = sp5.groupby("Order Date")[["Sales"]].sum()
sp5_1
# Out:
#                Sales
# Order Date
# 2014-01-06    19.440
# 2014-01-13  1679.749
# 2014-01-20    38.660
# 2014-01-27   426.670
# 2014-01-31   290.666
# ...              ...
# 2017-12-24  2970.432
# 2017-12-25   424.172
# 2017-12-28  1066.544
# 2017-12-29   797.064
# 2017-12-30    34.624
#
# [659 rows x 1 columns]

# %%
trace1 = go.Scatter(
                    x = sp5.loc[:,"Order Date"].sort_values(ascending=True)
,
                    y = sp5_1['Sales'],
                    name = 'Sales',# es importante siempre ponerle un nombre a la traza
                    mode= 'lines',
                    marker = dict(color = 'rgba(16, 112, 2, 0.8)'),# el color siempre se introduce como diccionario, y podemos utilizar el rgba o poner el nombre "green"
                    text = sp5_1['Sales'])

data = [trace1]

layout = dict(title = 'Sales by day in California', # existe un objeto go.layout que requiere los mismos elemento y puede ser incluso mas interesante
             xaxis= dict(title= 'World Rank',ticklen= 5)
           )

fig = go.Figure(data = data, layout=layout)

fig

# %%
# Out:
# <div>                            <div id="b3a855e1-17b8-42df-9a7b-581e0c3c2e00" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b3a855e1-17b8-42df-9a7b-581e0c3c2e00")) {                    Plotly.newPlot(                        "b3a855e1-17b8-42df-9a7b-581e0c3c2e00",                        [{"mode":"lines","x":["2014-01-06T00:00:00","2014-01-13T00:00:00","2014-01-20T00:00:00","2014-01-27T00:00:00","2014-01-31T00:00:00","2014-02-02T00:00:00","2014-02-04T00:00:00","2014-02-12T00:00:00","2014-02-20T00:00:00","2014-02-22T00:00:00","2014-03-03T00:00:00","2014-03-11T00:00:00","2014-03-14T00:00:00","2014-03-18T00:00:00","2014-03-23T00:00:00","2014-03-24T00:00:00","2014-03-25T00:00:00","2014-03-26T00:00:00","2014-03-30T00:00:00","2014-03-31T00:00:00","2014-
# ...
