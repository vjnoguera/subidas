# %% [markdown]
# # Fictional Army - Filtering and Sorting

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Read the csv

# %%
army = pd.read_csv(r"C:\Users\Victor\Desktop\Subidas\Data\2 -Pandas\4-Fictional_Army\army.csv")
army
# Out:
#     Unnamed: 0    regiment company  deaths  battles  size  veterans  \
# 0            0  Nighthawks     1st     523        5  1045         1
# 1            1  Nighthawks     1st      52       42   957         5
# 2            2  Nighthawks     2nd      25        2  1099        62
# 3            3  Nighthawks     2nd     616        2  1400        26
# 4            4    Dragoons     1st      43        4  1592        73
# 5            5    Dragoons     1st     234        7  1006        37
# 6            6    Dragoons     2nd     523        8   987       949
# 7            7    Dragoons     2nd      62        3   849        48
# 8            8      Scouts     1st      62        4   973        48
# 9            9      Scouts     1st      73        7  1005       435
# 10          10      Scouts     2nd      37        8  1099        63
# 11          11      Scouts     2nd      35        9  1523       345
#
#     readiness  armored  deserters      origin
# ...

# %% [markdown]
# ### Step 3. Create a dataframe and assign it to a variable called army.

# %%
army
# Out:
#     Unnamed: 0    regiment company  deaths  battles  size  veterans  \
# 0            0  Nighthawks     1st     523        5  1045         1
# 1            1  Nighthawks     1st      52       42   957         5
# 2            2  Nighthawks     2nd      25        2  1099        62
# 3            3  Nighthawks     2nd     616        2  1400        26
# 4            4    Dragoons     1st      43        4  1592        73
# 5            5    Dragoons     1st     234        7  1006        37
# 6            6    Dragoons     2nd     523        8   987       949
# 7            7    Dragoons     2nd      62        3   849        48
# 8            8      Scouts     1st      62        4   973        48
# 9            9      Scouts     1st      73        7  1005       435
# 10          10      Scouts     2nd      37        8  1099        63
# 11          11      Scouts     2nd      35        9  1523       345
#
#     readiness  armored  deserters      origin
# ...

# %% [markdown]
# ### Step 4. Set the 'origin' colum as the index of the dataframe

# %%
army.index = army["origin"]
army
# Out:
#             Unnamed: 0    regiment company  deaths  battles  size  veterans  \
# origin
# Arizona              0  Nighthawks     1st     523        5  1045         1
# California           1  Nighthawks     1st      52       42   957         5
# Texas                2  Nighthawks     2nd      25        2  1099        62
# Florida              3  Nighthawks     2nd     616        2  1400        26
# Maine                4    Dragoons     1st      43        4  1592        73
# Iowa                 5    Dragoons     1st     234        7  1006        37
# Alaska               6    Dragoons     2nd     523        8   987       949
# Washington           7    Dragoons     2nd      62        3   849        48
# Oregon               8      Scouts     1st      62        4   973        48
# Wyoming              9      Scouts     1st      73        7  1005       435
# Louisana            10      Scouts     2nd      37        8  1099        63
# ...

# %% [markdown]
# ### Step 5. Print only the column veterans

# %%
army.loc[:,"veterans"]
# Out:
# 0       1
# 1       5
# 2      62
# 3      26
# 4      73
# 5      37
# 6     949
# 7      48
# 8      48
# 9     435
# 10     63
# 11    345
# Name: veterans, dtype: int64

# %% [markdown]
# ### Step 6. Print the columns 'veterans' and 'deaths'

# %%
army[["veterans","deaths"]]
# Out:
#     veterans  deaths
# 0          1     523
# 1          5      52
# 2         62      25
# 3         26     616
# 4         73      43
# 5         37     234
# 6        949     523
# 7         48      62
# 8         48      62
# 9        435      73
# 10        63      37
# 11       345      35

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
army.columns
# Out:
# Index(['Unnamed: 0', 'regiment', 'company', 'deaths', 'battles', 'size',
#        'veterans', 'readiness', 'armored', 'deserters', 'origin'],
#       dtype='object')

# %% [markdown]
# ### Step 8. Select the 'deaths', 'size' and 'deserters' columns from Maine and Alaska

# %%
mask8 = army["origin"].isin(["Maine","Alaska"])

# %%
army.loc[mask8,["deaths","size","deserters"]]
# Out:
#         deaths  size  deserters
# origin
# Maine       43  1592          3
# Alaska     523   987         24

# %% [markdown]
# ### Step 9. Select the rows 3 to 7 and the columns 3 to 6

# %%
army.iloc[3:8,3:7]
# Out:
#             deaths  battles  size  veterans
# origin
# Florida        616        2  1400        26
# Maine           43        4  1592        73
# Iowa           234        7  1006        37
# Alaska         523        8   987       949
# Washington      62        3   849        48

# %% [markdown]
# ### Step 10. Select every row after the fourth row and all columns

# %%
army.iloc[5:,:]
# Out:
#             Unnamed: 0  regiment company  deaths  battles  size  veterans  \
# origin
# Iowa                 5  Dragoons     1st     234        7  1006        37
# Alaska               6  Dragoons     2nd     523        8   987       949
# Washington           7  Dragoons     2nd      62        3   849        48
# Oregon               8    Scouts     1st      62        4   973        48
# Wyoming              9    Scouts     1st      73        7  1005       435
# Louisana            10    Scouts     2nd      37        8  1099        63
# Georgia             11    Scouts     2nd      35        9  1523       345
#
#             readiness  armored  deserters      origin
# origin
# Iowa                1        1          4        Iowa
# Alaska              2        0         24      Alaska
# Washington          3        1         31  Washington
# Oregon              2        0          2      Oregon
# Wyoming             1        0          3     Wyoming
# ...

# %% [markdown]
# ### Step 11. Select every row up to the 4th row and all columns

# %%
army.iloc[:4,:]
# Out:
#             Unnamed: 0    regiment company  deaths  battles  size  veterans  \
# origin
# Arizona              0  Nighthawks     1st     523        5  1045         1
# California           1  Nighthawks     1st      52       42   957         5
# Texas                2  Nighthawks     2nd      25        2  1099        62
# Florida              3  Nighthawks     2nd     616        2  1400        26
#
#             readiness  armored  deserters      origin
# origin
# Arizona             1        1          4     Arizona
# California          2        0         24  California
# Texas               3        1         31       Texas
# Florida             3        1          2     Florida

# %% [markdown]
# ### Step 12. Select the 3rd column up to the 7th column

# %%
army.iloc[:,3:8]
# Out:
#             deaths  battles  size  veterans  readiness
# origin
# Arizona        523        5  1045         1          1
# California      52       42   957         5          2
# Texas           25        2  1099        62          3
# Florida        616        2  1400        26          3
# Maine           43        4  1592        73          2
# Iowa           234        7  1006        37          1
# Alaska         523        8   987       949          2
# Washington      62        3   849        48          3
# Oregon          62        4   973        48          2
# Wyoming         73        7  1005       435          1
# Louisana        37        8  1099        63          2
# Georgia         35        9  1523       345          3

# %% [markdown]
# ### Step 13. Select rows where df.deaths is greater than 50

# %%
mask13 = army.loc[:,"deaths"]

# %%
army.loc[mask13>50]
# Out:
#             Unnamed: 0    regiment company  deaths  battles  size  veterans  \
# origin
# Arizona              0  Nighthawks     1st     523        5  1045         1
# California           1  Nighthawks     1st      52       42   957         5
# Florida              3  Nighthawks     2nd     616        2  1400        26
# Iowa                 5    Dragoons     1st     234        7  1006        37
# Alaska               6    Dragoons     2nd     523        8   987       949
# Washington           7    Dragoons     2nd      62        3   849        48
# Oregon               8      Scouts     1st      62        4   973        48
# Wyoming              9      Scouts     1st      73        7  1005       435
#
#             readiness  armored  deserters      origin
# origin
# Arizona             1        1          4     Arizona
# California          2        0         24  California
# Florida             3        1          2     Florida
# ...

# %% [markdown]
# ### Step 14. Select rows where df.deaths is greater than 500 or less than 50

# %%
army = army[~army['deaths'].between(50, 500)]
army
# Out:
#           Unnamed: 0    regiment company  deaths  battles  size  veterans  \
# origin
# Arizona            0  Nighthawks     1st     523        5  1045         1
# Texas              2  Nighthawks     2nd      25        2  1099        62
# Florida            3  Nighthawks     2nd     616        2  1400        26
# Maine              4    Dragoons     1st      43        4  1592        73
# Alaska             6    Dragoons     2nd     523        8   987       949
# Louisana          10      Scouts     2nd      37        8  1099        63
# Georgia           11      Scouts     2nd      35        9  1523       345
#
#           readiness  armored  deserters    origin
# origin
# Arizona           1        1          4   Arizona
# Texas             3        1         31     Texas
# Florida           3        1          2   Florida
# Maine             2        0          3     Maine
# Alaska            2        0         24    Alaska
# Louisana          2        1          2  Louisana
# ...

# %% [markdown]
# ### Step 15. Select all the regiments not named "Dragoons"

# %%
import pandas as pd

# Create a DataFrame
data = {"Name": ["John", "Jane", "Mary", "Adam"],
        "City": ["New York", "Los Angeles", "Chicago", "Houston"]}
df = pd.DataFrame(data)

# Filter the DataFrame by a list of string values in the "City" column
filtered_df = df[~df["City"].isin(["Los Angeles", "Chicago"])]

print(filtered_df)
# Out:
#    Name      City
# 0  John  New York
# 3  Adam   Houston

# %%
army15 = army[~army.loc[:,"regiment"].isin(["Dragoons"])]
army15
# Out:
#           Unnamed: 0    regiment company  deaths  battles  size  veterans  \
# origin
# Arizona            0  Nighthawks     1st     523        5  1045         1
# Texas              2  Nighthawks     2nd      25        2  1099        62
# Florida            3  Nighthawks     2nd     616        2  1400        26
# Louisana          10      Scouts     2nd      37        8  1099        63
# Georgia           11      Scouts     2nd      35        9  1523       345
#
#           readiness  armored  deserters    origin
# origin
# Arizona           1        1          4   Arizona
# Texas             3        1         31     Texas
# Florida           3        1          2   Florida
# Louisana          2        1          2  Louisana
# Georgia           3        1          3   Georgia

# %% [markdown]
# ### Step 16. Select the rows called Texas and Arizona

# %%
army16 = army[(army.loc[:,"origin"] == "Texas")| (army.loc[:,"origin"] == "Arizona")]
army16
# Out:
#          Unnamed: 0    regiment company  deaths  battles  size  veterans  \
# origin
# Arizona           0  Nighthawks     1st     523        5  1045         1
# Texas             2  Nighthawks     2nd      25        2  1099        62
#
#          readiness  armored  deserters   origin
# origin
# Arizona          1        1          4  Arizona
# Texas            3        1         31    Texas

# %% [markdown]
# ### Step 17. Select the third cell in the row named Arizona

# %%
army.iloc[0,3]
# Out:
# 523

# %%
army.at["Arizona","deaths"]
# Out:
# 523

# %%
army.iloc["Arizona"][3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 army.iloc["Arizona"][3]
#
# File c:\Users\Victor\miniconda3\envs\EVA_ENV\lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\Victor\miniconda3\envs\EVA_ENV\lib\site-packages\pandas\core\indexing.py:1749, in _iLocIndexer._getitem_axis(self, key, axis)
#    1747 key = item_from_zerodim(key)
#    1748 if not is_integer(key):
# -> 1749     raise TypeError("Cannot index by location index with a non-integer key")
#    1751 # validate the location
#    1752 self._validate_integer(key, axis)
#
# ...

# %% [markdown]
# ### Step 18. Select the third cell down in the column named deaths

# %%
army.iloc[2]["deaths"]
# Out:
# 43
