# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv) and assign it to a variable called chipo.

# %%
chipo = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv", sep = "\t")
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ### Step 3. Name of the max valued product

# %%
suma =  lambda x: x+3

# %%
suma (3)
# Out:
# 6

# %%
suma =  lambda x,y: x+y

# %%
suma(3,4)
# Out:
# 7

# %%
f = lambda x: float(x[1:])

# %%
f("$2.18")
# Out:
# 2.18

# %%
chipo.loc[:,"item_price"].apply(f)
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %%
def func(x):
    return float(x[1:])
chipo.loc[:,"item_price"].apply(func)# al apply podemos meterle cualquier función.

# %%
chipo.loc[:,"item_price"].apply(lambda x: float(x[1:]))

# %%
def comparator(x):
    numero = float(x[1:])
    if numero < 5:
        return "barato"
    elif numero < 10:
        retunr "medio"
    else:
        return "caro"

chipo.loc[:,"item_price"].apply(comparator)

# %%
chipo.loc[:,"item_price"].str.replace("$","").astype(float)# cambiamos el tipo de dato, previa eliminación del $ mediante el str.replace
# si quisieramos cambiar el valor de la columna,sería:
#chipo.loc[:,"item_price"] = chipo.loc[:,"item_price"].str.replace("$","").astype(float)
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: float64

# %%
prices=[]
for idx,row in chipo.iterrows():# el resultado nos devuelve el simbolo del dolar, probablemente bajo un string. Añadimos [1:] para quitarlo
    prices.append(float(row.loc["item_price"][1:]))# y convertimos a float
    
chipo.loc[:,"item_price"] = prices
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN       2.39
# ...

# %%
chipo
chipo.loc[:,"item_price"]=chipo.loc[:,"item_price"].str[1:].astype(float)

# %%
maximo = chipo.loc[:,"item_price"].sort_values(ascending=False).iloc[0]
maximo
# Out:
# 44.25

# %%
nombre = chipo.loc[chipo["item_price"] == maximo]
nombre
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#      item_price
# 3598      44.25

# %%
nombre["item_name"]
# Out:
# 3598    Chips and Fresh Tomato Salsa
# Name: item_name, dtype: object

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
filtro = chipo.loc[:,"item_price"].sort_values(ascending=False)

# %%
chipo.loc[chipo.loc[:,"item_price"]>10,"item_name"]
# Out:
# 4             Chicken Bowl
# 5             Chicken Bowl
# 7            Steak Burrito
# 13            Chicken Bowl
# 23         Chicken Burrito
#                ...
# 4610         Steak Burrito
# 4611        Veggie Burrito
# 4617         Steak Burrito
# 4618         Steak Burrito
# 4619    Chicken Salad Bowl
# Name: item_name, Length: 1130, dtype: object

# %%
ventas = chipo.loc[chipo["item_price"]>10]
len(ventas.loc[:,"item_name"].unique())# sacamos la longitud de la lista cogiendo los nombres sin que se repitan
# Out:
# 31

# %% [markdown]
# Extra: Cuántos pedidos se han hecho con un producto de más de 10$

# %%
len(ventas.loc[:,"order_id"].unique())
# Out:
# 863

# %% [markdown]
# ### Step 5. What is the price of each item? Get only item_name and unit_price

# %%
# Crea una nueva columna llamada unit_price
chipo["unit_price"] = chipo.loc[:,"item_price"]/chipo.loc[:,"quantity"]
chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price unit_price
# 0                                                   NaN       2.39       2.39
# ...

# %%
chipo[["item_name","unit_price"]]
# Out:
#                                   item_name unit_price
# 0              Chips and Fresh Tomato Salsa       2.39
# 1                                      Izze       3.39
# 2                          Nantucket Nectar       3.39
# 3     Chips and Tomatillo-Green Chili Salsa       2.39
# 4                              Chicken Bowl       8.49
# ...                                     ...        ...
# 4617                          Steak Burrito      11.75
# 4618                          Steak Burrito      11.75
# 4619                     Chicken Salad Bowl      11.25
# 4620                     Chicken Salad Bowl       8.75
# 4621                     Chicken Salad Bowl       8.75
#
# [4622 rows x 2 columns]

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
chipo.loc[:,"item_name"].sort_values()
# Out:
# 3389    6 Pack Soft Drink
# 341     6 Pack Soft Drink
# 1849    6 Pack Soft Drink
# 1860    6 Pack Soft Drink
# 2713    6 Pack Soft Drink
#               ...
# 2384    Veggie Soft Tacos
# 781     Veggie Soft Tacos
# 2851    Veggie Soft Tacos
# 1699    Veggie Soft Tacos
# 1395    Veggie Soft Tacos
# Name: item_name, Length: 4622, dtype: object

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered? 2 ways

# %%
max_price = chipo.loc[:,"unit_price"].max()
max_price
# Out:
# 11.89

# %%
chipo.loc[chipo.loc[:,"unit_price"]==max_price,:]
# Out:
#       order_id  quantity            item_name  \
# 281        123         2     Steak Salad Bowl
# 606        250         1     Steak Salad Bowl
# 613        253         2     Steak Salad Bowl
# 749        309         1     Steak Salad Bowl
# 1132       468         1  Carnitas Salad Bowl
# 1159       478         1     Steak Salad Bowl
# 1229       501         1  Barbacoa Salad Bowl
# 1311       534         1     Steak Salad Bowl
# 1326       541         1  Barbacoa Salad Bowl
# 1505       612         1     Steak Salad Bowl
# 1571       637         1     Steak Salad Bowl
# 1590       644         1     Steak Salad Bowl
# 1816       734         1     Steak Salad Bowl
# 2401       953         1     Steak Salad Bowl
# 2439       969         1     Steak Salad Bowl
# 2442       970         1  Barbacoa Salad Bowl
# 2610      1035         1  Carnitas Salad Bowl
# 2740      1088         1     Steak Salad Bowl
# 2804      1114         1     Steak Salad Bowl
# ...

# %%
max_names = chipo.loc[chipo.loc[:,"unit_price"]==max_price,"item_name"].unique()

# %%
for item in max_names:
    print(item)
    print(chipo.loc[chipo.loc[:,"item_name"]==item,"quantity"].sum())
# Out:
# Steak Salad Bowl
# 31
# Carnitas Salad Bowl
# 6
# Barbacoa Salad Bowl
# 10

# %%
# chipo.loc[:,"item_price"].sort_values().iloc[0]
type(maximo)
# Out:
# float

# %%
vendido = chipo["item_price"].value_counts(maximo)
len(vendido.unique())
# Out:
# 38

# %%
chipo[chipo["item_price"] == chipo["item_price"].max()]['quantity'].values[0]# ni de puta coña habría sacado esto yo solo
# Out:
# 15

# %%
chipo[chipo["item_price"] == chipo["item_price"].max()]['quantity']
# Out:
# 3598    15
# Name: quantity, dtype: int64

# %%
"""UNO DE TUS MEJORES AMIGOS"""
chipo.loc[chipo.loc[:,"item_name"].isin(max_names), :].groupby("item_name")["quantity"].sum()
#groupby tiene 3 cosas, sobre que agrupas, que agregas y cómo lo agregas
# Out:
#       order_id  quantity            item_name  \
# 281        123         2     Steak Salad Bowl
# 606        250         1     Steak Salad Bowl
# 607        250         1     Steak Salad Bowl
# 613        253         2     Steak Salad Bowl
# 749        309         1     Steak Salad Bowl
# 1132       468         1  Carnitas Salad Bowl
# 1159       478         1     Steak Salad Bowl
# 1229       501         1  Barbacoa Salad Bowl
# 1311       534         1     Steak Salad Bowl
# 1326       541         1  Barbacoa Salad Bowl
# 1418       576         1  Barbacoa Salad Bowl
# 1421       576         1  Barbacoa Salad Bowl
# 1505       612         1     Steak Salad Bowl
# 1571       637         1     Steak Salad Bowl
# 1590       644         1     Steak Salad Bowl
# 1816       734         1     Steak Salad Bowl
# 1825       738         1  Barbacoa Salad Bowl
# 1865       756         1  Carnitas Salad Bowl
# 2401       953         1     Steak Salad Bowl
# ...

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
veggie = chipo[chipo.loc[:,"item_name"] == "Veggie Salad Bowl"]
len(veggie)
# Out:
# 18

# %%
veggie = chipo[chipo.loc[:,"item_name"] == "Veggie Salad Bowl"].shape[0]
veggie
# Out:
# 18

# %%
chipo.loc[chipo.loc[:,"item_name"] == "Veggie Salad Bowl", :].shape[0]# esto nos ha iluminado mucho, importante recordar
# Out:
# 18

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
canned = chipo[chipo.loc[:,"item_name"] == "Canned Soda"]
ventas1 = canned[canned.loc[:,"quantity"]>1]
len(ventas1)
# Out:
# 20

# %% [markdown]
# Extra

# %%
# 1º Filtrar con una máscara: chipo[chipo["item_name"] == "Canned Soda"]
# 2º Agrupar las orders y canned sodas sumando las cantitades totales .groupby(['order_id','item_name'], as_index= False)
# 3º Quiero sumar solo la columna de quantity [['quantity']].sum()
