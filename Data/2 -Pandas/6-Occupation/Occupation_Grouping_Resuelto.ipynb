# %% [markdown]
# # Occupation

# %%
import pandas as pd

# %% [markdown]
# ### Step 3. Assign it to a variable called users.

# %%
users = pd.read_table('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', 
                      sep='|', index_col='user_id')
users
# Out:
#          age gender     occupation zip_code
# user_id
# 1         24      M     technician    85711
# 2         53      F          other    94043
# 3         23      M         writer    32067
# 4         24      M     technician    43537
# 5         33      F          other    15213
# ...      ...    ...            ...      ...
# 939       26      F        student    33319
# 940       32      M  administrator    02215
# 941       20      M        student    97229
# 942       48      F      librarian    78209
# 943       22      M        student    77841
#
# [943 rows x 4 columns]

# %%
users.loc[users.loc[:,"gender"]=="M"]
# Out:
#          age gender     occupation zip_code
# user_id
# 1         24      M     technician    85711
# 3         23      M         writer    32067
# 4         24      M     technician    43537
# 6         42      M      executive    98101
# 7         57      M  administrator    91344
# ...      ...    ...            ...      ...
# 936       24      M          other    32789
# 937       48      M       educator    98072
# 940       32      M  administrator    02215
# 941       20      M        student    97229
# 943       22      M        student    77841
#
# [670 rows x 4 columns]

# %% [markdown]
# ### Step 4. Discover what is the mean age per occupation

# %%
users.groupby("occupation")[["age"]].mean()
# Out:
#                      age
# occupation
# administrator  38.746835
# artist         31.392857
# doctor         43.571429
# educator       42.010526
# engineer       36.388060
# entertainment  29.222222
# executive      38.718750
# healthcare     41.562500
# homemaker      32.571429
# lawyer         36.750000
# librarian      40.000000
# marketing      37.615385
# none           26.555556
# other          34.523810
# programmer     33.121212
# retired        63.071429
# salesman       35.666667
# scientist      35.548387
# student        22.081633
# technician     33.148148
# writer         36.311111

# %%
# Out:
#                      age
# occupation
# administrator  38.746835
# artist         31.392857
# doctor         43.571429
# educator       42.010526
# engineer       36.388060
# entertainment  29.222222
# executive      38.718750
# healthcare     41.562500
# homemaker      32.571429
# lawyer         36.750000
# librarian      40.000000
# marketing      37.615385
# none           26.555556
# other          34.523810
# programmer     33.121212
# retired        63.071429
# salesman       35.666667
# scientist      35.548387
# student        22.081633
# technician     33.148148
# writer         36.311111

# %% [markdown]
# ### Step 5. Discover the Male ratio per occupation and sort it from the most to the least

# %%
# Define a dictionary containing ICC rankings 
rankings = {'test': ['India', 'South Africa', 'England', 
                            'New Zealand', 'Australia'], 
            'odi': ['England', 'India', 'New Zealand', 
                            'South Africa', 'Pakistan'], 
            't20': ['Pakistan', 'India', 'Australia', 
                            'England', 'New Zealand']} 
  
# Convert the dictionary into DataFrame 
rankings_pd = pd.DataFrame(rankings) 
  
# Before renaming the columns 
print(rankings_pd) 
  
rankings_pd.rename(columns = {'test':'TEST'}, inplace = True) 
  
# After renaming the columns 
print("\nAfter modifying first column:\n", rankings_pd.columns) 
rankings_pd
# Out:
#            test           odi          t20
# 0         India       England     Pakistan
# 1  South Africa         India        India
# 2       England   New Zealand    Australia
# 3   New Zealand  South Africa      England
# 4     Australia      Pakistan  New Zealand
#
# After modifying first column:
#  Index(['TEST', 'odi', 't20'], dtype='object')
#            TEST           odi          t20
# 0         India       England     Pakistan
# 1  South Africa         India        India
# 2       England   New Zealand    Australia
# 3   New Zealand  South Africa      England
# 4     Australia      Pakistan  New Zealand

# %%
total1.reset_index()
# Out:
#        occupation  gender
# 0   administrator      79
# 1          artist      28
# 2          doctor       7
# 3        educator      95
# 4        engineer      67
# 5   entertainment      18
# 6       executive      32
# 7      healthcare      16
# 8       homemaker       7
# 9          lawyer      12
# 10      librarian      51
# 11      marketing      26
# 12           none       9
# 13          other     105
# 14     programmer      66
# 15        retired      14
# 16       salesman      12
# 17      scientist      31
# 18        student     196
# 19     technician      27
# 20         writer      45

# %%
total
# Out:
#                       gender
# occupation    gender
# administrator F           36
#               M           43
# artist        F           13
#               M           15
# doctor        M            7
# educator      F           26
#               M           69
# engineer      F            2
#               M           65
# entertainment F            2
#               M           16
# executive     F            3
#               M           29
# healthcare    F           11
#               M            5
# homemaker     F            6
#               M            1
# lawyer        F            2
#               M           10
# librarian     F           29
#               M           22
# marketing     F           10
#               M           16
# none          F            4
#               M            5
# other         F           36
#               M           69
# programmer    F            6
#               M           60
# retired       F            1
# ...

# %%
total= users.groupby(["occupation","gender"])[["gender"]].count()
total1= users.groupby("occupation")[["gender"]].count()
total2 = total/total1
# total2.reset_index(col_level= "gender")
total2
# Out:
#                         gender
# occupation    gender
# administrator F       0.455696
#               M       0.544304
# artist        F       0.464286
#               M       0.535714
# doctor        M       1.000000
# educator      F       0.273684
#               M       0.726316
# engineer      F       0.029851
#               M       0.970149
# entertainment F       0.111111
#               M       0.888889
# executive     F       0.093750
#               M       0.906250
# healthcare    F       0.687500
#               M       0.312500
# homemaker     F       0.857143
#               M       0.142857
# lawyer        F       0.166667
#               M       0.833333
# librarian     F       0.568627
#               M       0.431373
# marketing     F       0.384615
#               M       0.615385
# none          F       0.444444
#               M       0.555556
# other         F       0.342857
#               M       0.657143
# programmer    F       0.090909
# ...

# %%
# Out:
# occupation
# doctor           1.000000
# engineer         0.970149
# technician       0.962963
# retired          0.928571
# programmer       0.909091
# executive        0.906250
# scientist        0.903226
# entertainment    0.888889
# lawyer           0.833333
# salesman         0.750000
# educator         0.726316
# student          0.693878
# other            0.657143
# marketing        0.615385
# writer           0.577778
# none             0.555556
# administrator    0.544304
# artist           0.535714
# librarian        0.431373
# healthcare       0.312500
# homemaker        0.142857
# Name: count, dtype: float64

# %%
Hombre = users[users['gender'] == 'M']
Hombre["occupation"].value_counts()
Hombre["occupation"].value_counts()/users["occupation"].value_counts()

filtro_m = users[users["gender"] == "M"]
filtro_m_counts = filtro_m["occupation"].value_counts()
users_counts = users["occupation"].value_counts()
total = filtro_m_counts / users_counts
total


# users_plus = pd.concat([users[users.loc[:,"gender"]=="M"], total], ignore_index=True)
# users_plus.dropna()
# Out:
# occupation
# administrator    0.544304
# artist           0.535714
# doctor           1.000000
# educator         0.726316
# engineer         0.970149
# entertainment    0.888889
# executive        0.906250
# healthcare       0.312500
# homemaker        0.142857
# lawyer           0.833333
# librarian        0.431373
# marketing        0.615385
# none             0.555556
# other            0.657143
# programmer       0.909091
# retired          0.928571
# salesman         0.750000
# scientist        0.903226
# student          0.693878
# technician       0.962963
# writer           0.577778
# Name: count, dtype: float64

# %%
# Out:
#        occupation gender  percentage
# 1   administrator      M    0.544304
# 3          artist      M    0.535714
# 4          doctor      M    1.000000
# 6        educator      M    0.726316
# 8        engineer      M    0.970149
# 10  entertainment      M    0.888889
# 12      executive      M    0.906250
# 14     healthcare      M    0.312500
# 16      homemaker      M    0.142857
# 18         lawyer      M    0.833333
# 20      librarian      M    0.431373
# 22      marketing      M    0.615385
# 24           none      M    0.555556
# 26          other      M    0.657143
# 28     programmer      M    0.909091
# 30        retired      M    0.928571
# 32       salesman      M    0.750000
# 34      scientist      M    0.903226
# 36        student      M    0.693878
# 38     technician      M    0.962963
# 40         writer      M    0.577778

# %% [markdown]
# ### Step 6. For each occupation, calculate the minimum and maximum ages

# %%
users.groupby("occupation")["age"].aggregate(["min","max"])
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %% [markdown]
# ### Step 7. For each combination of occupation and gender, calculate the mean age

# %%
users.groupby(["occupation","gender"])[["age"]].mean()
# Out:
#                             age
# occupation    gender
# administrator F       40.638889
#               M       37.162791
# artist        F       30.307692
#               M       32.333333
# doctor        M       43.571429
# educator      F       39.115385
#               M       43.101449
# engineer      F       29.500000
#               M       36.600000
# entertainment F       31.000000
#               M       29.000000
# executive     F       44.000000
#               M       38.172414
# healthcare    F       39.818182
#               M       45.400000
# homemaker     F       34.166667
#               M       23.000000
# lawyer        F       39.500000
#               M       36.200000
# librarian     F       40.000000
#               M       40.000000
# marketing     F       37.200000
#               M       37.875000
# none          F       36.500000
#               M       18.600000
# other         F       35.472222
#               M       34.028986
# ...

# %% [markdown]
# ### Step 8.  For each occupation present the percentage of women and men

# %%
total = users.groupby(["occupation","gender"])[["gender"]].count()
total1 = users.groupby("occupation")[["gender"]].count()
total/total1
# Out:
#                         gender
# occupation    gender
# administrator F       0.455696
#               M       0.544304
# artist        F       0.464286
#               M       0.535714
# doctor        M       1.000000
# educator      F       0.273684
#               M       0.726316
# engineer      F       0.029851
#               M       0.970149
# entertainment F       0.111111
#               M       0.888889
# executive     F       0.093750
#               M       0.906250
# healthcare    F       0.687500
#               M       0.312500
# homemaker     F       0.857143
#               M       0.142857
# lawyer        F       0.166667
#               M       0.833333
# librarian     F       0.568627
#               M       0.431373
# marketing     F       0.384615
#               M       0.615385
# none          F       0.444444
#               M       0.555556
# other         F       0.342857
#               M       0.657143
# programmer    F       0.090909
# ...

# %%
# Out:
# occupation     gender
# administrator  M         0.544304
#                F         0.455696
# artist         M         0.535714
#                F         0.464286
# doctor         M         1.000000
# educator       M         0.726316
#                F         0.273684
# engineer       M         0.970149
#                F         0.029851
# entertainment  M         0.888889
#                F         0.111111
# executive      M         0.906250
#                F         0.093750
# healthcare     F         0.687500
#                M         0.312500
# homemaker      F         0.857143
#                M         0.142857
# lawyer         M         0.833333
#                F         0.166667
# librarian      F         0.568627
#                M         0.431373
# marketing      M         0.615385
#                F         0.384615
# none           M         0.555556
#                F         0.444444
# other          M         0.657143
#                F         0.342857
# ...
