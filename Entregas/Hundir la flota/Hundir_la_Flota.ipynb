# %%
"""Importación de librerias"""
import numpy as np
import time
import os
from IPython.display import clear_output
"""Importación de librerias"""

""" Definición de variables"""
flota_j = [1,1,1,1,2,2,2,3,3,4]
flota_m = [1,1,1,1,2,2,2,3,3,4]
n_barcos_j = len(flota_j)
portaaviones_j = flota_j.count(4)
acorazado_j = flota_j.count(3)
buque_j = flota_j.count(2)
fragata_j = flota_j.count(1)
n_barcos_m = len(flota_m)
portaaviones_m = flota_m.count(4)
acorazado_m = flota_m.count(3)
buque_m = flota_m.count(2)
fragata_m = flota_m.count(1)
n_portaaviones_j = 0
n_acorazado_j = 0
n_buque_j = 0
n_fragata_j = 0
# n_barcos_j = len(flota_j)
n_portaaviones_m = 0
n_acorazado_m = 0
n_buque_m = 0
n_fragata_m = 0
# n_barcos_m = len(flota_m)
turno_m = 0
turno_j = 0
focus = 0
aciertos = 0
up = 0
down = 0
left = 0
right = 0
ganador_j = 0
ganador_m = 0
n_vidas_jugador = sum(flota_j)
n_vidas_maquina = sum(flota_m)
l_barcos = ["","fragata","buque","acorazado","portaaviones"]
"""Definición de variables"""

"""Definición del tablero"""
tablero1 = np.full((12,11)," ~ ") # tablero barcos jugador
tablero2 = np.full((11,11)," ~ ") # tablero disparos jugador
tablero3 = np.full((12,11)," ~ ") # tablero barcos máquina
tablero4 = np.full((11,11)," ~ ") # tablero disparos máquina

marco = ["=V=","_1_","_2_","_3_","_4_","_5_","_6_","_7_","_8_","_9_","_10"]
jugador1 = ["___","___","_J_","_U_","_G_","_A_","_D_","_O_","_R_","___","___"]
jugador2 = ["___","___","_M_","_A_","_Q_","_U_","_I_","_N_","_A_","___","___"]# buscar la opción de indicar el nº de vidas o barcos restantes en el título de la cuadrícula

tablero1[1:,:1] = np.reshape(marco,(11,1))
tablero1[1:2,:] = np.reshape(marco,(1,11))
tablero1[:1,:] = np.reshape(jugador1,(1,11))
# tablero1[0,-1] = len(flota_j)
# tablero1[0,-1] = sum(flota_j)

tablero2[0:,:1] = np.reshape(marco,(11,1))
tablero2[:1,:] = np.reshape(marco,(1,11))

tablero3[1:,:1] = np.reshape(marco,(11,1))
tablero3[1:2,:] = np.reshape(marco,(1,11))
tablero3[:1,:] = np.reshape(jugador2,(1,11))
# tablero3[0,-1] = len(flota_m)
# tablero1[0,-1] = sum(flota_m)

tablero4[0:,:1] = np.reshape(marco,(11,1))
tablero4[:1,:] = np.reshape(marco,(1,11))
"""Definición del tablero"""



jugar = input("¿Quieres Jugar? (S/N)")
if jugar.lower() == "s":
    
    reglas = input("¿Conoces las reglas del juego de Hundir la Flota? (S/N)")
    if reglas.lower() == "s":
        clear_output(wait=True)
        print("Genial, entonces vamos a ello!")
    elif reglas.lower() == "n":
        clear_output(wait=True)
        print("Aqui las tienes")
        print("Reglas del juego de Hundir la Flota:\n",
      "-------------------------------------\n",
      "1. Preparación del juego:\n",
      "   - Los barcos de cada jugdor se pondrán en la cuadrícula de 10x10 de forma aleatoria.\n",
      "   - Los barcos disponibles son: portaaviones (4 casillas), acorazado (3 casillas), buque (2 casillas) y fragata (1 casillas).\n",
      "   - Los barcos no pueden superponerse ni colocarse en diagonal.\n",
      "\n",
      "2. Turno de juego:\n",
      "   - Los jugadores se turnan para bombardear las cuadrículas del oponente con el objetivo de hundir todos sus barcos.\n",
      "   - Cada turno, el jugador elige una casilla del tablero del oponente para bombardear.\n",
      "   - El jugador podrá elegir si jugar de forma manual, introduciendo los valores de casillas donde disparar, o de forma automática con disparo aleatorio.\n",
      "   - La máquina disparará siempre de forma aleatoria.\n",
      "   - En caso de impacto, el jugador/máquina vuelve a disparar.\n",
      "\n",
      "3. Resultados del bombardeo:\n",
      "   - Si la casilla elegida contiene una parte de un barco del oponente, se considera un impacto y se marca como '_X_' en la cuadrícula del oponente.\n",
      "   - Si la casilla no contiene ninguna parte de un barco, se considera un fallo y se marca como ' A ' en la cuadrícula del oponente.\n",
      "   - Si todas las casillas de un barco han sido impactadas, el barco se hunde y se informa al jugador.\n",
      "   - El juego continúa hasta que todos los barcos de un jugador hayan sido hundidos.\n",
      "\n",
      "4. Fin del juego:\n",
      "   - El juego termina cuando uno de los jugadores ha hundido todos los barcos del oponente.\n",
      "   - El jugador que logra hundir todos los barcos del oponente es declarado como ganador.")

    game_style = input("¿Como quieres jugar, Modo Manual (M) o Modo Automático (A)?")
    clear_output(wait=True)
    print("Genial! Pongamos nuestros barcos")
    
    while n_portaaviones_j < portaaviones_j:
        if np.random.randint(0,2,1):
            orientacion = "horizontal"
            coord1 = np.random.randint(2,11)
            coord2 = np.random.randint(1,11-4+1)
        
            if "_B_" in tablero1[coord1-1:coord1+2, coord2-1:coord2+5]:
                pass
            else: 
                tablero1[coord1, coord2:coord2+4] = "_B_"
                n_portaaviones_j += 1
        else:
            orientacion = "vertical"

            coord1 = np.random.randint(2,11-4+1)
            coord2 = np.random.randint(1,11)
        
            if "_B_" in tablero1[coord1-1:coord1+5, coord2-1:coord2+2]:
                pass
            else: 
                tablero1[coord1:coord1+4, coord2] = "_B_"
                n_portaaviones_j += 1
    while n_acorazado_j < acorazado_j:
        if np.random.randint(0,2,1):
            orientacion = "horizontal"
            coord1 = np.random.randint(2,11)
            coord2 = np.random.randint(1,11-3+1)
        
            if "_B_" in tablero1[coord1-1:coord1+2, coord2-1:coord2+4]:
                pass
            else: 
                tablero1[coord1, coord2:coord2+3] = "_B_"
                n_acorazado_j += 1
        else:
            orientacion = "vertical"

            coord1 = np.random.randint(2,11-3+1)
            coord2 = np.random.randint(1,11)
        
            if "_B_" in tablero1[coord1-1:coord1+4, coord2-1:coord2+2]:
                pass
            else: 
                tablero1[coord1:coord1+3, coord2] = "_B_"
                n_acorazado_j += 1
    while n_buque_j < buque_j:
        if np.random.randint(0,2,1):
            orientacion = "horizontal"
            coord1 = np.random.randint(2,11)
            coord2 = np.random.randint(1,11-2+1)
        
            if "_B_" in tablero1[coord1-1:coord1+2, coord2-1:coord2+3]:
                pass
            else: 
                tablero1[coord1, coord2:coord2+2] = "_B_"
                n_buque_j += 1
        else:
            orientacion = "vertical"

            coord1 = np.random.randint(2,11-2+1)
            coord2 = np.random.randint(1,11)
        
            if "_B_" in tablero1[coord1-1:coord1+3, coord2-1:coord2+2]:
                pass
            else: 
                tablero1[coord1:coord1+2, coord2] = "_B_"
                n_buque_j += 1
    while n_fragata_j < fragata_j:
        if np.random.randint(0,2,1):
            orientacion = "horizontal"
            coord1 = np.random.randint(2,11)
            coord2 = np.random.randint(1,11)
        
            if "_B_" in tablero1[coord1-1:coord1+2, coord2-1:coord2+2]:
                pass
            else: 
                tablero1[coord1, coord2:coord2+1] = "_B_"
                n_fragata_j += 1
        else:
            orientacion = "vertical"

            coord1 = np.random.randint(2,11)
            coord2 = np.random.randint(1,11)
        
            if "_B_" in tablero1[coord1-1:coord1+2, coord2-1:coord2+2]:
                pass
            else: 
                tablero1[coord1:coord1+1, coord2] = "_B_"
                n_fragata_j += 1

    while n_portaaviones_m < portaaviones_m:
        if np.random.randint(0,2,1):
            orientacion = "horizontal"
            coord3 = np.random.randint(2,11)
            coord4 = np.random.randint(1,11-4+1)
        
            if "_B_" in tablero3[coord3-1:coord3+2, coord4-1:coord4+5]:
                pass
            else: 
                tablero3[coord3, coord4:coord4+4] = "_B_"
                n_portaaviones_m += 1
        else:
            orientacion = "vertical"

            coord3 = np.random.randint(2,11-4+1)
            coord4 = np.random.randint(1,11)
        
            if "_B_" in tablero3[coord3-1:coord3+5, coord4-1:coord4+2]:
                pass
            else: 
                tablero3[coord3:coord3+4, coord4] = "_B_"
                n_portaaviones_m += 1
    while n_acorazado_m < acorazado_m:
        if np.random.randint(0,2,1):
            orientacion = "horizontal"
            coord3 = np.random.randint(2,11)
            coord4 = np.random.randint(1,11-3+1)
        
            if "_B_" in tablero3[coord3-1:coord3+2, coord4-1:coord4+4]:
                pass
            else: 
                tablero3[coord3, coord4:coord4+3] = "_B_"
                n_acorazado_m += 1
        else:
            orientacion = "vertical"

            coord3 = np.random.randint(2,11-3+1)
            coord4 = np.random.randint(1,11)
        
            if "_B_" in tablero3[coord3-1:coord3+4, coord4-1:coord4+2]:
                pass
            else: 
                tablero3[coord3:coord3+3, coord4] = "_B_"
                n_acorazado_m += 1
    while n_buque_m < buque_m:
        if np.random.randint(0,2,1):
            orientacion = "horizontal"
            coord3 = np.random.randint(2,11)
            coord4 = np.random.randint(1,11-2+1)
        
            if "_B_" in tablero3[coord3-1:coord3+2, coord4-1:coord4+3]:
                pass
            else: 
                tablero3[coord3, coord4:coord4+2] = "_B_"
                n_buque_m += 1
        else:
            orientacion = "vertical"

            coord3 = np.random.randint(2,11-2+1)
            coord4 = np.random.randint(1,11)
        
            if "_B_" in tablero3[coord3-1:coord3+3, coord4-1:coord4+2]:
                pass
            else: 
                tablero3[coord3:coord3+2, coord4] = "_B_"
                n_buque_m += 1

    while n_fragata_m < fragata_m:
        if np.random.randint(0,2,1):
            orientacion = "horizontal"

            coord3 = np.random.randint(2,12)
            coord4 = np.random.randint(1,11)
            if "_B_" in tablero3[coord3-1:coord3+2, coord4-1:coord4+2]:
                pass
            else: 
                tablero3[coord3, coord4:coord4+1] = "_B_"
                n_fragata_m += 1
        else:
            orientacion = "vertical"

            coord3 = np.random.randint(2,12)
            coord4 = np.random.randint(1,11)
            if "_B_" in tablero3[coord3-1:coord3+2, coord4-1:coord4+2]:
                pass
            else: 
                tablero3[coord3:coord3+1, coord4] = "_B_"
                n_fragata_m += 1

    enter = input("Presiona enter para continuar")
    if enter == "":
        clear_output(wait=True)
        print(tablero1)
        if game_style.lower() == "a":
            print(tablero3)
    enter = input("Presiona enter para continuar")
    if enter == "":    
        clear_output(wait=True)
        time.sleep(1)
        print("Veamos quien empieza")

#decisión de turno aleatoria
    enter = input("Presiona enter para continuar")
    if enter == "":   
        if np.random.randint(0,2,1):
            clear_output(wait=True)
            time.sleep(1)
            print("Te toca esperar, empiezo disparando!")
            turno_m = 1
        else:
            clear_output(wait=True)
            time.sleep(1)
            print("Que suerte, eres el primero en empezar, empieza disparando!")
            turno_j = 1

while (ganador_m == 0) and (ganador_j == 0):
    enter = input("Presiona enter para continuar")  
    if enter == "":
        if turno_m == 1 and focus == 0 and up == 0 and down == 0 and right == 0 and left == 0:
            coord1 = np.random.randint(2,12)
            coord2 = np.random.randint(1,11)
            if "_B_" in tablero1[coord1, coord2]:
                tablero1[coord1, coord2] = "_X_"
                tablero2[coord1-1, coord2] = "_X_"
                clear_output(wait=True)
                print(f"Te he dado en la fila {coord1-1}, columna {coord2}")
                print(tablero1)
                print(tablero2)  
                turno_m = 1
                turno_j = 0
                n_vidas_jugador-=1
                focus = 1
                aciertos += 1              
                if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2]:
                    print(f"He hundido tu {l_barcos[aciertos]}!")
                    turno_m = 1
                    turno_j = 0
                    focus = 0
                    aciertos = 0
                    n_barcos_j -=1
                else:    
                    enter = input("Presiona enter para continuar") # disparo "inteligente"
                    if enter == "" and focus == 1 and up == 0 and down == 0 and right == 0 and left == 0:# derecha
                        up = 0
                        down = 0
                        right = 1
                        left = 0
                        if coord2+((right)-(left))*focus < 10:  
                            if focus == 1 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: 
                                #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando.
                                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                clear_output(wait=True)
                                print(f"Te he dado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus}")
                                print(tablero1)
                                print(tablero2)  
                                turno_m = 1
                                turno_j = 0
                                n_vidas_jugador-=1
                                focus = 2
                                aciertos += 1 
                                if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+1+focus]:
                                    print(f"He hundido tu {l_barcos[aciertos]}!")# reseteamos todos los valores de búsqueda y repetimos disparo
                                    turno_m = 1
                                    turno_j = 0
                                    focus = 0
                                    aciertos = 0
                                    n_barcos_j -=1
                                    up = 0
                                    down = 0
                                    right = 0
                                    left = 0
                                else:    # derecha
                                    enter = input("Presiona enter para continuar") 
                                    if enter == "" and focus == 2 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: 
                                        #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                                        tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                        tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                        clear_output(wait=True)
                                        print(f"Te he dado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus}")
                                        print(tablero1)
                                        print(tablero2)  
                                        turno_m = 1
                                        turno_j = 0
                                        n_vidas_jugador-=1
                                        focus = 3
                                        aciertos += 1 
                                        if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+1+focus]:
                                            print(f"He hundido tu {l_barcos[aciertos]}!")# reseteamos todos los valores de búsqueda y repetimos disparo
                                            turno_m = 1
                                            turno_j = 0
                                            focus = 0
                                            aciertos = 0
                                            n_barcos_j -=1
                                            up = 0
                                            down = 0
                                            right = 0
                                            left = 0
                                        else:    # derecha
                                            enter = input("Presiona enter para continuar") 
                                            if enter == "" and focus == 3 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: 
                                                #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                                                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                                clear_output(wait=True)
                                                print(f"Te he dado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus}")
                                                print(tablero1)
                                                print(tablero2)  
                                                turno_m = 1
                                                turno_j = 0
                                                n_vidas_jugador-=1
                                                aciertos += 1 
                                                if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+1+focus]:
                                                    print(f"He hundido tu {l_barcos[aciertos]}!")# reseteamos todos los valores de búsqueda y repetimos disparo 
                                                    turno_m = 1
                                                    turno_j = 0
                                                    focus = 0
                                                    aciertos = 0
                                                    n_barcos_j -=1
                                                    up = 0
                                                    down = 0
                                                    right = 0
                                                    left = 0                                                         
                                            elif enter == "" and focus == 3 and "_B_" not in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                                                # tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = " A "
                                                clear_output(wait=True)
                                                print(f"He fallado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus},ahora te toca a ti")
                                                print(tablero1)
                                                print(tablero2)  
                                                turno_m = 0
                                                turno_j = 1
                                                focus = 1
                                                up = 0
                                                down = 0
                                                right = 0
                                                left = 1
                                                
                                    elif " A " in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] or "_X_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                                        turno_m = 1
                                        turno_j = 0
                                        pass
                                    else:
                                        # tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                        tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = " A "
                                        clear_output(wait=True)
                                        print(f"He fallado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus},ahora te toca a ti")
                                        print(tablero1)
                                        print(tablero2)
                                        turno_m = 0
                                        turno_j = 1
                                        focus = 1
                                        up = 0
                                        down = 0
                                        right = 0
                                        left = 1
                                              
                            elif " A " in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] or "_X_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                                turno_m = 1
                                turno_j = 0
                                pass
                            else:
                                # tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = " A "
                                acierto = 0
                                clear_output(wait=True)
                                print(f"He fallado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus},ahora te toca a ti")
                                print(tablero1)
                                print(tablero2) 
                                turno_m = 0
                                turno_j = 1
                                focus = 1
                                up = 0
                                down = 0
                                right = 0
                                left = 1
                        else:
                            turno_m = 1
                            turno_j = 0
                            focus = 1
                            up = 0
                            down = 0
                            right = 0
                            left = 1
            elif " A " in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] or "_X_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                turno_m = 1
                turno_j = 0
                pass
            else:
                # tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = " A "
                clear_output(wait=True)
                print(f"He fallado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus},ahora te toca a ti")
                print(tablero1)
                print(tablero2)  
                turno_m = 0
                turno_j = 1
                aciertos = 0
                focus = 0
                up = 0
                down = 0
                right = 0
                left = 0
        elif turno_m == 1 and focus == 1 and left == 1: # izquierda
            if coord2+((right)-(left))*focus > 1:
                if "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: 
                    #hacemos disparo en coordenada mas focus hacia la izquierda, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                    tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                    tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                    clear_output(wait=True)
                    print(f"Te he dado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus} izquierda")
                    print(tablero1)
                    print(tablero2)   
                    turno_m = 1
                    turno_j = 0
                    n_vidas_jugador-=1
                    focus = 2
                    aciertos += 1 
                    if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2, coord2-1-focus:coord2+2]:# ojo, si damos turno_m mitad de un barco grande, entenderemos que hemos hundido un buque, y no es correcto
                        print(f"He hundido tu {l_barcos[aciertos]}!")  
                        turno_m = 1
                        turno_j = 0
                        focus = 0
                        aciertos = 0
                        n_barcos_j -=1
                        up = 0
                        down = 0
                        right = 0
                        left = 0
                    else:    # izquierda
                        enter = input("Presiona enter para continuar") 
                        if enter == "" and focus == 2 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: 
                            #hacemos disparo en coordenada mas focus hacia la izquierda, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                            tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                            #disparo1 = tablero1[coord1, coord2]
                            tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                            clear_output(wait=True)
                            print(f"Te he dado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus}")
                            print(tablero1)
                            print(tablero2)   
                            turno_m = 1
                            turno_j = 0
                            n_vidas_jugador-=1
                            focus = 3
                            aciertos += 1 
                            if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2, coord2-1-focus:coord2+2]:
                                print(f"He hundido tu {l_barcos[aciertos]}!")
                                turno_m = 1
                                turno_j = 0
                                focus = 0
                                aciertos = 0
                                n_barcos_j -=1
                                up = 0
                                down = 0
                                right = 0
                                left = 0
                            else:    #izquierda
                                enter = input("Presiona enter para continuar") 
                                if enter == "" and focus == 3 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: 
                                    #hacemos disparo en coordenada mas focus hacia la izquierda, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                                    tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                    tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                    clear_output(wait=True)
                                    print(f"Te he dado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus}")
                                    print(tablero1)
                                    print(tablero2)   
                                    turno_m = 1
                                    turno_j = 0
                                    n_vidas_jugador-=1
                                    aciertos += 1 
                                    if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2, coord2-1-focus:coord2+2]:
                                        print(f"He hundido tu {l_barcos[aciertos]}!")
                                        turno_m = 1
                                        turno_j = 0
                                        focus = 0
                                        aciertos = 0
                                        n_barcos_j -=1
                                        up = 0
                                        down = 0
                                        right = 0
                                        left = 0
                                elif enter == "" and focus == 3 and "_B_" not in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                                    # tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                    tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = " A "
                                    clear_output(wait=True)                                    
                                    print(f"He fallado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus},ahora te toca a ti")
                                    print(tablero1)
                                    print(tablero2)  
                                    focus = 1
                                    up = 0
                                    down = 1
                                    right = 0
                                    left = 0
                                    
                                    turno_m = 0
                                    turno_j = 1
                        elif " A " in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] or "_X_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                            turno_m = 1
                            turno_j = 0
                            pass
                        else:
                            tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = " A "
                            clear_output(wait=True)
                            print(f"He fallado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus},ahora te toca a ti")
                            print(tablero1)
                            print(tablero2) 
                            turno_m = 0
                            turno_j = 1
                            focus = 1
                            up = 0
                            down = 1
                            right = 0
                            left = 0
                elif " A " in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] or "_X_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                    turno_m = 1
                    turno_j = 0
                    pass
                else:
                    # tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                    tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = " A "
                    clear_output(wait=True)
                    print(f"He fallado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus},ahora te toca a ti")
                    print(tablero1)
                    print(tablero2)  
                    turno_m = 0
                    turno_j = 1
                    focus = 1
                    up = 0
                    down = 1
                    right = 0
                    left = 0

            else:
                turno_m = 1
                turno_j = 0
                focus = 1
                up = 0
                down = 1
                right = 0
                left = 0
                        
        elif turno_m == 1 and focus == 1 and down == 1: # abajo
            if coord1-1+((down)-(up))*focus < 10:
                if "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: 
                    #hacemos disparo en coordenada mas focus hacia abajo, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                    tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                    tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                    clear_output(wait=True)
                    print(f"Te he dado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus}")
                    print(tablero1)
                    print(tablero2)   
                    turno_m = 1
                    turno_j = 0
                    n_vidas_jugador-=1
                    focus = 2
                    aciertos += 1 
                    if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+1+focus, coord2-1:coord2+2]:# ojo, si damos turno_m mitad de un barco grande, entenderemos que hemos hundido un buque, y no es correcto
                        print(f"He hundido tu {l_barcos[aciertos]}!")
                        turno_m = 1
                        turno_j = 0
                        focus = 0
                        aciertos = 0
                        n_barcos_j -=1
                        up = 0
                        down = 0
                        right = 0
                        left = 0
                    else:    # abajo
                        enter = input("Presiona enter para continuar") 
                        if enter == "" and focus == 2 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: 
                            #hacemos disparo en coordenada mas focus hacia abajo, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                            tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                            #disparo1 = tablero1[coord1, coord2]
                            tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                            clear_output(wait=True)
                            print(f"Te he dado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus}")
                            print(tablero1)
                            print(tablero2)   
                            turno_m = 1
                            turno_j = 0
                            n_vidas_jugador-=1
                            focus = 3
                            aciertos += 1 
                            if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+1+focus, coord2-1:coord2+2]:
                                print(f"He hundido tu {l_barcos[aciertos]}!")
                                turno_m = 1
                                turno_j = 0
                                focus = 0
                                aciertos = 0
                                n_barcos_j -=1
                                up = 0
                                down = 0
                                right = 0
                                left = 0
                            else:    #abajo
                                enter = input("Presiona enter para continuar") 
                                if enter == "" and focus == 3 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: 
                                    #hacemos disparo en coordenada mas focus hacia abajo, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                                    tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                    tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                    clear_output(wait=True)
                                    print(f"Te he dado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus}")
                                    print(tablero1)
                                    print(tablero2)   
                                    turno_m = 1
                                    turno_j = 0
                                    n_vidas_jugador-=1
                                    focus = 4
                                    aciertos += 1 
                                    if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+1+focus, coord2-1:coord2+2]:
                                        print(f"He hundido tu {l_barcos[aciertos]}!")
                                        turno_m = 1
                                        turno_j = 0
                                        focus = 0
                                        n_barcos_j -=1
                                        up = 0
                                        down = 0
                                        right = 0
                                        left = 0
                                elif enter == "" and focus == 3 and "_B_" not in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                                    # tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                    tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = " A "
                                    clear_output(wait=True)
                                    print(f"He fallado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus},ahora te toca a ti")
                                    print(tablero1)
                                    print(tablero2)  
                                    focus = 1
                                    up = 1
                                    down = 0
                                    right = 0
                                    left = 0
                                    turno_m = 0
                                    turno_j = 1
                        elif " A " in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] or "_X_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                            turno_m = 1
                            turno_j = 0
                            pass
                        else:
                            # tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                            tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = " A "
                            clear_output(wait=True)
                            print(f"He fallado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus},ahora te toca a ti")
                            print(tablero1)
                            print(tablero2) 
                            turno_m = 0
                            turno_j = 1
                            focus = 1
                            up = 1
                            down = 0
                            right = 0
                            left = 0                            
                elif " A " in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] or "_X_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                    turno_m = 1
                    turno_j = 0
                    pass
                else:
                    # tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                    tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = " A "                    
                    clear_output(wait=True)
                    print(f"He fallado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus},ahora te toca a ti")
                    print(tablero1)
                    print(tablero2) 
                    turno_m = 0
                    turno_j = 1
                    focus = 1
                    up = 1
                    down = 0
                    right = 0
                    left = 0
            else:
                focus = 1
                up = 1
                down = 0
                right = 0
                left = 0
        elif turno_m == 1 and focus == 1 and up == 1: # arriba
            if "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: 
                #hacemos disparo en coordenada mas focus hacia arriba, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                clear_output(wait=True)
                print(f"Te he dado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus}")
                print(tablero1)
                print(tablero2)  
                turno_m = 1
                turno_j = 0
                n_vidas_jugador-=1
                focus = 2
                aciertos +=1
                if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1-focus:coord1+2, coord2-1:coord2+2]:# ojo, si damos turno_m mitad de un barco grande, entenderemos que hemos hundido un buque, y no es correcto
                    print(f"He hundido tu {l_barcos[aciertos]}!") 
                    turno_m = 1
                    turno_j = 0
                    focus = 0
                    aciertos = 0
                    n_barcos_j -=1
                    up = 0
                    down = 0
                    right = 0
                    left = 0
                else:    # arriba
                    enter = input("Presiona enter para continuar") 
                    if enter == "" and focus == 2 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                        tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                        tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                        clear_output(wait=True)
                        print(f"Te he dado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus}")
                        print(tablero1)
                        print(tablero2)   
                        turno_m = 1
                        turno_j = 0
                        n_vidas_jugador-=1
                        focus = 3
                        aciertos +=1
                        if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1-focus:coord1+2, coord2-1:coord2+2]:
                            print(f"He hundido tu {l_barcos[aciertos]}!")
                            turno_m = 1
                            turno_j = 0
                            focus = 0
                            aciertos = 0
                            n_barcos_j -=1
                            up = 0
                            down = 0
                            right = 0
                            left = 0
                        else:    #arriba
                            enter = input("Presiona enter para continuar") 
                            if enter == "" and focus == 3 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: 
                                #hacemos disparo en coordenada mas focus hacia arrba, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                clear_output(wait=True)
                                print(f"Te he dado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus}")
                                print(tablero1)
                                print(tablero2)     
                                turno_m = 1
                                turno_j = 0
                                n_vidas_jugador-=1
                                aciertos +=1
                                focus = 4
                                if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1-focus:coord1+2, coord2-1:coord2+2]:
                                    print(f"He hundido tu {l_barcos[aciertos]}!")   
                                    turno_m = 1
                                    turno_j = 0
                                    focus = 0
                                    aciertos = 0
                                    n_barcos_j -=1
                                    up = 0
                                    down = 0
                                    right = 0
                                    left = 0
                                    # ganador_j = 1                                                           
                            elif enter == "" and focus == 3 and "_B_" not in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                                # tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = " A "
                                focus = 1
                                clear_output(wait=True)
                                print(f"He fallado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus},ahora te toca a ti")
                                print(tablero1)
                                print(tablero2)  
                                turno_m = 0
                                turno_j = 1
                    elif " A " in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] or "_X_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                        turno_m = 1
                        turno_j = 0
                        pass
                    else:
                        # tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                        tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = " A "
                        clear_output(wait=True)
                        print(f"He fallado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus},ahora te toca a ti")
                        print(tablero1)
                        print(tablero2) 
                        turno_m = 0
                        turno_j = 1
            elif " A " in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] or "_X_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                turno_m = 1
                turno_j = 0
                pass
            else:
                # tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = " A "
                clear_output(wait=True)
                print(f"He fallado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus},ahora te toca a ti")
                print(tablero1)
                print(tablero2) 
                focus = 1
                turno_m = 0
                turno_j = 1
        elif turno_j == 1:
            if game_style.lower() == "m":
                coord3 = int(input("Introduce un valor entre el 1 y el 10 para la fila donde quieres disparar"))
                coord4 = int(input("Introduce un valor entre el 1 y el 10 para la columna donde quieres disparar"))
                if "_B_" in tablero3[coord3+1, coord4]:
                    tablero3[coord3+1, coord4] = "_X_"
                    tablero4[coord3, coord4] = "_X_"
                    clear_output(wait=True)
                    print("Me has dado")
                    # print(tablero3)
                    print(tablero4)   
                    turno_j = 1
                    turno_m = 0
                    n_vidas_maquina-=1
                elif " A " in tablero3[coord3+1, coord4] or "_X_" in tablero3[coord3+1, coord4]:
                    print ("Ya has disparado ahí, tolai, vuelve a intentarlo")
                    turno_j = 1
                    turno_m = 0
                    pass
                    
                else:
                    tablero4[coord3, coord4] = "~A~"
                    acierto = 0
                    clear_output(wait=True)
                    print("Has fallado, me toca a mi")
                    print(tablero4)  
                    turno_j = 0
                    turno_m = 1

            elif game_style.lower() == "a":
                coord3 = np.random.randint(2,12)
                coord4 = np.random.randint(1,11)
                if "_B_" in tablero3[coord3, coord4]:
                    tablero3[coord3, coord4] = "_X_"
                    tablero4[coord3-1, coord4] = "_X_"
                    clear_output(wait=True)
                    print("Me has dado")    
                    print(tablero3)
                    print(tablero4)   
                    turno_j = 1
                    turno_m = 0
                    n_vidas_maquina-=1
                elif " A " in tablero3[coord3, coord4] or "_X_" in tablero3[coord3, coord4]:
                    turno_j = 1
                    turno_m = 0
                    pass
                else:
                    # tablero3[coord3, coord4] = "_A_"
                    tablero4[coord3-1, coord4] = " A "
                    acierto = 0
                    clear_output(wait=True)
                    print("Has fallado, me toca a mi")
                    print(tablero3)
                    print(tablero4)  
                    turno_j = 0
                    turno_m = 1
        if n_vidas_jugador<= 0:
            ganador_m = 1
            print("He ganado! Maquina")
            
        elif n_vidas_maquina <= 0:
            ganador_j = 1
            print("Has ganado! Jugador")
# Out:
# He fallado en la fila 3, columna 7,ahora te toca a ti
# [['___' '___' '_J_' '_U_' '_G_' '_A_' '_D_' '_O_' '_R_' '___' '___']
#  ['=V=' '_1_' '_2_' '_3_' '_4_' '_5_' '_6_' '_7_' '_8_' '_9_' '_10']
#  ['_1_' ' ~ ' ' ~ ' '_X_' '_X_' '_X_' ' ~ ' ' ~ ' '_B_' ' ~ ' ' ~ ']
#  ['_2_' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ']
#  ['_3_' '_B_' ' ~ ' ' ~ ' ' ~ ' ' ~ ' '_B_' ' ~ ' ' ~ ' ' ~ ' ' ~ ']
#  ['_4_' ' ~ ' ' ~ ' ' ~ ' '_X_' ' ~ ' '_B_' ' ~ ' '_B_' ' ~ ' '_B_']
#  ['_5_' ' ~ ' ' ~ ' ' ~ ' '_X_' ' ~ ' ' ~ ' ' ~ ' '_B_' ' ~ ' '_B_']
#  ['_6_' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' '_B_']
#  ['_7_' ' ~ ' '_B_' '_B_' '_B_' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' '_B_']
#  ['_8_' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' '_B_' ' ~ ' ' ~ ' ' ~ ']
#  ['_9_' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' '_B_']
#  ['_10' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ']]
# [['=V=' '_1_' '_2_' '_3_' '_4_' '_5_' '_6_' '_7_' '_8_' '_9_' '_10']
#  ['_1_' ' A ' ' ~ ' '_X_' '_X_' '_X_' ' A ' ' ~ ' ' ~ ' ' ~ ' ' ~ ']
#  ['_2_' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ']
#  ['_3_' ' ~ ' ' ~ ' ' ~ ' ' A ' ' ~ ' ' ~ ' ' A ' ' ~ ' ' ~ ' ' ~ ']
#  ['_4_' ' ~ ' ' ~ ' ' ~ ' '_X_' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ']
#  ['_5_' ' ~ ' ' ~ ' ' A ' '_X_' ' A ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ']
#  ['_6_' ' ~ ' ' ~ ' ' ~ ' ' A ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ']
#  ['_7_' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' A ' ' ~ ']
#  ['_8_' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' A ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' A ']
#  ['_9_' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ']
#  ['_10' ' ~ ' ' ~ ' ' A ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ']]
