# %%
import numpy as np

# %%
np.

# %%
tablero1 = np.full((12,11),"___")# pruebas de disparo inteligente. Depuración del fallo
tablero2 = np.full((11,11),"___")
tablero3 = np.full((12,11),"___")
tablero4 = np.full((11,11),"___")
marco = ["_0_","_1_","_2_","_3_","_4_","_5_","_6_","_7_","_8_","_9_","_10"]
jugador1 = ["___","___","_J_","_U_","_G_","_A_","_D_","_O_","_R_","___","___"]
jugador2 = ["___","___","_M_","_A_","_Q_","_U_","_I_","_N_","_A_","___","___"]
tablero1[1:,:1] = np.reshape(marco,(11,1))
tablero1[1:2,:] = np.reshape(marco,(1,11))
tablero1[:1,:] = np.reshape(jugador1,(1,11))
tablero2[0:,:1] = np.reshape(marco,(11,1))
tablero2[:1,:] = np.reshape(marco,(1,11))
tablero3[1:,:1] = np.reshape(marco,(11,1))
tablero3[1:2,:] = np.reshape(marco,(1,11))
tablero3[:1,:] = np.reshape(jugador2,(1,11))
tablero4[0:,:1] = np.reshape(marco,(11,1))
tablero4[:1,:] = np.reshape(marco,(1,11))

turno_j = 1 # el comienzo de los turnos también debería ser aleatorio. habría que inicilializar los valores en 0, y mediante función aleatoria, poner un 1 en el que correspoda
turno_m = 1
flota = [1,1,1,1,2,2,2,3,3,4]
n_barcos = len(flota)
portaaviones = flota.count(4)
acorazado = flota.count(3)
buque = flota.count(2)
fragata = flota.count(1)
n_portaaviones = 0
n_acorazado = 0
n_buque = 0
n_fragata = 0



while n_portaaviones < portaaviones:
    if np.random.randint(0,2,1):
        orientacion = "horizontal"
        coord1 = np.random.randint(2,11)
        coord2 = np.random.randint(2,11-4+1)
    
        if "_B_" in tablero1[coord1-1:coord1+2, coord2-1:coord2+5]:
            #tablero1[coord1, coord2:coord2+size] = "C"
            pass
        else: 
            tablero1[coord1, coord2:coord2+4] = "_B_"
            n_portaaviones += 1
            #print(elemento)
    else:
        orientacion = "vertical"

        coord1 = np.random.randint(2,11-4+1)
        coord2 = np.random.randint(2,11)
    
        if "_B_" in tablero1[coord1-1:coord1+5, coord2-1:coord2+2]:
            #tablero1[coord1, coord2:coord2+size] = "C"
            pass
        else: 
            tablero1[coord1:coord1+4, coord2] = "_B_"
            n_portaaviones += 1
                #print(elemento)
while n_acorazado < acorazado:
    if np.random.randint(0,2,1):
        orientacion = "horizontal"
        coord1 = np.random.randint(2,11)
        coord2 = np.random.randint(2,11-3+1)
    
        if "_B_" in tablero1[coord1-1:coord1+2, coord2-1:coord2+4]:
            #tablero1[coord1, coord2:coord2+size] = "C"
            pass
        else: 
            tablero1[coord1, coord2:coord2+3] = "_B_"
            n_acorazado += 1
            #print(elemento)
    else:
        orientacion = "vertical"

        coord1 = np.random.randint(2,11-3+1)
        coord2 = np.random.randint(2,11)
    
        if "_B_" in tablero1[coord1-1:coord1+4, coord2-1:coord2+2]:
            #tablero1[coord1, coord2:coord2+size] = "C"
            pass
        else: 
            tablero1[coord1:coord1+3, coord2] = "_B_"
            n_acorazado += 1
                #print(elemento)
while n_buque < buque:
    if np.random.randint(0,2,1):
        orientacion = "horizontal"
        coord1 = np.random.randint(2,11)
        coord2 = np.random.randint(2,11-2+1)
    
        if "_B_" in tablero1[coord1-1:coord1+2, coord2-1:coord2+3]:
            #tablero1[coord1, coord2:coord2+size] = "C"
            pass
        else: 
            tablero1[coord1, coord2:coord2+2] = "_B_"
            n_buque += 1
            #print(elemento)
    else:
        orientacion = "vertical"

        coord1 = np.random.randint(2,11-2+1)
        coord2 = np.random.randint(2,11)
    
        if "_B_" in tablero1[coord1-1:coord1+3, coord2-1:coord2+2]:
            #tablero1[coord1, coord2:coord2+size] = "C"
            pass
        else: 
            tablero1[coord1:coord1+2, coord2] = "_B_"
            n_buque += 1
                #print(elemento)
while n_fragata < fragata:
    if np.random.randint(0,2,1):
        orientacion = "horizontal"
        coord1 = np.random.randint(2,11)
        coord2 = np.random.randint(2,11)
    
        if "_B_" in tablero1[coord1-1:coord1+2, coord2-1:coord2+2]:
            #tablero1[coord1, coord2:coord2+size] = "C"
            pass
        else: 
            tablero1[coord1, coord2:coord2+1] = "_B_"
            n_fragata += 1
            #print(elemento)
    else:
        orientacion = "vertical"

        coord1 = np.random.randint(2,11)
        coord2 = np.random.randint(2,11)
    
        if "_B_" in tablero1[coord1-1:coord1+2, coord2-1:coord2+2]:
            #tablero1[coord1, coord2:coord2+size] = "C"
            pass
        else: 
            tablero1[coord1:coord1+1, coord2] = "_B_"
            n_fragata += 1
                #print(elemento)  
print(tablero1)
print(tablero2)

# %%
"""Importación de librerias"""
import numpy as np
import time
import os
from IPython.display import clear_output
"""Importación de librerias"""

"""Definición del tablero"""
tablero1 = np.full((12,11),"___")# pruebas de disparo inteligente. Depuración del fallo
tablero2 = np.full((11,11),"___")
tablero3 = np.full((12,11),"___")
tablero4 = np.full((11,11),"___")
marco = ["_0_","_1_","_2_","_3_","_4_","_5_","_6_","_7_","_8_","_9_","_10"]
jugador1 = ["___","___","_J_","_U_","_G_","_A_","_D_","_O_","_R_","___","___"]
jugador2 = ["___","___","_M_","_A_","_Q_","_U_","_I_","_N_","_A_","___","___"]
tablero1[1:,:1] = np.reshape(marco,(11,1))
tablero1[1:2,:] = np.reshape(marco,(1,11))
tablero1[:1,:] = np.reshape(jugador1,(1,11))
tablero2[0:,:1] = np.reshape(marco,(11,1))
tablero2[:1,:] = np.reshape(marco,(1,11))
tablero3[1:,:1] = np.reshape(marco,(11,1))
tablero3[1:2,:] = np.reshape(marco,(1,11))
tablero3[:1,:] = np.reshape(jugador2,(1,11))
tablero4[0:,:1] = np.reshape(marco,(11,1))
tablero4[:1,:] = np.reshape(marco,(1,11))
"""Definición del tablero"""

""" Definición de variables"""
turno_j = 0 # el comienzo de los turnos también debería ser aleatorio. habría que inicilializar los valores en 0, y mediante función aleatoria, poner un 1 en el que correspoda
turno_m = 1
flota_j = [1,1,1,1,2,2,2,3,3,4]
flota_m = [1,1,1,1,2,2,2,3,3,4]
n_barcos_j = len(flota_j)
portaaviones_j = flota_j.count(4)
acorazado_j = flota_j.count(3)
buque_j = flota_j.count(2)
fragata_j = flota_j.count(1)
n_barcos_m = len(flota_m)
portaaviones_m = flota_m.count(4)
acorazado_m = flota_m.count(3)
buque_m = flota_m.count(2)
fragata_m = flota_m.count(1)
n_portaaviones_j = 0
n_acorazado_j = 0
n_buque_j = 0
n_fragata_j = 0
n_barcos_j_ok = n_portaaviones_j +n_acorazado_j + n_buque_j +n_fragata_j
n_portaaviones_m = 0
n_acorazado_m = 0
n_buque_m = 0
n_fragata_m = 0
n_barcos_m_ok = n_portaaviones_m +n_acorazado_m + n_buque_m +n_fragata_m
"""Definición de variables"""
while n_portaaviones_j < portaaviones_j:
    if np.random.randint(0,2,1):
        orientacion = "horizontal"
        coord1 = np.random.randint(2,11)
        coord2 = np.random.randint(2,11-4+1)
    
        if "_B_" in tablero1[coord1-1:coord1+2, coord2-1:coord2+5]:
            #tablero1[coord1, coord2:coord2+size] = "C"
            pass
        else: 
            tablero1[coord1, coord2:coord2+4] = "_B_"
            n_portaaviones_j += 1
            #print(elemento)
    else:
        orientacion = "vertical"

        coord1 = np.random.randint(2,11-4+1)
        coord2 = np.random.randint(2,11)
    
        if "_B_" in tablero1[coord1-1:coord1+5, coord2-1:coord2+2]:
            #tablero1[coord1, coord2:coord2+size] = "C"
            pass
        else: 
            tablero1[coord1:coord1+4, coord2] = "_B_"
            n_portaaviones_j += 1
                #print(elemento)
while n_acorazado_j < acorazado_j:
    if np.random.randint(0,2,1):
        orientacion = "horizontal"
        coord1 = np.random.randint(2,11)
        coord2 = np.random.randint(2,11-3+1)
    
        if "_B_" in tablero1[coord1-1:coord1+2, coord2-1:coord2+4]:
            #tablero1[coord1, coord2:coord2+size] = "C"
            pass
        else: 
            tablero1[coord1, coord2:coord2+3] = "_B_"
            n_acorazado_j += 1
            #print(elemento)
    else:
        orientacion = "vertical"

        coord1 = np.random.randint(2,11-3+1)
        coord2 = np.random.randint(2,11)
    
        if "_B_" in tablero1[coord1-1:coord1+4, coord2-1:coord2+2]:
            #tablero1[coord1, coord2:coord2+size] = "C"
            pass
        else: 
            tablero1[coord1:coord1+3, coord2] = "_B_"
            n_acorazado_j += 1
                #print(elemento)
while n_buque_j < buque_j:
    if np.random.randint(0,2,1):
        orientacion = "horizontal"
        coord1 = np.random.randint(2,11)
        coord2 = np.random.randint(2,11-2+1)
    
        if "_B_" in tablero1[coord1-1:coord1+2, coord2-1:coord2+3]:
            #tablero1[coord1, coord2:coord2+size] = "C"
            pass
        else: 
            tablero1[coord1, coord2:coord2+2] = "_B_"
            n_buque_j += 1
            #print(elemento)
    else:
        orientacion = "vertical"

        coord1 = np.random.randint(2,11-2+1)
        coord2 = np.random.randint(2,11)
    
        if "_B_" in tablero1[coord1-1:coord1+3, coord2-1:coord2+2]:
            #tablero1[coord1, coord2:coord2+size] = "C"
            pass
        else: 
            tablero1[coord1:coord1+2, coord2] = "_B_"
            n_buque_j += 1
                #print(elemento)
while n_fragata_j < fragata_j:
    if np.random.randint(0,2,1):
        orientacion = "horizontal"
        coord1 = np.random.randint(2,11)
        coord2 = np.random.randint(2,11)
    
        if "_B_" in tablero1[coord1-1:coord1+2, coord2-1:coord2+2]:
            #tablero1[coord1, coord2:coord2+size] = "C"
            pass
        else: 
            tablero1[coord1, coord2:coord2+1] = "_B_"
            n_fragata_j += 1
            #print(elemento)
    else:
        orientacion = "vertical"

        coord1 = np.random.randint(2,11)
        coord2 = np.random.randint(2,11)
    
        if "_B_" in tablero1[coord1-1:coord1+2, coord2-1:coord2+2]:
            #tablero1[coord1, coord2:coord2+size] = "C"
            pass
        else: 
            tablero1[coord1:coord1+1, coord2] = "_B_"
            n_fragata_j += 1
                #print(elemento)  

while n_portaaviones_m < portaaviones_m:
    if np.random.randint(0,2,1):
        orientacion = "horizontal"
        coord3 = np.random.randint(2,11)
        coord4 = np.random.randint(2,11-4+1)
    
        if "_B_" in tablero3[coord3-1:coord3+2, coord4-1:coord4+5]:
            #tablero1[coord3, coord4:coord4+size] = "C"
            pass
        else: 
            tablero3[coord3, coord4:coord4+4] = "_B_"
            n_portaaviones_m += 1
            #print(elemento)
    else:
        orientacion = "vertical"

        coord3 = np.random.randint(2,11-4+1)
        coord4 = np.random.randint(2,11)
    
        if "_B_" in tablero3[coord3-1:coord3+5, coord4-1:coord4+2]:
            #tablero1[coord3, coord4:coord4+size] = "C"
            pass
        else: 
            tablero3[coord3:coord3+4, coord4] = "_B_"
            n_portaaviones_m += 1
                #print(elemento)
while n_acorazado_m < acorazado_m:
    if np.random.randint(0,2,1):
        orientacion = "horizontal"
        coord3 = np.random.randint(2,11)
        coord4 = np.random.randint(2,11-3+1)
    
        if "_B_" in tablero3[coord3-1:coord3+2, coord4-1:coord4+4]:
            #tablero1[coord3, coord4:coord4+size] = "C"
            pass
        else: 
            tablero3[coord3, coord4:coord4+3] = "_B_"
            n_acorazado_m += 1
            #print(elemento)
    else:
        orientacion = "vertical"

        coord3 = np.random.randint(2,11-3+1)
        coord4 = np.random.randint(2,11)
    
        if "_B_" in tablero3[coord3-1:coord3+4, coord4-1:coord4+2]:
            #tablero1[coord3, coord4:coord4+size] = "C"
            pass
        else: 
            tablero3[coord3:coord3+3, coord4] = "_B_"
            n_acorazado_m += 1
                #print(elemento)
while n_buque_m < buque_m:
    if np.random.randint(0,2,1):
        orientacion = "horizontal"
        coord3 = np.random.randint(2,11)
        coord4 = np.random.randint(2,11-2+1)
    
        if "_B_" in tablero3[coord3-1:coord3+2, coord4-1:coord4+3]:
            #tablero1[coord3, coord4:coord4+size] = "C"
            pass
        else: 
            tablero3[coord3, coord4:coord4+2] = "_B_"
            n_buque_m += 1
            #print(elemento)
    else:
        orientacion = "vertical"

        coord3 = np.random.randint(2,11-2+1)
        coord4 = np.random.randint(2,11)
    
        if "_B_" in tablero3[coord3-1:coord3+3, coord4-1:coord4+2]:
            #tablero1[coord3, coord4:coord4+size] = "C"
            pass
        else: 
            tablero3[coord3:coord3+2, coord4] = "_B_"
            n_buque_m += 1
                #print(elemento)
while n_fragata_m < fragata_m:
    if np.random.randint(0,2,1):
        orientacion = "horizontal"
        coord3 = np.random.randint(2,11)
        coord4 = np.random.randint(2,11)
    
        if "_B_" in tablero3[coord3-1:coord3+2, coord4-1:coord4+2]:
            #tablero1[coord3, coord4:coord4+size] = "C"
            pass
        else: 
            tablero3[coord3, coord4:coord4+1] = "_B_"
            n_fragata_m += 1
            #print(elemento)
    else:
        orientacion = "vertical"

        coord3 = np.random.randint(2,11)
        coord4 = np.random.randint(2,11)
    
        if "_B_" in tablero3[coord3-1:coord3+2, coord4-1:coord4+2]:
            #tablero1[coord3, coord4:coord4+size] = "C"
            pass
        else: 
            tablero3[coord3:coord3+1, coord4] = "_B_"
            n_fragata_m += 1
                #print(elemento)  
# print(tablero1)
# print(tablero2)
# clear_output(wait=True)
# time.sleep(1)
print(tablero1)
print(tablero2)
# clear_output(wait=True)
# time.sleep(1)
# print("tamos ready")

# %%
""" DISEÑO DE LA FUNCIÓN PARA POSICIONADO DE BARCOS"""
"""Importación de librerias"""
import numpy as np
import time
import os
from IPython.display import clear_output
"""Importación de librerias"""

"""Definición del tablero"""
tablero1 = np.full((12,11),"___")# pruebas de disparo inteligente. Depuración del fallo
tablero2 = np.full((11,11),"___")
tablero3 = np.full((12,11),"___")
tablero4 = np.full((11,11),"___")
marco = ["_0_","_1_","_2_","_3_","_4_","_5_","_6_","_7_","_8_","_9_","_10"]
jugador1 = ["___","___","_J_","_U_","_G_","_A_","_D_","_O_","_R_","___","___"]
jugador2 = ["___","___","_M_","_A_","_Q_","_U_","_I_","_N_","_A_","___","___"]
tablero1[1:,:1] = np.reshape(marco,(11,1))
tablero1[1:2,:] = np.reshape(marco,(1,11))
tablero1[:1,:] = np.reshape(jugador1,(1,11))
tablero2[0:,:1] = np.reshape(marco,(11,1))
tablero2[:1,:] = np.reshape(marco,(1,11))
tablero3[1:,:1] = np.reshape(marco,(11,1))
tablero3[1:2,:] = np.reshape(marco,(1,11))
tablero3[:1,:] = np.reshape(jugador2,(1,11))
tablero4[0:,:1] = np.reshape(marco,(11,1))
tablero4[:1,:] = np.reshape(marco,(1,11))
"""Definición del tablero"""

""" Definición de variables"""
turno_j = 0 # el comienzo de los turnos también debería ser aleatorio. habría que inicilializar los valores en 0, y mediante función aleatoria, poner un 1 en el que correspoda
turno_m = 1
flota_j = [1,1,1,1,2,2,2,3,3,4]
flota_m = [1,1,1,1,2,2,2,3,3,4]
n_barcos_j = len(flota_j)
portaaviones_j = flota_j.count(4)
acorazado_j = flota_j.count(3)
buque_j = flota_j.count(2)
fragata_j = flota_j.count(1)
n_barcos_m = len(flota_m)
portaaviones_m = flota_m.count(4)
acorazado_m = flota_m.count(3)
buque_m = flota_m.count(2)
fragata_m = flota_m.count(1)
n_portaaviones_j = 0
n_acorazado_j = 0
n_buque_j = 0
n_fragata_j = 0
n_barcos_j_ok = n_portaaviones_j +n_acorazado_j + n_buque_j +n_fragata_j
n_portaaviones_m = 0
n_acorazado_m = 0
n_buque_m = 0
n_fragata_m = 0
n_barcos_m_ok = n_portaaviones_m +n_acorazado_m + n_buque_m +n_fragata_m
"""Definición de variables"""

a = 1
while a == 1:
    for elemento in flota_j:
        if np.random.randint(0,2,1):
            orientacion = "horizontal"
            coord1 = np.random.randint(2,11)
            coord2 = np.random.randint(1,11-elemento+1)
            if "_B_" in tablero1[coord1-1:coord1+2, coord2-1:coord2+elemento+1]:
                #tablero1[coord1, coord2:coord2+size] = "C"
                pass
            else: 
                tablero1[coord1, coord2:coord2+elemento] = "_B_"
                #n_portaaviones_j += 1
                #print(elemento)
        else:
            orientacion = "vertical"

            coord1 = np.random.randint(2,11-4+1)
            coord2 = np.random.randint(1,11)
        
            if "_B_" in tablero1[coord1-1:coord1+elemento+1, coord2-1:coord2+2]:
                #tablero1[coord1, coord2:coord2+size] = "C"
                pass
            else: 
                tablero1[coord1:coord1+elemento, coord2] = "_B_"
                #n_portaaviones_j += 1

while n_portaaviones_j < portaaviones_j:
    if np.random.randint(0,2,1):
        orientacion = "horizontal"
        coord1 = np.random.randint(2,11)
        coord2 = np.random.randint(2,11-4+1)
    
        if "_B_" in tablero1[coord1-1:coord1+2, coord2-1:coord2+5]:
            #tablero1[coord1, coord2:coord2+size] = "C"
            pass
        else: 
            tablero1[coord1, coord2:coord2+4] = "_B_"
            n_portaaviones_j += 1
            #print(elemento)
    else:
        orientacion = "vertical"

        coord1 = np.random.randint(2,11-4+1)
        coord2 = np.random.randint(2,11)
    
        if "_B_" in tablero1[coord1-1:coord1+5, coord2-1:coord2+2]:
            #tablero1[coord1, coord2:coord2+size] = "C"
            pass
        else: 
            tablero1[coord1:coord1+4, coord2] = "_B_"
            n_portaaviones_j += 1
                #print(elemento)
while n_acorazado_j < acorazado_j:
    if np.random.randint(0,2,1):
        orientacion = "horizontal"
        coord1 = np.random.randint(2,11)
        coord2 = np.random.randint(2,11-3+1)
    
        if "_B_" in tablero1[coord1-1:coord1+2, coord2-1:coord2+4]:
            #tablero1[coord1, coord2:coord2+size] = "C"
            pass
        else: 
            tablero1[coord1, coord2:coord2+3] = "_B_"
            n_acorazado_j += 1
            #print(elemento)
    else:
        orientacion = "vertical"

        coord1 = np.random.randint(2,11-3+1)
        coord2 = np.random.randint(2,11)
    
        if "_B_" in tablero1[coord1-1:coord1+4, coord2-1:coord2+2]:
            #tablero1[coord1, coord2:coord2+size] = "C"
            pass
        else: 
            tablero1[coord1:coord1+3, coord2] = "_B_"
            n_acorazado_j += 1
                #print(elemento)
while n_buque_j < buque_j:
    if np.random.randint(0,2,1):
        orientacion = "horizontal"
        coord1 = np.random.randint(2,11)
        coord2 = np.random.randint(2,11-2+1)
    
        if "_B_" in tablero1[coord1-1:coord1+2, coord2-1:coord2+3]:
            #tablero1[coord1, coord2:coord2+size] = "C"
            pass
        else: 
            tablero1[coord1, coord2:coord2+2] = "_B_"
            n_buque_j += 1
            #print(elemento)
    else:
        orientacion = "vertical"

        coord1 = np.random.randint(2,11-2+1)
        coord2 = np.random.randint(2,11)
    
        if "_B_" in tablero1[coord1-1:coord1+3, coord2-1:coord2+2]:
            #tablero1[coord1, coord2:coord2+size] = "C"
            pass
        else: 
            tablero1[coord1:coord1+2, coord2] = "_B_"
            n_buque_j += 1
                #print(elemento)
while n_fragata_j < fragata_j:
    if np.random.randint(0,2,1):
        orientacion = "horizontal"
        coord1 = np.random.randint(2,11)
        coord2 = np.random.randint(2,11)
    
        if "_B_" in tablero1[coord1-1:coord1+2, coord2-1:coord2+2]:
            #tablero1[coord1, coord2:coord2+size] = "C"
            pass
        else: 
            tablero1[coord1, coord2:coord2+1] = "_B_"
            n_fragata_j += 1
            #print(elemento)
    else:
        orientacion = "vertical"

        coord1 = np.random.randint(2,11)
        coord2 = np.random.randint(2,11)
    
        if "_B_" in tablero1[coord1-1:coord1+2, coord2-1:coord2+2]:
            #tablero1[coord1, coord2:coord2+size] = "C"
            pass
        else: 
            tablero1[coord1:coord1+1, coord2] = "_B_"
            n_fragata_j += 1
                #print(elemento)  

while n_portaaviones_m < portaaviones_m:
    if np.random.randint(0,2,1):
        orientacion = "horizontal"
        coord3 = np.random.randint(2,11)
        coord4 = np.random.randint(2,11-4+1)
    
        if "_B_" in tablero3[coord3-1:coord3+2, coord4-1:coord4+5]:
            #tablero1[coord3, coord4:coord4+size] = "C"
            pass
        else: 
            tablero3[coord3, coord4:coord4+4] = "_B_"
            n_portaaviones_m += 1
            #print(elemento)
    else:
        orientacion = "vertical"

        coord3 = np.random.randint(2,11-4+1)
        coord4 = np.random.randint(2,11)
    
        if "_B_" in tablero3[coord3-1:coord3+5, coord4-1:coord4+2]:
            #tablero1[coord3, coord4:coord4+size] = "C"
            pass
        else: 
            tablero3[coord3:coord3+4, coord4] = "_B_"
            n_portaaviones_m += 1
                #print(elemento)
while n_acorazado_m < acorazado_m:
    if np.random.randint(0,2,1):
        orientacion = "horizontal"
        coord3 = np.random.randint(2,11)
        coord4 = np.random.randint(2,11-3+1)
    
        if "_B_" in tablero3[coord3-1:coord3+2, coord4-1:coord4+4]:
            #tablero1[coord3, coord4:coord4+size] = "C"
            pass
        else: 
            tablero3[coord3, coord4:coord4+3] = "_B_"
            n_acorazado_m += 1
            #print(elemento)
    else:
        orientacion = "vertical"

        coord3 = np.random.randint(2,11-3+1)
        coord4 = np.random.randint(2,11)
    
        if "_B_" in tablero3[coord3-1:coord3+4, coord4-1:coord4+2]:
            #tablero1[coord3, coord4:coord4+size] = "C"
            pass
        else: 
            tablero3[coord3:coord3+3, coord4] = "_B_"
            n_acorazado_m += 1
                #print(elemento)
while n_buque_m < buque_m:
    if np.random.randint(0,2,1):
        orientacion = "horizontal"
        coord3 = np.random.randint(2,11)
        coord4 = np.random.randint(2,11-2+1)
    
        if "_B_" in tablero3[coord3-1:coord3+2, coord4-1:coord4+3]:
            #tablero1[coord3, coord4:coord4+size] = "C"
            pass
        else: 
            tablero3[coord3, coord4:coord4+2] = "_B_"
            n_buque_m += 1
            #print(elemento)
    else:
        orientacion = "vertical"

        coord3 = np.random.randint(2,11-2+1)
        coord4 = np.random.randint(2,11)
    
        if "_B_" in tablero3[coord3-1:coord3+3, coord4-1:coord4+2]:
            #tablero1[coord3, coord4:coord4+size] = "C"
            pass
        else: 
            tablero3[coord3:coord3+2, coord4] = "_B_"
            n_buque_m += 1
                #print(elemento)
while n_fragata_m < fragata_m:
    if np.random.randint(0,2,1):
        orientacion = "horizontal"
        coord3 = np.random.randint(2,11)
        coord4 = np.random.randint(2,11)
    
        if "_B_" in tablero3[coord3-1:coord3+2, coord4-1:coord4+2]:
            #tablero1[coord3, coord4:coord4+size] = "C"
            pass
        else: 
            tablero3[coord3, coord4:coord4+1] = "_B_"
            n_fragata_m += 1
            #print(elemento)
    else:
        orientacion = "vertical"

        coord3 = np.random.randint(2,11)
        coord4 = np.random.randint(2,11)
    
        if "_B_" in tablero3[coord3-1:coord3+2, coord4-1:coord4+2]:
            #tablero1[coord3, coord4:coord4+size] = "C"
            pass
        else: 
            tablero3[coord3:coord3+1, coord4] = "_B_"
            n_fragata_m += 1
                #print(elemento)  
flota_j_1 =[]
# len(flota_j_1) <= 10:
#     for indice, elemento in enumerate(flota_j):
while len(flota_j_1) <= 10:
    for indice, elemento in enumerate(flota_j):
        # if np.random.randint(0,2,1) == 1:
        #     orientacion = "horizontal"
            coord1 = np.random.randint(2,11)
            coord2 = np.random.randint(1,11-elemento+1)
            if "_B_" in tablero1[coord1-1:coord1+2, coord2-1:coord2+elemento+1]:
                #tablero1[coord1, coord2:coord2+size] = "C"
                pass
                
            else: 
                tablero1[coord1, coord2:coord2+elemento] = "_B_"
                flota_j_1.append(elemento)
                #n_portaaviones_j += 1
                #print(elemento)
        # else:
        #     orientacion = "vertical"

        #     coord1 = np.random.randint(2,11-4+1)
        #     coord2 = np.random.randint(1,11)
        
        #     if "_B_" in tablero1[coord1-1:coord1+elemento+1, coord2-1:coord2+2]:
        #         #tablero1[coord1, coord2:coord2+size] = "C"
        #         pass
        #     else: 
        #         tablero1[coord1:coord1+elemento, coord2] = "_B_"
                #n_portaaviones_j += 1


# print(tablero1)
# print(tablero2)
# clear_output(wait=True)
# time.sleep(1)
print(flota_j_1)
print(tablero1)
print(tablero2)
# clear_output(wait=True)
# time.sleep(1)
# print("tamos ready")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 59
#      57 while a == 1:
#      58     for elemento in flota_j:
# ---> 59         if np.random.randint(0,2,1):
#      60             orientacion = "horizontal"
#      61             coord1 = np.random.randint(2,11)
#
# KeyboardInterrupt:

# %%
# Out:
#   Cell In[11], line 6
#     print( <b> tablero5[2,2] </b> )
#            ^
# SyntaxError: invalid syntax
