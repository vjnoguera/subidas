# %% [markdown]
# Nos falta incluir las coordenadas en los prints que hacemos, para que sea mas fácil seguir el juego.
# Hay que evitar que se repitan coordenadas de disparo

# %%
"""Importación de librerias"""# disparo inteligente, conseguimos que funcione!!!
import numpy as np
import time
import os
from IPython.display import clear_output
"""Importación de librerias"""
tablero1 = np.full((11,11),"___")# pruebas de disparo inteligente. Ya hacemos búsqueda aleatoria de mas X, pero el aviso de hundimiento de barco lo hacemos mal, solo sale con el segundo disparo, y en caso de fallar, con lo que hay que ver la forma de hacerlo antes.
tablero2 = np.full((11,11),"___")
tablero3 = np.full((11,11),"___")
tablero4 = np.full((11,11),"___")
marco = ["_0_","_1_","_2_","_3_","_4_","_5_","_6_","_7_","_8_","_9_","_10"]
tablero1[0:,:1] = np.reshape(marco,(11,1))
tablero1[:1,:] = np.reshape(marco,(1,11))
tablero2[0:,:1] = np.reshape(marco,(11,1))
tablero2[:1,:] = np.reshape(marco,(1,11))
tablero3[0:,:1] = np.reshape(marco,(11,1))
tablero3[:1,:] = np.reshape(marco,(1,11))
tablero4[0:,:1] = np.reshape(marco,(11,1))
tablero4[:1,:] = np.reshape(marco,(1,11))
turno_j = 1 # el comienzo de los turnos también debería ser aleatorio. habría que inicilializar los valores en 0, y mediante función aleatoria, poner un 1 en el que correspoda
turno_m = 1
focus = 0
right = 0
left = 0
up = 0
down = 0
ganador_j = 0
ganador_m = 0
n_vidas_jugador = 3
n_vidas_maquina = 3
disp_int = []
n_barcos = 10
a = 1
b = 0
aciertos = 0 # esto hay que convertirlo en una lista con [fragata,buque,acorazado,portaaviones], de forma que en función del número de aciertos acumulados, sepamos que tipo de barco hemos hundido

while (ganador_m == 0) and (ganador_j == 0):
    enter = input("Presiona enter para continuar")  
    if enter == "":
        if a == 1 and focus == 0 and up == 0 and down == 0 and right == 0 and left == 0:
            coord1 = np.random.randint(1,11)
            coord2 = np.random.randint(1,11)
            if "_B_" in tablero1[coord1, coord2]:
                tablero1[coord1, coord2] = "_X_"
                tablero2[coord1-1, coord2] = "_X_"
                clear_output(wait=True)
                print("Me has dado!1")
                print(tablero1)
                print(tablero2)  
                a = 1
                b = 0
                n_vidas_maquina-=1
                focus = 1
                if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2]:
                    print("Has hundido mi fragata!")
                    a = 1
                    b = 0
                    focus = 0
                    n_barcos -=1
                else:    
                    enter = input("Presiona enter para continuar") # disparo "inteligente"
                    if enter == "" and focus == 1 and up == 0 and down == 0 and right == 0 and left == 0:# derecha
                        up = 0
                        down = 0
                        right = 1
                        left = 0
                        if focus == 1 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                            tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                            tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                            clear_output(wait=True)
                            print("Me has dado!2")
                            print(tablero1)
                            print(tablero2)  
                            a = 1
                            b = 0
                            n_vidas_maquina-=1
                            focus = 2
                            aciertos = 2
                            if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2+focus]:# ojo, si damos a mitad de un barco grande, entenderemos que hemos hundido un buque, y no es correcto
                                print("Has hundido mi buque!")
                                a = 1
                                b = 0
                                focus = 0
                                aciertos = 0
                                n_barcos -=1
                                up = 0
                                down = 0
                                right = 0
                                left = 0
                            else:    # derecha
                                enter = input("Presiona enter para continuar") 
                                if enter == "" and focus == 2 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                                    tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                    tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                    clear_output(wait=True)
                                    print("Me has dado!3")
                                    print(tablero1)
                                    print(tablero2)  
                                    a = 1
                                    b = 0
                                    n_vidas_maquina-=1
                                    focus = 3
                                    aciertos = 3
                                    if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2+focus]:
                                        print("Has hundido mi acorazado!")
                                        a = 1
                                        b = 0
                                        focus = 0
                                        aciertos = 0
                                        n_barcos -=1
                                        up = 0
                                        down = 0
                                        right = 0
                                        left = 0
                                    else:    # derecha
                                        enter = input("Presiona enter para continuar") 
                                        if enter == "" and focus == 3 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                                            tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                            tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                            clear_output(wait=True)
                                            print("Me has dado!4")
                                            print(tablero1)
                                            print(tablero2)  
                                            a = 1
                                            b = 0
                                            n_vidas_maquina-=1
                                            if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2+focus]:# ojo, si damos a mitad de un barco grande, entenderemos que hemos hundido un buque, y no es correcto
                                                print("Has hundido mi portaaviones!")
                                                a = 1
                                                b = 0
                                                focus = 0
                                                aciertos = 0
                                                n_barcos -=1
                                                up = 0
                                                down = 0
                                                right = 0
                                                left = 0                                                         
                                        elif enter == "" and focus == 3 and "_B_" not in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                                            tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                            tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                            clear_output(wait=True)
                                            a = 0
                                            b = 1
                                            acierto = 0
                                            focus = 1
                                            up = 0
                                            down = 0
                                            right = 0
                                            left = 1
                                            print("Has fallado, ahora me toca a mi4")
                                            print(tablero1)
                                            print(tablero2)  
                                            print(focus)
                                            print(right, left)
                                elif "_A_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                                    a = 1
                                    b = 0
                                    pass
                                else:
                                    tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                    tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                    acierto = 0
                                    clear_output(wait=True)
                                    a = 0
                                    b = 1
                                    acierto = 0
                                    focus = 1
                                    up = 0
                                    down = 0
                                    right = 0
                                    left = 1
                                    print("Has fallado, ahora me toca a mi3")
                                    print(tablero1)
                                    print(tablero2)  
                                    print(focus)
                                    print(right, left)
                                    print (a)
                        elif "_A_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                            a = 1
                            b = 0
                            pass
                        else:
                            tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                            tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                            acierto = 0
                            clear_output(wait=True)
                            a = 0
                            b = 1
                            acierto = 0
                            focus = 1
                            up = 0
                            down = 0
                            right = 0
                            left = 1
                            print("Has fallado, ahora me toca a mi2")
                            print(tablero1)
                            print(tablero2)  
                            print(focus)
                            print(right, left)
            elif "_A_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                a = 1
                b = 0
                pass
            else:
                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                acierto = 0
                clear_output(wait=True)
                a = 0
                b = 1
                acierto = 0
                focus = 1
                up = 0
                down = 0
                right = 0
                left = 1
                print("Has fallado, ahora me toca a mi1")
                print(tablero1)
                print(tablero2)  
                print(focus)
                print(right, left)
        elif a == 1 and focus == 1 and left == 1: # izquierdas
            if "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                #disparo1 = tablero1[coord1, coord2]
                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                clear_output(wait=True)
                print("Me has dado!12")
                print(tablero1)
                print(tablero2)  
                a = 1
                b = 0
                n_vidas_maquina-=1
                focus = 2
                aciertos = 2
                if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2, coord2-1-focus:coord2+2]:# ojo, si damos a mitad de un barco grande, entenderemos que hemos hundido un buque, y no es correcto
                    print("Has hundido mi buque!12")
                    a = 1
                    b = 0
                    focus = 0
                    aciertos = 0
                    n_barcos -=1
                    up = 0
                    down = 0
                    right = 0
                    left = 0
                else:    # izquierda
                    enter = input("Presiona enter para continuar") 
                    if enter == "" and focus == 2 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                        tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                        #disparo1 = tablero1[coord1, coord2]
                        tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                        clear_output(wait=True)
                        print("Me has dado!13")
                        print(tablero1)
                        print(tablero2)  
                        a = 1
                        b = 0
                        n_vidas_maquina-=1
                        focus = 3
                        aciertos = 3
                        if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2, coord2-1-focus:coord2+2]:
                            print("Has hundido mi acorazado!13")
                            a = 1
                            b = 0
                            focus = 0
                            aciertos = 0
                            n_barcos -=1
                            up = 0
                            down = 0
                            right = 0
                            left = 0
                        else:    #izquierda
                            enter = input("Presiona enter para continuar") 
                            if enter == "" and focus == 3 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                clear_output(wait=True)
                                print("Me has dado!14")
                                print(tablero1)
                                print(tablero2)  
                                a = 1
                                b = 0
                                n_vidas_maquina-=1
                                if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2, coord2-1-focus:coord2+2]:# ojo, si damos a mitad de un barco grande, entenderemos que hemos hundido un buque, y no es correcto
                                    print("Has hundido mi portaaviones!14")
                                    a = 1
                                    b = 0
                                    focus = 0
                                    aciertos = 0
                                    n_barcos -=1
                                    up = 0
                                    down = 0
                                    right = 0
                                    left = 0
                                    # ganador_j = 1                                                           
                            elif enter == "" and focus == 3 and "_B_" not in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                acierto = 0
                                focus = 1
                                up = 0
                                down = 0
                                right = 0
                                left = 1
                                clear_output(wait=True)
                                #time.sleep(1)
                                print("Has fallado, ahora me toca a mi14")
                                print(tablero1)
                                print(tablero2)  
                                print(focus)
                                print(right, left)
                                a = 0
                                b = 1
                    elif "_A_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                        a = 1
                        b = 0
                        pass
                    else:
                        tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                        tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                        acierto = 0
                        clear_output(wait=True)
                        #time.sleep(1)
                        a = 0
                        b = 1
                        acierto = 0
                        focus = 1
                        up = 0
                        down = 0
                        right = 0
                        left = 1
                        print("Has fallado, ahora me toca a mi13")
                        print(tablero1)
                        print(tablero2)  
            elif "_A_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                a = 1
                b = 0
                pass
            else:
                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                clear_output(wait=True)
                a = 0
                b = 1
                acierto = 1
                focus = 1
                up = 0
                down = 1
                right = 0
                left = 0
                print("Has fallado, ahora me toca a mi2")
                print(tablero1)
                print(tablero2)  
                print(focus)
                print(right, left, down, up)
                        
        elif a == 1 and focus == 1 and down == 1: # abajo
            if "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                #disparo1 = tablero1[coord1, coord2]
                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                clear_output(wait=True)
                print("Me has dado!abajo1")
                print(tablero1)
                print(tablero2)  
                a = 1
                b = 0
                n_vidas_maquina-=1
                focus = 2
                aciertos = 2
                if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2+focus, coord2-1:coord2+2]:# ojo, si damos a mitad de un barco grande, entenderemos que hemos hundido un buque, y no es correcto
                    print("Has hundido mi buque!abajo")
                    a = 1
                    b = 0
                    focus = 0
                    aciertos = 0
                    n_barcos -=1
                    up = 0
                    down = 0
                    right = 0
                    left = 0
                else:    # abajo
                    enter = input("Presiona enter para continuar") 
                    if enter == "" and focus == 2 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                        tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                        #disparo1 = tablero1[coord1, coord2]
                        tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                        clear_output(wait=True)
                        print("Me has dado!abajo2")
                        print(tablero1)
                        print(tablero2)  
                        a = 1
                        b = 0
                        n_vidas_maquina-=1
                        focus = 3
                        aciertos = 3
                        if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2+focus, coord2-1:coord2+2]:
                            print("Has hundido mi acorazado!abajo")
                            a = 1
                            b = 0
                            focus = 0
                            aciertos = 0
                            n_barcos -=1
                            up = 0
                            down = 0
                            right = 0
                            left = 0
                        else:    #abajo
                            enter = input("Presiona enter para continuar") 
                            if enter == "" and focus == 3 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                #disparo1 = tablero1[coord1, coord2]
                                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                clear_output(wait=True)
                                print("Me has dado!abajo3")
                                print(tablero1)
                                print(tablero2)  
                                a = 1
                                b = 0
                                n_vidas_maquina-=1
                                if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2+focus, coord2-1:coord2+2]:# ojo, si damos a mitad de un barco grande, entenderemos que hemos hundido un buque, y no es correcto
                                    print("Has hundido mi portaaviones!abajo")
                                    a = 1
                                    b = 0
                                    focus = 0
                                    aciertos = 0
                                    n_barcos -=1
                                    up = 0
                                    down = 0
                                    right = 0
                                    left = 0
                                    # ganador_j = 1                                                           
                            elif enter == "" and focus == 3 and "_B_" not in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                acierto = 2
                                focus = 1
                                up = 1
                                down = 0
                                right = 0
                                left = 0
                                clear_output(wait=True)
                                #time.sleep(1)
                                print("Has fallado, ahora me toca a mi!abajo3")
                                print(tablero1)
                                print(tablero2)  
                                print(focus)
                                print(right, left)
                                a = 0
                                b = 1
                    elif "_A_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                        a = 1
                        b = 0
                        pass
                    else:
                        tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                        tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                        acierto = 1
                        clear_output(wait=True)
                        #time.sleep(1)
                        a = 0
                        b = 1
                        acierto = 0
                        focus = 1
                        up = 1
                        down = 0
                        right = 0
                        left = 0
                        print("Has fallado, ahora me toca a mi!abajo2")
                        print(tablero1)
                        print(tablero2) 
                        
            elif "_A_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                a = 1
                b = 0
                pass
            else:
                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                acierto = 0
                focus = 1
                up = 1
                down = 0
                right = 0
                left = 0
                clear_output(wait=True)
                #time.sleep(1)
                print("Has fallado, ahora me toca a miabajo1")
                print(tablero1)
                print(tablero2) 
                print(coord1)
                print(coord2)
                print 
                a = 0
                b = 1
        elif a == 1 and focus == 1 and up == 1: # arriba
            if "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                #disparo1 = tablero1[coord1, coord2]
                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                clear_output(wait=True)
                print("Me has dado!arriba1")
                print(tablero1)
                print(tablero2)  
                a = 1
                b = 0
                n_vidas_maquina-=1
                focus = 2
                aciertos = 2
                if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1-focus:coord1+2, coord2-1:coord2+2]:# ojo, si damos a mitad de un barco grande, entenderemos que hemos hundido un buque, y no es correcto
                    print("Has hundido mi buque!arriba")
                    a = 1
                    b = 0
                    focus = 0
                    aciertos = 0
                    n_barcos -=1
                    up = 0
                    down = 0
                    right = 0
                    left = 0
                else:    # abajo
                    enter = input("Presiona enter para continuar") 
                    if enter == "" and focus == 2 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                        tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                        #disparo1 = tablero1[coord1, coord2]
                        tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                        clear_output(wait=True)
                        print("Me has dado!arriba2")
                        print(tablero1)
                        print(tablero2)  
                        a = 1
                        b = 0
                        n_vidas_maquina-=1
                        focus = 3
                        aciertos = 3
                        if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1-focus:coord1+2, coord2-1:coord2+2]:
                            print("Has hundido mi acorazado!arriba")
                            a = 1
                            b = 0
                            focus = 0
                            aciertos = 0
                            n_barcos -=1
                            up = 0
                            down = 0
                            right = 0
                            left = 0
                        else:    #abajo
                            enter = input("Presiona enter para continuar") 
                            if enter == "" and focus == 3 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                #disparo1 = tablero1[coord1, coord2]
                                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                clear_output(wait=True)
                                print("Me has dado!arriba3")
                                print(tablero1)
                                print(tablero2)  
                                a = 1
                                b = 0
                                n_vidas_maquina-=1
                                aciertos = 4 
                                if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1-focus:coord1+2, coord2-1:coord2+2]:# ojo, si damos a mitad de un barco grande, entenderemos que hemos hundido un buque, y no es correcto
                                    print("Has hundido mi portaaviones!arriba")
                                    a = 1
                                    b = 0
                                    focus = 0
                                    aciertos = 0
                                    n_barcos -=1
                                    up = 0
                                    down = 0
                                    right = 0
                                    left = 0
                                    # ganador_j = 1                                                           
                            elif enter == "" and focus == 3 and "_B_" not in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                acierto = 2
                                focus = 1
                                # up = 0
                                # down = 0
                                # right = 0
                                # left = 0
                                clear_output(wait=True)
                                #time.sleep(1)
                                print("Has fallado, ahora me toca a mi!arriba3")
                                print(tablero1)
                                print(tablero2)  
                                print(focus)
                                print(right, left)
                                a = 0
                                b = 1
                    elif "_A_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                        a = 1
                        b = 0
                        pass
                    else:
                        tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                        tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                        acierto = 1
                        clear_output(wait=True)
                        #time.sleep(1)
                        a = 0
                        b = 1
                        acierto = 0
                        focus = 1
                        # up = 1
                        # down = 0
                        # right = 0
                        # left = 0
                        print("Has fallado, ahora me toca a mi!arriba2")
                        print(tablero1)
                        print(tablero2) 
                        
            elif "_A_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                a = 1
                b = 0
                pass
            else:
                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                acierto = 0
                focus = 1
                # up = 1
                # down = 0
                # right = 0
                # left = 0
                clear_output(wait=True)
                #time.sleep(1)
                print("Has fallado, ahora me toca a mi! arriba1")
                print(tablero1)
                print(tablero2) 
                print(coord1)
                print(coord2)
                print 
                a = 0
                b = 1
                
             
        elif b == 1:
            coord3 = np.random.randint(1,11)
            coord4 = np.random.randint(1,11)
            if "_B_" in tablero3[coord3, coord4]:
                tablero4[coord3, coord4] = "_X_"
                #disparo1 = tablero3[coord1, coord2]
                tablero4[coord1-1, coord2] = "_X_"
                clear_output(wait=True)
                print("Te he dado!")
                print(tablero3)
                print(tablero4)  
                b = 1
                a = 0
                n_vidas_jugador-=1
                # if turno == 0:
                #     turno = 0
            elif "_A_" in tablero1[coord1, coord2]:
                b = 1
                a = 0
                pass
                
            else:
                tablero3[coord3, coord4] = "_A_"
                tablero4[coord3-1, coord4] = "_A_"
                acierto = 0
                clear_output(wait=True)
                #time.sleep(1)
                print("He fallado, ahora te toca a ti")
                print(tablero3)
                print(tablero4)  
                print(focus)
                print(right, left)
                print(a)
                b = 0
                a = 1

# %%
#prueba de eliminación de disparo duplicado en A incompleta
"""Importación de librerias"""
import numpy as np
import time
import os
from IPython.display import clear_output
"""Importación de librerias"""
# pruebas para cerrar el bucle de jeugo al terminar las vidas de cada jugador
tablero1 = np.full((5,5),"___")
tablero2 = np.full((5,5),"___")
tablero3 = np.full((5,5),"___")
tablero4 = np.full((5,5),"___")
n_portaaviones_j = 0
n_portaaviones_m = 0
portaaviones_j = 1
portaaviones_m = 1
n_vidas_jugador = 5
n_vidas_maquina = 5
ganador_j = 0
ganador_m = 0
a = 0
b = 0
disparos_j = []
disparos_m =[]
# marco = ["=V=","_1_","_2_","_3_","_4_","_5_","_6_","_7_","_8_","_9_","_10"]
# jugador1 = ["___","___","_J_","_U_","_G_","_A_","_D_","_O_","_R_","___","___"]
# jugador2 = ["___","___","_M_","_A_","_Q_","_U_","_I_","_N_","_A_","___","___"]# buscar la opción de indicar el nº de vidas o barcos restantes en el título de la cuadrícula

# tablero1[1:,:1] = np.reshape(marco,(11,1))
# tablero1[1:2,:] = np.reshape(marco,(1,11))
# tablero1[:1,:] = np.reshape(jugador1,(1,11))

# tablero2[0:,:1] = np.reshape(marco,(11,1))
# tablero2[:1,:] = np.reshape(marco,(1,11))

# tablero3[1:,:1] = np.reshape(marco,(11,1))
# tablero3[1:2,:] = np.reshape(marco,(1,11))
# tablero3[:1,:] = np.reshape(jugador2,(1,11))

# tablero4[0:,:1] = np.reshape(marco,(11,1))
# tablero4[:1,:] = np.reshape(marco,(1,11))
jugar = 1 #input("¿Quieres Jugar (S/N)?")
if jugar == 1:
#if jugar.lower() == "s":
    print("Genial! Pongamos nuestros barcos")
  
    while n_portaaviones_j < portaaviones_j:
        if np.random.randint(0,2,1):
            orientacion = "horizontal"
            coord1 = np.random.randint(0,5)
            coord2 = np.random.randint(0,5-4+1)
        
            if "_B_" in tablero1[coord1-1:coord1+2, coord2-1:coord2+5]:
                #tablero1[coord1, coord2:coord2+size] = "C"
                pass
            else: 
                tablero1[coord1, coord2:coord2+4] = "_B_"
                n_portaaviones_j += 1
                #print(elemento)
        else:
            orientacion = "vertical"

            coord1 = np.random.randint(0,5-4+1)
            coord2 = np.random.randint(0,5)
        
            if "_B_" in tablero1[coord1-1:coord1+5, coord2-1:coord2+2]:
                #tablero1[coord1, coord2:coord2+size] = "C"
                pass
            else: 
                tablero1[coord1:coord1+4, coord2] = "_B_"
                n_portaaviones_j += 1
                    #print(elemento)
    while n_portaaviones_m < portaaviones_m:
        if np.random.randint(0,2,1):
            orientacion = "horizontal"
            coord3 = np.random.randint(0,5)
            coord4 = np.random.randint(0,5-4+1)
        
            if "_B_" in tablero3[coord3-1:coord3+2, coord4-1:coord4+5]:
                #tablero1[coord3, coord4:coord4+size] = "C"
                pass
            else: 
                tablero3[coord3, coord4:coord4+4] = "_B_"
                n_portaaviones_m += 1
                #print(elemento)
        else:
            orientacion = "vertical"

            coord3 = np.random.randint(0,5-4+1)
            coord4 = np.random.randint(0,5)
        
            if "_B_" in tablero3[coord3-1:coord3+5, coord4-1:coord4+2]:
                #tablero1[coord3, coord4:coord4+size] = "C"
                pass
            else: 
                tablero3[coord3:coord3+4, coord4] = "_B_"
                n_portaaviones_m += 1
                    #print(elemento)
    clear_output(wait=True)
    time.sleep(3)# nos da 3 segundos de Genial! Pongamos nuestros barcos
    print(tablero1)
    print(tablero3)

    clear_output(wait=True)
    time.sleep(3)
    print("Veamos quien empieza")

    if np.random.randint(0,2,1):
        clear_output(wait=True)
        time.sleep(2)
        print("Que suerte, eres el primero en empezar, empieza disparando!")
        a = 1
        turno = 1
        
        
    else:
        clear_output(wait=True)
        time.sleep(2)
        print("Te toca esperar, empiezo disparando!")
        b = 1
        turno = 0
while (ganador_m == 0) and (ganador_j == 0):
    enter = input("Presiona enter para continuar")  
    if enter == "":
        if a == 1:
            coord1 = np.random.randint(0,5)
            coord2 = np.random.randint(0,5)

            if "_B_" in tablero1[coord1, coord2]:
                tablero1[coord1, coord2] = "_X_"
                #disparo1 = tablero1[coord1, coord2]
                tablero2[coord1, coord2] = "_X_"
                clear_output(wait=True)
                print(f"Me has dado en la fila {coord1}, columna {coord2}")
                print(tablero1)
                print(tablero2)  
                a = 1
                b = 0
                n_vidas_maquina-=1
                # if turno == 1:
                #     turno = 1
            elif "_A_" in tablero1[coord1, coord2]:
                a = 1
                b = 0
                pass
            else:
                tablero1[coord1, coord2] = "_A_"
                tablero2[coord1, coord2] = "_A_"
                disparos_j.append(coord1)
                disparos_j.append(coord2)
                acierto = 0
                clear_output(wait=True)
                #time.sleep(1)
                print(f"Has fallado en la fila {coord1}, columna {coord2}, ahora me toca a mi")
                print(tablero1)
                print(tablero2)  
                print(disparos_j)
                a = 0
                b = 1
                # if turno == 1:
                #     turno = 0
        elif b == 1:
            coord3 = np.random.randint(0,5)
            coord4 = np.random.randint(0,5)
            
            if "_B_" in tablero1[coord3, coord4]:
                tablero3[coord3, coord4] = "_X_"
                #disparo1 = tablero3[coord1, coord2]
                tablero4[coord3, coord4] = "_X_"
                clear_output(wait=True)
                print(f"Te he dado en la fila {coord3}, columna {coord4}")
                print(tablero3)
                print(tablero4)  
                b = 1
                a = 0
                n_vidas_jugador-=1
                # if turno == 0:
                #     turno = 0
            elif "_A_" in tablero3[coord3, coord4]:
                b = 1
                a = 0
                pass
            else:
                tablero3[coord3, coord4] = "_A_"
                tablero4[coord3, coord4] = "_A_"
                disparos_m.append(coord3)
                disparos_m.append(coord4)
                acierto = 0
                clear_output(wait=True)
                #time.sleep(1)
                print(f"He fallado en la fila {coord3}, columna {coord4}, ahora te toca a ti")
                print(tablero3)
                print(tablero4)  
                print(disparos_m)
                b = 0
                a = 1
                # if turno == 0:
                #     turno = 1

# %%
l_barcos = ["fragata","buque","acorazado","portaaviones"]
aciertos = 3
print(l_barcos[aciertos])

# %%
#identificación de barcos
"""Importación de librerias"""
import numpy as np
import time
import os
from IPython.display import clear_output
"""Importación de librerias"""

""" Definición de variables"""
turno_j = 0 
turno_m = 1
flota_j = [1,1,1,1,2,2,2,3,3,4]
flota_m = [1,1,1,1,2,2,2,3,3,4]
n_barcos_j = len(flota_j)
portaaviones_j = flota_j.count(4)
acorazado_j = flota_j.count(3)
buque_j = flota_j.count(2)
fragata_j = flota_j.count(1)
n_barcos_m = len(flota_m)
portaaviones_m = flota_m.count(4)
acorazado_m = flota_m.count(3)
buque_m = flota_m.count(2)
fragata_m = flota_m.count(1)
n_portaaviones_j = 0
n_acorazado_j = 0
n_buque_j = 0
n_fragata_j = 0
# n_barcos_j = len(flota_j)
n_portaaviones_m = 0
n_acorazado_m = 0
n_buque_m = 0
n_fragata_m = 0
# n_barcos_m = len(flota_m)
a = 0
b = 0
focus = 0
aciertos = 0
up = 0
down = 0
left = 0
right = 0
ganador_j = 0
ganador_m = 0
n_vidas_jugador = sum(flota_j)
n_vidas_maquina = sum(flota_m)

l_barcos = ["","fragata","buque","acorazado","portaaviones"]
"""Definición de variables"""

"""Definición del tablero"""
tablero1 = np.full((12,11)," ~ ")
tablero2 = np.full((11,11)," ~ ")
tablero3 = np.full((12,11)," ~ ")
tablero4 = np.full((11,11)," ~ ")

marco = ["=V=","_1_","_2_","_3_","_4_","_5_","_6_","_7_","_8_","_9_","_10"]
jugador1 = ["___","___","_J_","_U_","_G_","_A_","_D_","_O_","_R_","___","___"]
jugador2 = ["___","___","_M_","_A_","_Q_","_U_","_I_","_N_","_A_","___","___"]# buscar la opción de indicar el nº de vidas o barcos restantes en el título de la cuadrícula



tablero1[1:,:1] = np.reshape(marco,(11,1))
tablero1[1:2,:] = np.reshape(marco,(1,11))
tablero1[:1,:] = np.reshape(jugador1,(1,11))
# tablero1[0,-1] = len(flota_j)
# tablero1[0,-1] = sum(flota_j)

tablero2[0:,:1] = np.reshape(marco,(11,1))
tablero2[:1,:] = np.reshape(marco,(1,11))

tablero3[1:,:1] = np.reshape(marco,(11,1))
tablero3[1:2,:] = np.reshape(marco,(1,11))
tablero3[:1,:] = np.reshape(jugador2,(1,11))
# tablero3[0,-1] = len(flota_m)
# tablero1[0,-1] = sum(flota_m)

tablero4[0:,:1] = np.reshape(marco,(11,1))
tablero4[:1,:] = np.reshape(marco,(1,11))
"""Definición del tablero"""

jugar = input("¿Quieres Jugar (S/N)")
# if jugar == 1:
if jugar.lower() == "s":
    print("Genial! Pongamos nuestros barcos")

    game_style = input("Como quieres jugar, Modo Manual (M) o Modo Automático (A)")
    
    while n_portaaviones_j < portaaviones_j:
        if np.random.randint(0,2,1):
            orientacion = "horizontal"
            coord1 = np.random.randint(2,11)
            coord2 = np.random.randint(1,11-4+1)
        
            if "_B_" in tablero1[coord1-1:coord1+2, coord2-1:coord2+5]:
                #tablero1[coord1, coord2:coord2+size] = "C"
                pass
            else: 
                tablero1[coord1, coord2:coord2+4] = "_B_"
                n_portaaviones_j += 1
                #print(elemento)
        else:
            orientacion = "vertical"

            coord1 = np.random.randint(2,11-4+1)
            coord2 = np.random.randint(1,11)
        
            if "_B_" in tablero1[coord1-1:coord1+5, coord2-1:coord2+2]:
                #tablero1[coord1, coord2:coord2+size] = "C"
                pass
            else: 
                tablero1[coord1:coord1+4, coord2] = "_B_"
                n_portaaviones_j += 1
                    #print(elemento)
    while n_acorazado_j < acorazado_j:
        if np.random.randint(0,2,1):
            orientacion = "horizontal"
            coord1 = np.random.randint(2,11)
            coord2 = np.random.randint(1,11-3+1)
        
            if "_B_" in tablero1[coord1-1:coord1+2, coord2-1:coord2+4]:
                #tablero1[coord1, coord2:coord2+size] = "C"
                pass
            else: 
                tablero1[coord1, coord2:coord2+3] = "_B_"
                n_acorazado_j += 1
                #print(elemento)
        else:
            orientacion = "vertical"

            coord1 = np.random.randint(2,11-3+1)
            coord2 = np.random.randint(1,11)
        
            if "_B_" in tablero1[coord1-1:coord1+4, coord2-1:coord2+2]:
                #tablero1[coord1, coord2:coord2+size] = "C"
                pass
            else: 
                tablero1[coord1:coord1+3, coord2] = "_B_"
                n_acorazado_j += 1
                    #print(elemento)
    while n_buque_j < buque_j:
        if np.random.randint(0,2,1):
            orientacion = "horizontal"
            coord1 = np.random.randint(2,11)
            coord2 = np.random.randint(1,11-2+1)
        
            if "_B_" in tablero1[coord1-1:coord1+2, coord2-1:coord2+3]:
                #tablero1[coord1, coord2:coord2+size] = "C"
                pass
            else: 
                tablero1[coord1, coord2:coord2+2] = "_B_"
                n_buque_j += 1
                #print(elemento)
        else:
            orientacion = "vertical"

            coord1 = np.random.randint(2,11-2+1)
            coord2 = np.random.randint(1,11)
        
            if "_B_" in tablero1[coord1-1:coord1+3, coord2-1:coord2+2]:
                #tablero1[coord1, coord2:coord2+size] = "C"
                pass
            else: 
                tablero1[coord1:coord1+2, coord2] = "_B_"
                n_buque_j += 1
                    #print(elemento)
    while n_fragata_j < fragata_j:
        if np.random.randint(0,2,1):
            orientacion = "horizontal"
            coord1 = np.random.randint(2,11)
            coord2 = np.random.randint(1,11)
        
            if "_B_" in tablero1[coord1-1:coord1+2, coord2-1:coord2+2]:
                #tablero1[coord1, coord2:coord2+size] = "C"
                pass
            else: 
                tablero1[coord1, coord2:coord2+1] = "_B_"
                n_fragata_j += 1
                #print(elemento)
        else:
            orientacion = "vertical"

            coord1 = np.random.randint(2,11)
            coord2 = np.random.randint(1,11)
        
            if "_B_" in tablero1[coord1-1:coord1+2, coord2-1:coord2+2]:
                #tablero1[coord1, coord2:coord2+size] = "C"
                pass
            else: 
                tablero1[coord1:coord1+1, coord2] = "_B_"
                n_fragata_j += 1
                    #print(elemento)  

    while n_portaaviones_m < portaaviones_m:
        if np.random.randint(0,2,1):
            orientacion = "horizontal"
            coord3 = np.random.randint(2,11)
            coord4 = np.random.randint(1,11-4+1)
        
            if "_B_" in tablero3[coord3-1:coord3+2, coord4-1:coord4+5]:
                #tablero1[coord3, coord4:coord4+size] = "C"
                pass
            else: 
                tablero3[coord3, coord4:coord4+4] = "_B_"
                n_portaaviones_m += 1
                #print(elemento)
        else:
            orientacion = "vertical"

            coord3 = np.random.randint(2,11-4+1)
            coord4 = np.random.randint(1,11)
        
            if "_B_" in tablero3[coord3-1:coord3+5, coord4-1:coord4+2]:
                #tablero1[coord3, coord4:coord4+size] = "C"
                pass
            else: 
                tablero3[coord3:coord3+4, coord4] = "_B_"
                n_portaaviones_m += 1
                    #print(elemento)
    while n_acorazado_m < acorazado_m:
        if np.random.randint(0,2,1):
            orientacion = "horizontal"
            coord3 = np.random.randint(2,11)
            coord4 = np.random.randint(1,11-3+1)
        
            if "_B_" in tablero3[coord3-1:coord3+2, coord4-1:coord4+4]:
                #tablero1[coord3, coord4:coord4+size] = "C"
                pass
            else: 
                tablero3[coord3, coord4:coord4+3] = "_B_"
                n_acorazado_m += 1
                #print(elemento)
        else:
            orientacion = "vertical"

            coord3 = np.random.randint(2,11-3+1)
            coord4 = np.random.randint(1,11)
        
            if "_B_" in tablero3[coord3-1:coord3+4, coord4-1:coord4+2]:
                #tablero1[coord3, coord4:coord4+size] = "C"
                pass
            else: 
                tablero3[coord3:coord3+3, coord4] = "_B_"
                n_acorazado_m += 1
                    #print(elemento)
    while n_buque_m < buque_m:
        if np.random.randint(0,2,1):
            orientacion = "horizontal"
            coord3 = np.random.randint(2,11)
            coord4 = np.random.randint(1,11-2+1)
        
            if "_B_" in tablero3[coord3-1:coord3+2, coord4-1:coord4+3]:
                #tablero1[coord3, coord4:coord4+size] = "C"
                pass
            else: 
                tablero3[coord3, coord4:coord4+2] = "_B_"
                n_buque_m += 1
                #print(elemento)
        else:
            orientacion = "vertical"

            coord3 = np.random.randint(2,11-2+1)
            coord4 = np.random.randint(1,11)
        
            if "_B_" in tablero3[coord3-1:coord3+3, coord4-1:coord4+2]:
                #tablero1[coord3, coord4:coord4+size] = "C"
                pass
            else: 
                tablero3[coord3:coord3+2, coord4] = "_B_"
                n_buque_m += 1
                    #print(elemento)
    while n_fragata_m < fragata_m:
        if np.random.randint(0,2,1):
            orientacion = "horizontal"
            coord3 = np.random.randint(2,12)
            coord4 = np.random.randint(1,11)
        
            if "_B_" in tablero3[coord3-1:coord3+2, coord4-1:coord4+2]:
                #tablero1[coord3, coord4:coord4+size] = "C"
                pass
            else: 
                tablero3[coord3, coord4:coord4+1] = "_B_"
                n_fragata_m += 1
                #print(elemento)
        else:
            orientacion = "vertical"

            coord3 = np.random.randint(2,12)
            coord4 = np.random.randint(1,11)
        
            if "_B_" in tablero3[coord3-1:coord3+2, coord4-1:coord4+2]:
                #tablero1[coord3, coord4:coord4+size] = "C"
                pass
            else: 
                tablero3[coord3:coord3+1, coord4] = "_B_"
                n_fragata_m += 1
                    #print(elemento)  

    enter = input("Presiona enter para continuar")
    if enter == "":
        clear_output(wait=True)
        # time.sleep(1)# nos da 3 segundos de Genial! Pongamos nuestros barcos
        print(tablero1)
        if game_style.lower() == "a":
            print(tablero3)
    enter = input("Presiona enter para continuar")
    if enter == "":    
        clear_output(wait=True)


        time.sleep(1)
        print("Veamos quien empieza")

#decisión de turno aleatoria

    if np.random.randint(0,2,1):
        clear_output(wait=True)
        time.sleep(1)
        print("Te toca esperar, empiezo disparando!")
        # print("Que suerte, eres el primero en empezar, empieza disparando!")
        a = 1
        #turno = 1
    else:
        clear_output(wait=True)
        time.sleep(1)
        # print("Te toca esperar, empiezo disparando!")
        print("Que suerte, eres el primero en empezar, empieza disparando!")
        b = 1
        #turno = 0

while (ganador_m == 0) and (ganador_j == 0):
    enter = input("Presiona enter para continuar")  
    if enter == "":
        if a == 1 and focus == 0 and up == 0 and down == 0 and right == 0 and left == 0:
            coord1 = np.random.randint(2,12)
            coord2 = np.random.randint(1,11)
            if "_B_" in tablero1[coord1, coord2]:
                tablero1[coord1, coord2] = "_X_"
                tablero2[coord1-1, coord2] = "_X_"
                clear_output(wait=True)
                print(f"Te he dado en la fila {coord1-1}, columna {coord2}")
                print(tablero1)
                print(tablero2)  
                a = 1
                b = 0
                n_vidas_jugador-=1
                focus = 1
                aciertos += 1      
                print(n_vidas_jugador)  
                tablero1[0,-1] = sum(flota_j)-1
        
                if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2]:
                    print(f"He hundido tu {l_barcos[aciertos]}!")
                    a = 1
                    b = 0
                    focus = 0
                    aciertos = 0
                    n_barcos_j -=1
                else:    
                    enter = input("Presiona enter para continuar") # disparo "inteligente"
                    if enter == "" and focus == 1 and up == 0 and down == 0 and right == 0 and left == 0:# derecha
                        up = 0
                        down = 0
                        right = 1
                        left = 0
                        if coord2+((right)-(left))*focus < 10:  
                            if focus == 1 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando.
                                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                clear_output(wait=True)
                                print(f"Te he dado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus}")
                                print(tablero1)
                                print(tablero2)  
                                a = 1
                                b = 0
                                n_vidas_jugador-=1
                                focus = 2
                                aciertos += 1 
                                if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+1+focus]:
                                    print(f"He hundido tu {l_barcos[aciertos]}!")# reseteamos todos los valores de búsqueda y repetimos disparo
                                    a = 1
                                    b = 0
                                    focus = 0
                                    aciertos = 0
                                    n_barcos_j -=1
                                    up = 0
                                    down = 0
                                    right = 0
                                    left = 0
                                else:    # derecha
                                    enter = input("Presiona enter para continuar") 
                                    if enter == "" and focus == 2 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                                        tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                        tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                        clear_output(wait=True)
                                        print(f"Te he dado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus}")
                                        print(tablero1)
                                        print(tablero2)  
                                        print(focus)
                                        print(coord1)
                                        print(coord2)   
                                        a = 1
                                        b = 0
                                        n_vidas_jugador-=1
                                        focus = 3
                                        aciertos += 1 
                                        if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+1+focus]:
                                            print(f"He hundido tu {l_barcos[aciertos]}!")# reseteamos todos los valores de búsqueda y repetimos disparo
                                            a = 1
                                            b = 0
                                            focus = 0
                                            aciertos = 0
                                            n_barcos_j -=1
                                            up = 0
                                            down = 0
                                            right = 0
                                            left = 0
                                        else:    # derecha
                                            enter = input("Presiona enter para continuar") 
                                            if enter == "" and focus == 3 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                                                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                                clear_output(wait=True)
                                                print(f"Te he dado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus}")
                                                print(tablero1)
                                                print(tablero2)  
                                                print(focus)
                                                print(coord1)
                                                print(coord2)   
                                                a = 1
                                                b = 0
                                                n_vidas_jugador-=1
                                                # focus = 4
                                                aciertos += 1 
                                                if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+1+focus]:
                                                    print(f"He hundido tu {l_barcos[aciertos]}!")# reseteamos todos los valores de búsqueda y repetimos disparo
                                                    print(focus)
                                                    print(coord1)
                                                    print(coord2)   
                                                    a = 1
                                                    b = 0
                                                    focus = 0
                                                    aciertos = 0
                                                    n_barcos_j -=1
                                                    up = 0
                                                    down = 0
                                                    right = 0
                                                    left = 0                                                         
                                            elif enter == "" and focus == 3 and "_B_" not in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                                                # tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = " A "
                                                clear_output(wait=True)
                                                print(f"He fallado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus},ahora te toca a ti")
                                                print(tablero1)
                                                print(tablero2)  
                                                a = 0
                                                b = 1
                                                focus = 1
                                                # aciertos = 3
                                                up = 0
                                                down = 0
                                                right = 0
                                                left = 1
                                                
                                    elif " A " in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] or "_X_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                                        a = 1
                                        b = 0
                                        pass
                                    else:
                                        # tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                        tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = " A "
                                        clear_output(wait=True)
                                        print(f"He fallado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus},ahora te toca a ti")
                                        print(tablero1)
                                        print(tablero2)
                                        a = 0
                                        b = 1
                                        focus = 1
                                        # aciertos = 2
                                        up = 0
                                        down = 0
                                        right = 0
                                        left = 1
                                              
                            elif " A " in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] or "_X_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                                a = 1
                                b = 0
                                pass
                            else:
                                # tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = " A "
                                acierto = 0
                                clear_output(wait=True)
                                print(f"He fallado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus},ahora te toca a ti")
                                print(tablero1)
                                print(tablero2) 
                                a = 0
                                b = 1
                                focus = 1
                                # aciertos = 1
                                up = 0
                                down = 0
                                right = 0
                                left = 1
                        else:
                            a = 1
                            b = 0
                            # aciertos = 1
                            focus = 1
                            up = 0
                            down = 0
                            right = 0
                            left = 1
            elif " A " in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] or "_X_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                a = 1
                b = 0
                pass
            else:
                # tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = " A "
                acierto = 0
                clear_output(wait=True)
                print(f"He fallado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus},ahora te toca a ti")
                print(tablero1)
                print(tablero2)  
                a = 0
                b = 1
                aciertos = 0
                focus = 0
                up = 0
                down = 0
                right = 0
                left = 0
        elif a == 1 and focus == 1 and left == 1: # izquierdas
            if coord2+((right)-(left))*focus > 1:
                if "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                    tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                    tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                    clear_output(wait=True)
                    print(f"Te he dado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus} izquierda")
                    print(tablero1)
                    print(tablero2)  
                    print(focus)
                    print(coord1)
                    print(coord2)   
                    a = 1
                    b = 0
                    n_vidas_jugador-=1
                    focus = 2
                    aciertos += 1 
                    if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2, coord2-1-focus:coord2+2]:# ojo, si damos a mitad de un barco grande, entenderemos que hemos hundido un buque, y no es correcto
                        print(f"He hundido tu {l_barcos[aciertos]}!")
                        print(focus)
                        print(coord1)
                        print(coord2)   
                        a = 1
                        b = 0
                        focus = 0
                        aciertos = 0
                        n_barcos_j -=1
                        up = 0
                        down = 0
                        right = 0
                        left = 0
                    else:    # izquierda
                        enter = input("Presiona enter para continuar") 
                        if enter == "" and focus == 2 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                            tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                            #disparo1 = tablero1[coord1, coord2]
                            tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                            clear_output(wait=True)
                            print(f"Te he dado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus}")
                            print(tablero1)
                            print(tablero2)  
                            print(focus)
                            print(coord1)
                            print(coord2)   
                            a = 1
                            b = 0
                            n_vidas_jugador-=1
                            focus = 3
                            aciertos += 1 
                            if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2, coord2-1-focus:coord2+2]:
                                print(f"He hundido tu {l_barcos[aciertos]}!")
                                a = 1
                                b = 0
                                focus = 0
                                aciertos = 0
                                n_barcos_j -=1
                                up = 0
                                down = 0
                                right = 0
                                left = 0
                            else:    #izquierda
                                enter = input("Presiona enter para continuar") 
                                if enter == "" and focus == 3 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                                    tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                    tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                    clear_output(wait=True)
                                    print(f"Te he dado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus}")
                                    print(tablero1)
                                    print(tablero2)  
                                    print(focus)
                                    print(coord1)
                                    print(coord2)   
                                    a = 1
                                    b = 0
                                    n_vidas_jugador-=1
                                    aciertos += 1 
                                    if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2, coord2-1-focus:coord2+2]:# ojo, si damos a mitad de un barco grande, entenderemos que hemos hundido un buque, y no es correcto
                                        print(f"He hundido tu {l_barcos[aciertos]}!")
                                        a = 1
                                        b = 0
                                        focus = 0
                                        aciertos = 0
                                        n_barcos_j -=1
                                        up = 0
                                        down = 0
                                        right = 0
                                        left = 0
                                        # ganador_j = 1                                                           
                                elif enter == "" and focus == 3 and "_B_" not in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                                    # tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                    tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = " A "
                                    # aciertos = 0
                                    print(f"He fallado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus},ahora te toca a ti")
                                    print(tablero1)
                                    print(tablero2)  
                                    print(focus)
                                    print(coord1)
                                    print(coord2)
                                    focus = 1
                                    up = 0
                                    down = 1
                                    right = 0
                                    left = 0
                                    clear_output(wait=True)
                                    #time.sleep(1)
                                    a = 0
                                    b = 1
                        elif " A " in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] or "_X_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                            a = 1
                            b = 0
                            pass
                        else:
                            tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = " A "
                            clear_output(wait=True)
                            print(f"He fallado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus},ahora te toca a ti")
                            print(tablero1)
                            print(tablero2) 
                            print(f"He fallado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus},ahora te toca a ti")
                            #time.sleep(1)
                            a = 0
                            b = 1
                            # aciertos = 2
                            focus = 1
                            up = 0
                            down = 1
                            right = 0
                            left = 0
                elif " A " in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] or "_X_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                    a = 1
                    b = 0
                    pass
                else:
                    # tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                    tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = " A "
                    clear_output(wait=True)
                    print(f"He fallado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus},ahora te toca a ti")
                    print(tablero1)
                    print(tablero2)  
                    a = 0
                    b = 1
                    # aciertos = 1
                    focus = 1
                    up = 0
                    down = 1
                    right = 0
                    left = 0
                    
                    # print(focus)
                    # print(right, left, down, up)
            else:
                a = 1
                b = 0
                # aciertos = 1
                focus = 1
                up = 0
                down = 1
                right = 0
                left = 0
                        
        elif a == 1 and focus == 1 and down == 1: # abajo
            if coord1-1+((down)-(up))*focus < 10:
                if "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                    tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                    #disparo1 = tablero1[coord1, coord2]
                    tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                    clear_output(wait=True)
                    print(f"Te he dado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus}")
                    print(tablero1)
                    print(tablero2)  
                    print(focus)
                    print(coord1)
                    print(coord2)   
                    a = 1
                    b = 0
                    n_vidas_jugador-=1
                    focus = 2
                    aciertos += 1 
                    if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+1+focus, coord2-1:coord2+2]:# ojo, si damos a mitad de un barco grande, entenderemos que hemos hundido un buque, y no es correcto
                        print(f"He hundido tu {l_barcos[aciertos]}!")
                        a = 1
                        b = 0
                        focus = 0
                        aciertos = 0
                        n_barcos_j -=1
                        up = 0
                        down = 0
                        right = 0
                        left = 0
                    else:    # abajo
                        enter = input("Presiona enter para continuar") 
                        if enter == "" and focus == 2 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                            tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                            #disparo1 = tablero1[coord1, coord2]
                            tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                            clear_output(wait=True)
                            print(f"Te he dado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus}")
                            print(tablero1)
                            print(tablero2)  
                            print(focus)
                            print(coord1)
                            print(coord2)   
                            a = 1
                            b = 0
                            n_vidas_jugador-=1
                            focus = 3
                            aciertos += 1 
                            if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+1+focus, coord2-1:coord2+2]:
                                print(f"He hundido tu {l_barcos[aciertos]}!")
                                a = 1
                                b = 0
                                focus = 0
                                aciertos = 0
                                n_barcos_j -=1
                                up = 0
                                down = 0
                                right = 0
                                left = 0
                            else:    #abajo
                                enter = input("Presiona enter para continuar") 
                                if enter == "" and focus == 3 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                                    tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                    #disparo1 = tablero1[coord1, coord2]
                                    tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                    clear_output(wait=True)
                                    print(f"Te he dado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus}")
                                    print(tablero1)
                                    print(tablero2)  
                                    print(focus)
                                    print(coord1)
                                    print(coord2)   
                                    a = 1
                                    b = 0
                                    n_vidas_jugador-=1
                                    focus = 4
                                    aciertos += 1 
                                    if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+1+focus, coord2-1:coord2+2]:# ojo, si damos a mitad de un barco grande, entenderemos que hemos hundido un buque, y no es correcto
                                        print(f"He hundido tu {l_barcos[aciertos]}!")
                                        a = 1
                                        b = 0
                                        focus = 0
                                        # aciertos = 0
                                        n_barcos_j -=1
                                        up = 0
                                        down = 0
                                        right = 0
                                        left = 0
                                        # ganador_j = 1                                                           
                                elif enter == "" and focus == 3 and "_B_" not in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                                    # tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                    tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "~A~"
                                    clear_output(wait=True)
                                    #time.sleep(1)
                                    print(f"He fallado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus},ahora te toca a ti")
                                    print(tablero1)
                                    print(tablero2)  
                                    print(focus)
                                    print(coord1)
                                    print(coord2)   
                                    # aciertos = 3
                                    focus = 1
                                    up = 1
                                    down = 0
                                    right = 0
                                    left = 0
                                    a = 0
                                    b = 1
                        elif " A " in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] or "_X_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                            a = 1
                            b = 0
                            pass
                        else:
                            # tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                            tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = " A "
                            clear_output(wait=True)
                            print(f"He fallado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus},ahora te toca a ti")
                            print(tablero1)
                            print(tablero2) 
                            #time.sleep(1)
                            a = 0
                            b = 1
                            # aciertos = 2
                            focus = 1
                            up = 1
                            down = 0
                            right = 0
                            left = 0                            
                elif " A " in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] or "_X_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                    a = 1
                    b = 0
                    pass
                else:
                    # tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                    tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = " A "
                    # aciertos = 1
                    
                    clear_output(wait=True)
                    #time.sleep(1)
                    print(f"He fallado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus},ahora te toca a ti")
                    print(tablero1)
                    print(tablero2) 
                    print(focus)
                    print(coord1)
                    print(coord2)   
                    print 
                    a = 0
                    b = 1
                    focus = 1
                    up = 1
                    down = 0
                    right = 0
                    left = 0
            else:
                focus = 1
                up = 1
                down = 0
                right = 0
                left = 0
        elif a == 1 and focus == 1 and up == 1: # arriba
            # if coord1-1+((down)-(up))*focus > 2
            if "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                #disparo1 = tablero1[coord1, coord2]
                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                clear_output(wait=True)
                print(f"Te he dado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus}")
                print(tablero1)
                print(tablero2)  
                print(focus)
                print(coord1)
                print(coord2)   
                a = 1
                b = 0
                n_vidas_jugador-=1
                focus = 2
                aciertos +=1
                if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1-focus:coord1+2, coord2-1:coord2+2]:# ojo, si damos a mitad de un barco grande, entenderemos que hemos hundido un buque, y no es correcto
                    print(f"He hundido tu {l_barcos[aciertos]}!")
                    print(focus)
                    print(coord1)
                    print(coord2)   
                    a = 1
                    b = 0
                    focus = 0
                    aciertos = 0
                    n_barcos_j -=1
                    up = 0
                    down = 0
                    right = 0
                    left = 0
                else:    # abajo
                    enter = input("Presiona enter para continuar") 
                    if enter == "" and focus == 2 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                        tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                        #disparo1 = tablero1[coord1, coord2]
                        tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                        clear_output(wait=True)
                        print(f"Te he dado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus}")
                        print(tablero1)
                        print(tablero2)  
                        print(focus)
                        print(coord1)
                        print(coord2)   
                        a = 1
                        b = 0
                        n_vidas_jugador-=1
                        focus = 3
                        aciertos +=1
                        if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1-focus:coord1+2, coord2-1:coord2+2]:
                            print(f"He hundido tu {l_barcos[aciertos]}!")
                            print(focus)
                            print(coord1)
                            print(coord2)      
                            a = 1
                            b = 0
                            focus = 0
                            aciertos = 0
                            n_barcos_j -=1
                            up = 0
                            down = 0
                            right = 0
                            left = 0
                        else:    #abajo
                            enter = input("Presiona enter para continuar") 
                            if enter == "" and focus == 3 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                #disparo1 = tablero1[coord1, coord2]
                                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                clear_output(wait=True)
                                print(f"Te he dado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus}")
                                print(tablero1)
                                print(tablero2)  
                                print(focus)
                                print(coord1)
                                print(coord2)      
                                a = 1
                                b = 0
                                n_vidas_jugador-=1
                                aciertos +=1
                                focus = 4
                                if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1-focus:coord1+2, coord2-1:coord2+2]:# ojo, si damos a mitad de un barco grande, entenderemos que hemos hundido un buque, y no es correcto
                                    print(f"He hundido tu {l_barcos[aciertos]}!")
                                    print(focus)
                                    print(coord1)
                                    print(coord2)      
                                    a = 1
                                    b = 0
                                    focus = 0
                                    aciertos = 0
                                    n_barcos_j -=1
                                    up = 0
                                    down = 0
                                    right = 0
                                    left = 0
                                    # ganador_j = 1                                                           
                            elif enter == "" and focus == 3 and "_B_" not in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                                # tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "~A~"
                                focus = 1
                                # up = 0
                                # down = 0
                                # right = 0
                                # left = 0
                                clear_output(wait=True)
                                #time.sleep(1)
                                print(f"He fallado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus},ahora te toca a ti")
                                print(tablero1)
                                print(tablero2)  
                                print(focus)
                                print(right, left)
                                a = 0
                                b = 1
                    elif " A " in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] or "_X_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                        a = 1
                        b = 0
                        pass
                    else:
                        # tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                        tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = " A "
                        clear_output(wait=True)
                        print(f"He fallado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus},ahora te toca a ti")
                        print(tablero1)
                        print(tablero2) 
                        #time.sleep(1)
                        a = 0
                        b = 1
                        # acierto = 0
                        focus = 1
                        # up = 1
                        # down = 0
                        # right = 0
                        # left = 0
                        
                        
            elif " A " in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] or "_X_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                a = 1
                b = 0
                pass
            else:
                # tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = " A "
                print(f"He fallado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus},ahora te toca a ti")
                print(tablero1)
                print(tablero2) 
                focus = 1
                # up = 1
                # down = 0
                # right = 0
                # left = 0
                clear_output(wait=True)
                #time.sleep(1)
                a = 0
                b = 1
        elif b == 1:
            if game_style.lower() == "m":
                coord3 = int(input("Introduce un valor entre el 1 y el 10 para la fila donde quieres disparar"))
                coord4 = int(input("Introduce un valor entre el 1 y el 10 para la columna donde quieres disparar"))
                if "_B_" in tablero3[coord3+1, coord4]:
                    tablero3[coord3+1, coord4] = "_X_"
                    #disparo1 = tablero3[coord1, coord2]
                    tablero4[coord3, coord4] = "_X_"
                    clear_output(wait=True)
                    print("Me has dado")
                    # print(tablero3)
                    print(tablero4)   
                    b = 1
                    a = 0
                    # n_vidas_maquina-=1
                    # int(tablero3[0,-1]) -= 1
                    # if turno == 0:
                    #     turno = 0
                elif " A " in tablero3[coord3+1, coord4] or "_X_" in tablero3[coord3+1, coord4]:
                    print ("Ya has disparado ahí, tolai, vuelve a intentarlo")
                    b = 1
                    a = 0
                    pass
                    
                else:
                    # tablero3[coord3, coord4] = "_A_"
                    tablero4[coord3, coord4] = " A "
                    acierto = 0
                    clear_output(wait=True)
                    #time.sleep(1)
                    print("Has fallado, me toca a mi")
                    # print(tablero3)
                    print(tablero4)  
                    print(a)
                    b = 0
                    a = 1

            elif game_style.lower() == "a":
                coord3 = np.random.randint(2,12)
                coord4 = np.random.randint(1,11)
                if "_B_" in tablero3[coord3, coord4]:
                    tablero3[coord3, coord4] = "_X_"
                    #disparo1 = tablero3[coord1, coord2]
                    tablero4[coord3-1, coord4] = "_X_"
                    clear_output(wait=True)
                    print("Me has dado")    
                    print(tablero3)
                    print(tablero4)   
                    b = 1
                    a = 0
                    n_vidas_maquina-=1
                    # if turno == 0:
                    #     turno = 0
                elif " A " in tablero3[coord3, coord4] or "_X_" in tablero3[coord3, coord4]:
                    b = 1
                    a = 0
                    pass
                    
                else:
                    # tablero3[coord3, coord4] = "_A_"
                    tablero4[coord3-1, coord4] = " A "
                    acierto = 0
                    clear_output(wait=True)
                    #time.sleep(1)
                    print("Has fallado, me toca a mi")
                    print(tablero3)
                    print(tablero4)  
                    print(a)
                    b = 0
                    a = 1
        if n_barcos_j <= 0:
            ganador_m = 1
            #clear_output(wait=True)
            print("He ganado! Maquina")
            print(tablero1)
        elif n_vidas_maquina <= 0:
            
            ganador_j = 1
            #clear_output(wait=True)
            print("Has ganado! Jugador")
            print(tablero3)
# Out:
# [['___' '___' '_J_' '_U_' '_G_' '_A_' '_D_' '_O_' '_R_' '___' '___']
#  ['=V=' '_1_' '_2_' '_3_' '_4_' '_5_' '_6_' '_7_' '_8_' '_9_' '_10']
#  ['_1_' '_B_' '_B_' '_B_' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ']
#  ['_2_' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' '_B_' ' ~ ' ' ~ ' '_B_' ' ~ ']
#  ['_3_' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' '_B_' ' ~ ']
#  ['_4_' ' ~ ' ' ~ ' ' ~ ' '_B_' ' ~ ' '_B_' '_B_' ' ~ ' '_B_' ' ~ ']
#  ['_5_' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' '_B_' ' ~ ']
#  ['_6_' '_B_' '_B_' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ']
#  ['_7_' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' '_B_' '_B_' '_B_' ' ~ ' ' ~ ']
#  ['_8_' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' '_B_']
#  ['_9_' ' ~ ' '_B_' ' ~ ' ' ~ ' '_B_' ' ~ ' ' ~ ' ' ~ ' ' ~ ' '_B_']
#  ['_10' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ']]
# [['___' '___' '_M_' '_A_' '_Q_' '_U_' '_I_' '_N_' '_A_' '___' '___']
#  ['=V=' '_1_' '_2_' '_3_' '_4_' '_5_' '_6_' '_7_' '_8_' '_9_' '_10']
#  ['_1_' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ']
#  ['_2_' ' ~ ' '_B_' '_B_' '_B_' ' ~ ' ' ~ ' '_B_' ' ~ ' ' ~ ' ' ~ ']
#  ['_3_' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' '_B_' ' ~ ']
#  ['_4_' ' ~ ' ' ~ ' '_B_' ' ~ ' '_B_' '_B_' '_B_' ' ~ ' '_B_' ' ~ ']
#  ['_5_' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' '_B_' ' ~ ']
#  ['_6_' ' ~ ' ' ~ ' '_B_' ' ~ ' '_B_' '_B_' ' ~ ' ' ~ ' '_B_' ' ~ ']
#  ['_7_' ' ~ ' ' ~ ' '_B_' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ']
#  ['_8_' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' '_B_' ' ~ ' ' ~ ' ' ~ ' ' ~ ']
#  ['_9_' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' '_B_' ' ~ ' ' ~ ' ' ~ ' ' ~ ']
#  ['_10' ' ~ ' '_B_' ' ~ ' ' ~ ' ' ~ ' ' ~ ' ' ~ ' '_B_' ' ~ ' ' ~ ']]

# %%
print("\x1b[31m\"red\"\x1b[0m")
# Out:
# "red"
