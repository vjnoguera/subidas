# %%
import numpy as np

# %%
import os
def clear_screen():
    os.system('cls' if os.name == "nt" else "clear")

# %%
import time

# %%
from IPython.display import clear_output

# %%
"""Importación de librerias"""
import numpy as np
import time
import os
from IPython.display import clear_output
"""Importación de librerias"""
tablero1 = np.full((12,11),"___")# pruebas de disparo inteligente. Depuración del fallo
tablero2 = np.full((11,11),"___")
tablero3 = np.full((11,11),"___")
tablero4 = np.full((11,11),"___")
marco = ["_0_","_1_","_2_","_3_","_4_","_5_","_6_","_7_","_8_","_9_","_10"]
jugador1 = ["___","___","_J_","_U_","_G_","_A_","_D_","_O_","_R_","___","___"]
jugador2 = ["___","___","_M_","_A_","_Q_","_U_","_I_","_N_","_A_","___","___"]
tablero1[:1,:] = np.reshape(jugador1,(1,11))
tablero1[1:2,:] = np.reshape(marco,(1,11))
tablero2[0:,:1] = np.reshape(marco,(11,1))
tablero2[:1,:] = np.reshape(marco,(1,11))
tablero3[0:,:1] = np.reshape(marco,(11,1))
tablero3[:1,:] = np.reshape(marco,(1,11))
tablero4[0:,:1] = np.reshape(marco,(11,1))
tablero4[:1,:] = np.reshape(marco,(1,11))
turno_j = 1 # el comienzo de los turnos también debería ser aleatorio. habría que inicilializar los valores en 0, y mediante función aleatoria, poner un 1 en el que correspoda
turno_m = 1
coord1 = 4
coord2 = 4

tablero1[coord1, coord2]= "_B_"
tablero1[coord1-1, coord2]= "_B_"
tablero1[coord1, coord2+2]= "___"
tablero1[coord1, coord2+3]= "_B_"
print(tablero1, end = "\r")
print(tablero2, end = "\r")

#while turno_j == 1 :#parte por definir para ligar el juego y sus pasos
acierto = 0
enter = input("Presiona enter para disparar")
if enter == "":
    if "_B_" in tablero1[coord1, coord2]:
        tablero1[coord1, coord2] = "_X_"
        tablero2[coord1, coord2] = "_X_"
        acierto+=1
        clear_output(wait=True)
        time.sleep(1)
        print("Has acertado!")
        print(tablero1)
        print(tablero2)
        enter1 = input("Presiona enter para volver a disparar")
        if enter1 == "":
            while acierto ==1:
                if "_B_" in tablero1[coord1-1:coord1+2, coord2-1:coord2+2]:
                    if "_B_" in tablero1[coord1,coord2+1]:
                        tablero1[coord1, coord2+1] = "_X_" 
                        tablero2[coord1, coord2+1] = "_X_"
                        acierto+=1
                        clear_output(wait=True)
                        time.sleep(1)
                        print("Estas en racha!")
                        print(tablero1)
                        print(tablero2)
                        enter2 = input("Presiona enter para volver a disparar")
                    # if enter2 == "":
                    #     while acierto ==2:
                    #         if "_B_" in tablero1[coord1-2:coord1+3, coord2-2:coord2+3]:
                    #             tablero1[coord1, coord2+2] = "_X_"
                    #             tablero2[coord1, coord2+2] = "_X_"
                    #             acierto+=1
                    #             clear_output(wait=True)
                    #             time.sleep(1)
                    #             print("Eres un fiera!")
                    #             print(tablero1)
                    #             print(tablero2)
                    #             enter2 = input("Presiona enter para volver a disparar")
                    #             if enter2 == "":
                    #                 while acierto ==3:
                    #                     if "_B_" in tablero1[coord1-3:coord1+4, coord2-3:coord2+4]:
                    #                         tablero1[coord1, coord2+3] = "_X_"
                    #                         tablero2[coord1, coord2+3] = "_X_"
                    #                         acierto+=1
                    #                         clear_output(wait=True)
                    #                         time.sleep(1)
                    #                         print("Poseidón te sonrie!")
                    #                         print(tablero1)
                    #                         print(tablero2) 
                    #                     else:
                    #                         tablero1[coord1, coord2+3] = "_A_"
                    #                         tablero2[coord1, coord2+3] = "_A_"
                    #                         acierto = 0
                    #                         clear_output(wait=True)
                    #                         time.sleep(1)
                    #                         print("Has fallado")
                    #                         print(tablero1)
                    #                         print(tablero2)  
                    #         else:
                    #             tablero1[coord1, coord2+2] = "_A_"
                    #             tablero2[coord1, coord2+2] = "_A_"
                    #             acierto = 0
                    #             clear_output(wait=True)
                    #             time.sleep(1)
                    #             print("Has fallado")
                    #             print(tablero1)
                    #             print(tablero2)  
                    else:
                        tablero1[coord1, coord2+1] = "_A_"
                        tablero2[coord1, coord2+1] = "_A_"
                        acierto = 0
                        clear_output(wait=True)
                        time.sleep(1)
                        print("Has fallado")
                        print(tablero1)
                        print(tablero2)   
                else:
                    print("Has hundido mi fragata!")
                    acierto = 0
                    focus = 0       
    else: 
        tablero1[coord1, coord2] = "_A_"
        tablero2[coord1, coord2] = "_A_"
        acierto = 0


        clear_output(wait=True)
        time.sleep(1)
        print("Has fallado")
        print(tablero1)
        print(tablero2)

# %%
tablero1 = np.full((11,11),"___")# pruebas de disparo inteligente. Depuración del fallo
tablero2 = np.full((11,11),"___")
tablero3 = np.full((11,11),"___")
tablero4 = np.full((11,11),"___")
marco = ["_0_","_1_","_2_","_3_","_4_","_5_","_6_","_7_","_8_","_9_","_10"]
tablero1[0:,:1] = np.reshape(marco,(11,1))
tablero1[:1,:] = np.reshape(marco,(1,11))
tablero2[0:,:1] = np.reshape(marco,(11,1))
tablero2[:1,:] = np.reshape(marco,(1,11))
tablero3[0:,:1] = np.reshape(marco,(11,1))
tablero3[:1,:] = np.reshape(marco,(1,11))
tablero4[0:,:1] = np.reshape(marco,(11,1))
tablero4[:1,:] = np.reshape(marco,(1,11))
turno_j = 1 # el comienzo de los turnos también debería ser aleatorio. habría que inicilializar los valores en 0, y mediante función aleatoria, poner un 1 en el que correspoda
turno_m = 1
coord1 = 4
coord2 = 4
focus = 0
right = 0
left = 0
up = 0
down = 0

tablero1[coord1, coord2]= "_B_"
tablero1[coord1-1, coord2]= "_B_"
tablero1[coord1, coord2+2]= "___"
tablero1[coord1, coord2+3]= "_B_"
print(tablero1, end = "\r")
print(tablero2, end = "\r")

# while turno_j == 1 :#parte por definir para ligar el juego y sus pasos
acierto = 0
enter = input("Presiona enter para disparar")
if enter == "":
    if "_B_" in tablero1[coord1, coord2]:
        tablero1[coord1, coord2] = "_X_"
        tablero2[coord1, coord2] = "_X_"
        acierto+=1
        clear_output(wait=True)
        time.sleep(0.1)
        print("Has acertado!")
        print(tablero1)
        print(tablero2)
        enter1 = input("Presiona enter para volver a disparar")
        if enter1 == "":
            while acierto == 1:
                if "_B_" in tablero1[coord1-1:coord1+2, coord2-1:coord2+2]:
                    focus = 1
                    coord1_f = coord1
                    coord2_f = coord2
                    aim = np.random.randint(1,5,1)
                    if aim == 1:# esto nos complica el eliminar opciones conforme avance el disparo inteligente, en su lugar habría que plantear una estrategia constante.
                        right = 1
                    elif aim == 2:
                        left = 1
                    elif aim == 3:
                        up = 1
                    elif aim == 4:
                        down = 1
                    if focus == 1 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                        tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                        tablero2[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                        acierto+=1
                        clear_output(wait=True)
                        time.sleep(0.1)
                        print("Estas en racha!")
                        print(tablero1)
                        print(tablero2)
                    else:
                        tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                        tablero2[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                        print("Has fallado")
                        acierto = 0

                else:
                    print("Has hundido mi fragata!")
                    acierto = 0
                    focus = 0

# %%
tablero1 = np.full((11,11),"___")# pruebas de disparo inteligente. Ya hacemos búsqueda aleatoria de mas X, pero el aviso de hundimiento de barco lo hacemos mal, solo sale con el segundo disparo, y en caso de fallar, con lo que hay que ver la forma de hacerlo antes.
tablero2 = np.full((11,11),"___")
tablero3 = np.full((11,11),"___")
tablero4 = np.full((11,11),"___")
marco = ["_0_","_1_","_2_","_3_","_4_","_5_","_6_","_7_","_8_","_9_","_10"]
tablero1[0:,:1] = np.reshape(marco,(11,1))
tablero1[:1,:] = np.reshape(marco,(1,11))
tablero2[0:,:1] = np.reshape(marco,(11,1))
tablero2[:1,:] = np.reshape(marco,(1,11))
tablero3[0:,:1] = np.reshape(marco,(11,1))
tablero3[:1,:] = np.reshape(marco,(1,11))
tablero4[0:,:1] = np.reshape(marco,(11,1))
tablero4[:1,:] = np.reshape(marco,(1,11))
turno_j = 1 # el comienzo de los turnos también debería ser aleatorio. habría que inicilializar los valores en 0, y mediante función aleatoria, poner un 1 en el que correspoda
turno_m = 1
coord1 = 4
coord2 = 4
acierto = 0
focus = 0
right = 0
left = 0
up = 0
down = 0

tablero1[coord1, coord2]= "_B_"
tablero1[coord1-1, coord2]= "___"
tablero1[coord1-2, coord2]= "_B_"
tablero1[coord1, coord2+3]= "_B_"
print(tablero1, end = "\r")
print(tablero2, end = "\r")

# while turno_j == 1 :#parte por definir para ligar el juego y sus pasos

enter = input("Presiona enter para disparar")
if enter == "":
    if "_B_" in tablero1[coord1, coord2]:
        tablero1[coord1, coord2] = "_X_"
        tablero2[coord1, coord2] = "_X_"
        acierto+=1
        clear_output(wait=True)
        time.sleep(0.1)
        print("Has acertado!")
        print(tablero1)
        print(tablero2)
        if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2]:
            print("Has hundido mi fragata!")
        #else:
            enter1 = input("Presiona enter para volver a disparar")
            if enter1 == "":
                while acierto == 1:
                    if "_B_" in tablero1[coord1-1:coord1+2, coord2-1:coord2+2]:
                        focus = 1
                        coord1_f = coord1
                        coord2_f = coord2
                        aim = np.random.randint(1,5,1)
                        if aim == 1:
                            right = 1
                        elif aim == 2:
                            left = 1
                        elif aim == 3:
                            up = 1
                        elif aim == 4:
                            down = 1
                        if focus == 1 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                            tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                            tablero2[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                            acierto+=1
                            clear_output(wait=True)
                            time.sleep(0.1)
                            print("Estas en racha!")
                            print(tablero1)
                            print(tablero2)
                        else:
                            clear_output(wait=True)
                            time.sleep(0.1)
                            tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                            tablero2[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                            print("Has fallado")
                            print(tablero1)
                            print(tablero2)
                            acierto = 0

                    else:
                        print("hariamos un disparo aleatorio de nuevo")
                        acierto = 0
                        focus = 0

# %%
tablero1 = np.full((12,11),"___")# pruebas de disparo inteligente. Depuración del fallo
tablero2 = np.full((11,11),"___")
tablero3 = np.full((12,11),"___")
tablero4 = np.full((11,11),"___")
marco = ["_0_","_1_","_2_","_3_","_4_","_5_","_6_","_7_","_8_","_9_","_10"]
jugador1 = ["___","___","_J_","_U_","_G_","_A_","_D_","_O_","_R_","___","___"]
jugador2 = ["___","___","_M_","_A_","_Q_","_U_","_I_","_N_","_A_","___","___"]
tablero1[1:,:1] = np.reshape(marco,(11,1))
tablero1[1:2,:] = np.reshape(marco,(1,11))
tablero1[:1,:] = np.reshape(jugador1,(1,11))
tablero2[0:,:1] = np.reshape(marco,(11,1))
tablero2[:1,:] = np.reshape(marco,(1,11))
tablero3[1:,:1] = np.reshape(marco,(11,1))
tablero3[1:2,:] = np.reshape(marco,(1,11))
tablero3[:1,:] = np.reshape(jugador2,(1,11))
tablero4[0:,:1] = np.reshape(marco,(11,1))
tablero4[:1,:] = np.reshape(marco,(1,11))

print(tablero1)
print(tablero3)

# %%
"""Importación de librerias"""# disparo inteligente, conseguimos que funcione!!!
import numpy as np
import time
import os
from IPython.display import clear_output
"""Importación de librerias"""
tablero1 = np.full((11,11),"___")# pruebas de disparo inteligente. Ya hacemos búsqueda aleatoria de mas X, pero el aviso de hundimiento de barco lo hacemos mal, solo sale con el segundo disparo, y en caso de fallar, con lo que hay que ver la forma de hacerlo antes.
tablero2 = np.full((11,11),"___")
tablero3 = np.full((11,11),"___")
tablero4 = np.full((11,11),"___")
marco = ["_0_","_1_","_2_","_3_","_4_","_5_","_6_","_7_","_8_","_9_","_10"]
tablero1[0:,:1] = np.reshape(marco,(11,1))
tablero1[:1,:] = np.reshape(marco,(1,11))
tablero2[0:,:1] = np.reshape(marco,(11,1))
tablero2[:1,:] = np.reshape(marco,(1,11))
tablero3[0:,:1] = np.reshape(marco,(11,1))
tablero3[:1,:] = np.reshape(marco,(1,11))
tablero4[0:,:1] = np.reshape(marco,(11,1))
tablero4[:1,:] = np.reshape(marco,(1,11))
turno_j = 1 # el comienzo de los turnos también debería ser aleatorio. habría que inicilializar los valores en 0, y mediante función aleatoria, poner un 1 en el que correspoda
turno_m = 1
# coord1 = 4
# coord2 = 4
acierto = 0
focus = 0
right = 0
left = 0
up = 0
down = 0
ganador_j = 0
ganador_m = 0
n_vidas_jugador = 3
n_vidas_maquina = 3
disp_int = []
n_barcos = 10
a = 1
b = 0
aciertos = 0 # esto hay que convertirlo en una lista con [fragata,buque,acorazado,portaaviones], de forma que en función del número de aciertos acumulados, sepamos que tipo de barco hemos hundido

# tablero1[coord1, coord2]= "_B_"
# tablero1[coord1+1, coord2]= "_B_"
# tablero1[coord1-1, coord2]= "_B_"
# tablero1[coord1-2, coord2]= "_B_"
# tablero1[coord1+4, coord2]= "_B_"
# tablero1[coord1+3, coord2]= "_B_"
# tablero1[coord1-2, coord2]= "_B_"
# tablero1[coord1, coord2+3]= "_B_"

# print(tablero1, end = "\r")
# print(tablero2, end = "\r")

# while turno_j == 1 :#parte por definir para ligar el juego y sus pasos
while (ganador_m == 0) and (ganador_j == 0):
    enter = input("Presiona enter para continuar")  
    if enter == "":
        if a == 1 and focus == 0 and up == 0 and down == 0 and right == 0 and left == 0:
            coord1 = np.random.randint(1,11)
            coord2 = np.random.randint(1,11)
            if "_B_" in tablero1[coord1, coord2]:
                tablero1[coord1, coord2] = "_X_"
                tablero2[coord1-1, coord2] = "_X_"
                clear_output(wait=True)
                print("Me has dado!1")
                print(tablero1)
                print(tablero2)  
                a = 1
                b = 0
                n_vidas_maquina-=1
                focus = 1
                if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2]:
                    print("Has hundido mi fragata!")
                    a = 1
                    b = 0
                    focus = 0
                    n_barcos -=1
                else:    
                    enter = input("Presiona enter para continuar") # disparo "inteligente"
                    if enter == "" and focus == 1 and up == 0 and down == 0 and right == 0 and left == 0:# derecha
                        up = 0
                        down = 0
                        right = 1
                        left = 0
                        if focus == 1 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                            tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                            tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                            clear_output(wait=True)
                            print("Me has dado!2")
                            print(tablero1)
                            print(tablero2)  
                            a = 1
                            b = 0
                            n_vidas_maquina-=1
                            focus = 2
                            aciertos = 2
                            if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2+focus]:# ojo, si damos a mitad de un barco grande, entenderemos que hemos hundido un buque, y no es correcto
                                print("Has hundido mi buque!")
                                a = 1
                                b = 0
                                focus = 0
                                aciertos = 0
                                n_barcos -=1
                                up = 0
                                down = 0
                                right = 0
                                left = 0
                            else:    # derecha
                                enter = input("Presiona enter para continuar") 
                                if enter == "" and focus == 2 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                                    tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                    tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                    clear_output(wait=True)
                                    print("Me has dado!3")
                                    print(tablero1)
                                    print(tablero2)  
                                    a = 1
                                    b = 0
                                    n_vidas_maquina-=1
                                    focus = 3
                                    aciertos = 3
                                    if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2+focus]:
                                        print("Has hundido mi acorazado!")
                                        a = 1
                                        b = 0
                                        focus = 0
                                        aciertos = 0
                                        n_barcos -=1
                                        up = 0
                                        down = 0
                                        right = 0
                                        left = 0
                                    else:    # derecha
                                        enter = input("Presiona enter para continuar") 
                                        if enter == "" and focus == 3 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                                            tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                            tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                            clear_output(wait=True)
                                            print("Me has dado!4")
                                            print(tablero1)
                                            print(tablero2)  
                                            a = 1
                                            b = 0
                                            n_vidas_maquina-=1
                                            if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2+focus]:# ojo, si damos a mitad de un barco grande, entenderemos que hemos hundido un buque, y no es correcto
                                                print("Has hundido mi portaaviones!")
                                                a = 1
                                                b = 0
                                                focus = 0
                                                aciertos = 0
                                                n_barcos -=1
                                                up = 0
                                                down = 0
                                                right = 0
                                                left = 0                                                         
                                        elif enter == "" and focus == 3 and "_B_" not in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                                            tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                            tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                            clear_output(wait=True)
                                            a = 0
                                            b = 1
                                            acierto = 0
                                            focus = 1
                                            up = 0
                                            down = 0
                                            right = 0
                                            left = 1
                                            print("Has fallado, ahora me toca a mi4")
                                            print(tablero1)
                                            print(tablero2)  
                                            print(focus)
                                            print(right, left)
                                elif "_A_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                                    a = 1
                                    b = 0
                                    pass
                                else:
                                    tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                    tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                    acierto = 0
                                    clear_output(wait=True)
                                    a = 0
                                    b = 1
                                    acierto = 0
                                    focus = 1
                                    up = 0
                                    down = 0
                                    right = 0
                                    left = 1
                                    print("Has fallado, ahora me toca a mi3")
                                    print(tablero1)
                                    print(tablero2)  
                                    print(focus)
                                    print(right, left)
                                    print (a)
                        elif "_A_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                            a = 1
                            b = 0
                            pass
                        else:
                            tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                            tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                            acierto = 0
                            clear_output(wait=True)
                            a = 0
                            b = 1
                            acierto = 0
                            focus = 1
                            up = 0
                            down = 0
                            right = 0
                            left = 1
                            print("Has fallado, ahora me toca a mi2")
                            print(tablero1)
                            print(tablero2)  
                            print(focus)
                            print(right, left)
            elif "_A_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                a = 1
                b = 0
                pass
            else:
                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                acierto = 0
                clear_output(wait=True)
                a = 0
                b = 1
                acierto = 0
                focus = 1
                up = 0
                down = 0
                right = 0
                left = 1
                print("Has fallado, ahora me toca a mi1")
                print(tablero1)
                print(tablero2)  
                print(focus)
                print(right, left)
        elif a == 1 and focus == 1 and left == 1: # izquierdas
            if "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                #disparo1 = tablero1[coord1, coord2]
                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                clear_output(wait=True)
                print("Me has dado!12")
                print(tablero1)
                print(tablero2)  
                a = 1
                b = 0
                n_vidas_maquina-=1
                focus = 2
                aciertos = 2
                if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2, coord2-1-focus:coord2+2]:# ojo, si damos a mitad de un barco grande, entenderemos que hemos hundido un buque, y no es correcto
                    print("Has hundido mi buque!12")
                    a = 1
                    b = 0
                    focus = 0
                    aciertos = 0
                    n_barcos -=1
                    up = 0
                    down = 0
                    right = 0
                    left = 0
                else:    # izquierda
                    enter = input("Presiona enter para continuar") 
                    if enter == "" and focus == 2 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                        tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                        #disparo1 = tablero1[coord1, coord2]
                        tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                        clear_output(wait=True)
                        print("Me has dado!13")
                        print(tablero1)
                        print(tablero2)  
                        a = 1
                        b = 0
                        n_vidas_maquina-=1
                        focus = 3
                        aciertos = 3
                        if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2, coord2-1-focus:coord2+2]:
                            print("Has hundido mi acorazado!13")
                            a = 1
                            b = 0
                            focus = 0
                            aciertos = 0
                            n_barcos -=1
                            up = 0
                            down = 0
                            right = 0
                            left = 0
                        else:    #izquierda
                            enter = input("Presiona enter para continuar") 
                            if enter == "" and focus == 3 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                clear_output(wait=True)
                                print("Me has dado!14")
                                print(tablero1)
                                print(tablero2)  
                                a = 1
                                b = 0
                                n_vidas_maquina-=1
                                if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2, coord2-1-focus:coord2+2]:# ojo, si damos a mitad de un barco grande, entenderemos que hemos hundido un buque, y no es correcto
                                    print("Has hundido mi portaaviones!14")
                                    a = 1
                                    b = 0
                                    focus = 0
                                    aciertos = 0
                                    n_barcos -=1
                                    up = 0
                                    down = 0
                                    right = 0
                                    left = 0
                                    # ganador_j = 1                                                           
                            elif enter == "" and focus == 3 and "_B_" not in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                acierto = 0
                                focus = 1
                                up = 0
                                down = 0
                                right = 0
                                left = 1
                                clear_output(wait=True)
                                #time.sleep(1)
                                print("Has fallado, ahora me toca a mi14")
                                print(tablero1)
                                print(tablero2)  
                                print(focus)
                                print(right, left)
                                a = 0
                                b = 1
                    elif "_A_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                        a = 1
                        b = 0
                        pass
                    else:
                        tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                        tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                        acierto = 0
                        clear_output(wait=True)
                        #time.sleep(1)
                        a = 0
                        b = 1
                        acierto = 0
                        focus = 1
                        up = 0
                        down = 0
                        right = 0
                        left = 1
                        print("Has fallado, ahora me toca a mi13")
                        print(tablero1)
                        print(tablero2)  
            elif "_A_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                a = 1
                b = 0
                pass
            else:
                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                clear_output(wait=True)
                a = 0
                b = 1
                acierto = 1
                focus = 1
                up = 0
                down = 1
                right = 0
                left = 0
                print("Has fallado, ahora me toca a mi2")
                print(tablero1)
                print(tablero2)  
                print(focus)
                print(right, left, down, up)
                        
        elif a == 1 and focus == 1 and down == 1: # abajo
            if "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                #disparo1 = tablero1[coord1, coord2]
                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                clear_output(wait=True)
                print("Me has dado!abajo1")
                print(tablero1)
                print(tablero2)  
                a = 1
                b = 0
                n_vidas_maquina-=1
                focus = 2
                aciertos = 2
                if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2+focus, coord2-1:coord2+2]:# ojo, si damos a mitad de un barco grande, entenderemos que hemos hundido un buque, y no es correcto
                    print("Has hundido mi buque!abajo")
                    a = 1
                    b = 0
                    focus = 0
                    aciertos = 0
                    n_barcos -=1
                    up = 0
                    down = 0
                    right = 0
                    left = 0
                else:    # abajo
                    enter = input("Presiona enter para continuar") 
                    if enter == "" and focus == 2 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                        tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                        #disparo1 = tablero1[coord1, coord2]
                        tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                        clear_output(wait=True)
                        print("Me has dado!abajo2")
                        print(tablero1)
                        print(tablero2)  
                        a = 1
                        b = 0
                        n_vidas_maquina-=1
                        focus = 3
                        aciertos = 3
                        if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2+focus, coord2-1:coord2+2]:
                            print("Has hundido mi acorazado!abajo")
                            a = 1
                            b = 0
                            focus = 0
                            aciertos = 0
                            n_barcos -=1
                            up = 0
                            down = 0
                            right = 0
                            left = 0
                        else:    #abajo
                            enter = input("Presiona enter para continuar") 
                            if enter == "" and focus == 3 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                #disparo1 = tablero1[coord1, coord2]
                                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                clear_output(wait=True)
                                print("Me has dado!abajo3")
                                print(tablero1)
                                print(tablero2)  
                                a = 1
                                b = 0
                                n_vidas_maquina-=1
                                if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2+focus, coord2-1:coord2+2]:# ojo, si damos a mitad de un barco grande, entenderemos que hemos hundido un buque, y no es correcto
                                    print("Has hundido mi portaaviones!abajo")
                                    a = 1
                                    b = 0
                                    focus = 0
                                    aciertos = 0
                                    n_barcos -=1
                                    up = 0
                                    down = 0
                                    right = 0
                                    left = 0
                                    # ganador_j = 1                                                           
                            elif enter == "" and focus == 3 and "_B_" not in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                acierto = 2
                                focus = 1
                                up = 1
                                down = 0
                                right = 0
                                left = 0
                                clear_output(wait=True)
                                #time.sleep(1)
                                print("Has fallado, ahora me toca a mi!abajo3")
                                print(tablero1)
                                print(tablero2)  
                                print(focus)
                                print(right, left)
                                a = 0
                                b = 1
                    elif "_A_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                        a = 1
                        b = 0
                        pass
                    else:
                        tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                        tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                        acierto = 1
                        clear_output(wait=True)
                        #time.sleep(1)
                        a = 0
                        b = 1
                        acierto = 0
                        focus = 1
                        up = 1
                        down = 0
                        right = 0
                        left = 0
                        print("Has fallado, ahora me toca a mi!abajo2")
                        print(tablero1)
                        print(tablero2) 
                        
            elif "_A_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                a = 1
                b = 0
                pass
            else:
                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                acierto = 0
                focus = 1
                up = 1
                down = 0
                right = 0
                left = 0
                clear_output(wait=True)
                #time.sleep(1)
                print("Has fallado, ahora me toca a miabajo1")
                print(tablero1)
                print(tablero2) 
                print(coord1)
                print(coord2)
                print 
                a = 0
                b = 1
        elif a == 1 and focus == 1 and up == 1: # arriba
            if "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                #disparo1 = tablero1[coord1, coord2]
                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                clear_output(wait=True)
                print("Me has dado!arriba1")
                print(tablero1)
                print(tablero2)  
                a = 1
                b = 0
                n_vidas_maquina-=1
                focus = 2
                aciertos = 2
                if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1-focus:coord1+2, coord2-1:coord2+2]:# ojo, si damos a mitad de un barco grande, entenderemos que hemos hundido un buque, y no es correcto
                    print("Has hundido mi buque!arriba")
                    a = 1
                    b = 0
                    focus = 0
                    aciertos = 0
                    n_barcos -=1
                    up = 0
                    down = 0
                    right = 0
                    left = 0
                else:    # abajo
                    enter = input("Presiona enter para continuar") 
                    if enter == "" and focus == 2 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                        tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                        #disparo1 = tablero1[coord1, coord2]
                        tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                        clear_output(wait=True)
                        print("Me has dado!arriba2")
                        print(tablero1)
                        print(tablero2)  
                        a = 1
                        b = 0
                        n_vidas_maquina-=1
                        focus = 3
                        aciertos = 3
                        if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1-focus:coord1+2, coord2-1:coord2+2]:
                            print("Has hundido mi acorazado!arriba")
                            a = 1
                            b = 0
                            focus = 0
                            aciertos = 0
                            n_barcos -=1
                            up = 0
                            down = 0
                            right = 0
                            left = 0
                        else:    #abajo
                            enter = input("Presiona enter para continuar") 
                            if enter == "" and focus == 3 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                #disparo1 = tablero1[coord1, coord2]
                                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                clear_output(wait=True)
                                print("Me has dado!arriba3")
                                print(tablero1)
                                print(tablero2)  
                                a = 1
                                b = 0
                                n_vidas_maquina-=1
                                if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1-focus:coord1+2, coord2-1:coord2+2]:# ojo, si damos a mitad de un barco grande, entenderemos que hemos hundido un buque, y no es correcto
                                    print("Has hundido mi portaaviones!arriba")
                                    a = 1
                                    b = 0
                                    focus = 0
                                    aciertos = 0
                                    n_barcos -=1
                                    up = 0
                                    down = 0
                                    right = 0
                                    left = 0
                                    # ganador_j = 1                                                           
                            elif enter == "" and focus == 3 and "_B_" not in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                acierto = 2
                                focus = 1
                                # up = 0
                                # down = 0
                                # right = 0
                                # left = 0
                                clear_output(wait=True)
                                #time.sleep(1)
                                print("Has fallado, ahora me toca a mi!arriba3")
                                print(tablero1)
                                print(tablero2)  
                                print(focus)
                                print(right, left)
                                a = 0
                                b = 1
                    elif "_A_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                        a = 1
                        b = 0
                        pass
                    else:
                        tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                        tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                        acierto = 1
                        clear_output(wait=True)
                        #time.sleep(1)
                        a = 0
                        b = 1
                        acierto = 0
                        focus = 1
                        # up = 1
                        # down = 0
                        # right = 0
                        # left = 0
                        print("Has fallado, ahora me toca a mi!arriba2")
                        print(tablero1)
                        print(tablero2) 
                        
            elif "_A_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                a = 1
                b = 0
                pass
            else:
                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                acierto = 0
                focus = 1
                # up = 1
                # down = 0
                # right = 0
                # left = 0
                clear_output(wait=True)
                #time.sleep(1)
                print("Has fallado, ahora me toca a mi! arriba1")
                print(tablero1)
                print(tablero2) 
                print(coord1)
                print(coord2)
                print 
                a = 0
                b = 1
                
             
        elif b == 1:
            coord3 = np.random.randint(1,11)
            coord4 = np.random.randint(1,11)
            if "_B_" in tablero3[coord3, coord4]:
                tablero4[coord3, coord4] = "_X_"
                #disparo1 = tablero3[coord1, coord2]
                tablero4[coord1-1, coord2] = "_X_"
                clear_output(wait=True)
                print("Te he dado!")
                print(tablero3)
                print(tablero4)  
                b = 1
                a = 0
                n_vidas_jugador-=1
                # if turno == 0:
                #     turno = 0
            elif "_A_" in tablero1[coord1, coord2]:
                b = 1
                a = 0
                pass
                
            else:
                tablero3[coord3, coord4] = "_A_"
                tablero4[coord3-1, coord4] = "_A_"
                acierto = 0
                clear_output(wait=True)
                #time.sleep(1)
                print("He fallado, ahora te toca a ti")
                print(tablero3)
                print(tablero4)  
                print(focus)
                print(right, left)
                print(a)
                b = 0
                a = 1
        #             elif enter == "" and focus == 1 and up == 0 and down == 0 and right == 0 and left == 1:
        #             # enter = input("Presiona enter para continuar") # disparo "inteligente"
                    
        #                 if focus == 1 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
        #                         tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
        #                         #disparo1 = tablero1[coord1, coord2]
        #                         tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
        #                         clear_output(wait=True)
        #                         print("Me has dado!")
        #                         print(tablero1)
        #                         print(tablero2)  
        #                         a = 1
        #                         b = 0
        #                         n_vidas_maquina-=1
        #                         focus = 2
        #                         if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1+((down)-(up))*focus:coord1+2+((down)-(up))*focus, coord2-1+((down)-(up))*focus:coord2+2+((down)-(up))*focus]:# ojo, si damos a mitad de un barco grande, entenderemos que hemos hundido un buque, y no es correcto
        #                             print("Has hundido mi buque!")
        #                             a = 1
        #                             b = 0
        #                             focus = 0
        #                             n_barcos -=1
        #                         else:    # derecha
        #                             enter = input("Presiona enter para continuar") 
        #                             if enter == "" and focus == 2 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
        #                                 tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
        #                                 #disparo1 = tablero1[coord1, coord2]
        #                                 tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
        #                                 clear_output(wait=True)
        #                                 print("Me has dado!")
        #                                 print(tablero1)
        #                                 print(tablero2)  
        #                                 a = 1
        #                                 b = 0
        #                                 n_vidas_maquina-=1
        #                                 focus = 3
        #                                 if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2+focus]:
        #                                     print("Has hundido mi acorazado!")
        #                                     a = 1
        #                                     b = 0
        #                                     focus = 0
        #                                     n_barcos -=1
        #                                 else:    # derecha
        #                                     enter = input("Presiona enter para continuar") 
        #                                     if enter == "" and focus == 3 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
        #                                         tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
        #                                         #disparo1 = tablero1[coord1, coord2]
        #                                         tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
        #                                         clear_output(wait=True)
        #                                         print("Me has dado!")
        #                                         print(tablero1)
        #                                         print(tablero2)  
        #                                         a = 1
        #                                         b = 0
        #                                         n_vidas_maquina-=1
        #                                         # focus = 4
        #                                         if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2+focus]:# ojo, si damos a mitad de un barco grande, entenderemos que hemos hundido un buque, y no es correcto
        #                                             print("Has hundido mi portaaviones!")
        #                                             a = 1
        #                                             b = 0
        #                                             focus = 0
        #                                             n_barcos -=1
        #                                             ganador_j = 1                      
        # #                 else:
        #                     tablero1[coord1, coord2+focus] = "_A_"
        #                     #disparo1 = tablero1[coord1, coord2]
        #                     tablero2[coord1-1, coord2+focus] = "_A_"
        #                     clear_output(wait=True)
        #                     print("Has fallado!")
        #                     print(tablero1)
        #                     print(tablero2)  
        #                     a = 0
        #                     b = 1
        #                     # n_vidas_maquina-=1
        #                     focus = 1   
        #     elif "_A_" in tablero1[coord1, coord2]:
        #         a = 1
        #         b = 0
        #         pass
        #     else:
        #         tablero1[coord1, coord2] = "_A_"
        #         tablero2[coord1-1, coord2] = "_A_"
        #         acierto = 0
        #         clear_output(wait=True)
        #         #time.sleep(1)
        #         print("Has fallado, ahora me toca a mi")
        #         print(tablero1)
        #         print(tablero2)  
        #         a = 0
        #         b = 1
        # elif a == 1 and focus !=0:
                
        # elif b == 1:
        #     coord1 = np.random.randint(2,12)
        #     coord2 = np.random.randint(1,11)
        #     if "_B_" in tablero1[coord1, coord2]:
        #         tablero3[coord1, coord2] = "_X_"
        #         #disparo1 = tablero3[coord1, coord2]
        #         tablero4[coord1-1, coord2] = "_X_"
        #         clear_output(wait=True)
        #         print("Te he dado!")
        #         print(tablero3)
        #         print(tablero4)  
        #         b = 1
        #         a = 0
        #         n_vidas_jugador-=1
                
        #     elif "_A_" in tablero1[coord1, coord2]:
        #         b = 1
        #         a = 0
        #         pass
        #     else:
        #         tablero3[coord1, coord2] = "_A_"
        #         tablero4[coord1-1, coord2] = "_A_"
        #         acierto = 0
        #         clear_output(wait=True)
        #         #time.sleep(1)
        #         print("He fallado, ahora te toca a ti")
        #         print(tablero3)
        #         print(tablero4)  
        #         b = 0
        #         a = 1
                
        
        # if n_vidas_jugador <= 0:
        #     ganador_m = 1
            
        #     print("He ganado! Maquina")
        # elif n_vidas_maquina <= 0:
        #     ganador_j = 1
            
        #     print("Has ganado! Jugador")

# %%
"""Importación de librerias"""
import numpy as np
import time
import os
from IPython.display import clear_output
"""Importación de librerias"""

""" Definición de variables"""
# turno_j = 0 
# turno_m = 1
flota_j = [1,1,1,1,2,2,2,3,3,4]
flota_m = [1,1,1,1,2,2,2,3,3,4]
n_barcos_j = len(flota_j)
portaaviones_j = flota_j.count(4)
acorazado_j = flota_j.count(3)
buque_j = flota_j.count(2)
fragata_j = flota_j.count(1)
n_barcos_m = len(flota_m)
portaaviones_m = flota_m.count(4)
acorazado_m = flota_m.count(3)
buque_m = flota_m.count(2)
fragata_m = flota_m.count(1)
n_portaaviones_j = 0
n_acorazado_j = 0
n_buque_j = 0
n_fragata_j = 0
# n_barcos_j_ok = n_portaaviones_j +n_acorazado_j + n_buque_j +n_fragata_j
n_portaaviones_m = 0
n_acorazado_m = 0
n_buque_m = 0
n_fragata_m = 0
# n_barcos_m_ok = n_portaaviones_m +n_acorazado_m + n_buque_m +n_fragata_m
# n_vidas_j = sum(flota_j)
# n_vidas_m = sum(flota_m)
a = 0
b = 0
focus = 0
ganador_j = 0
ganador_m = 0
n_vidas_jugador = sum(flota_j)
n_vidas_maquina = sum(flota_m)
up = 0
down = 0
right = 0
left = 0
aciertos = 0

"""Definición de variables"""

"""Definición del tablero"""
tablero1 = np.full((12,11),"___")
tablero2 = np.full((11,11),"___")
tablero3 = np.full((12,11),"___")
tablero4 = np.full((11,11),"___")

marco = ["=V=","_1_","_2_","_3_","_4_","_5_","_6_","_7_","_8_","_9_","_10"]
jugador1 = ["___","___","_J_","_U_","_G_","_A_","_D_","_O_","_R_","___","___"]
jugador2 = ["___","___","_M_","_A_","_Q_","_U_","_I_","_N_","_A_","___","___"]# buscar la opción de indicar el nº de vidas o barcos restantes en el título de la cuadrícula

# n_vidas_jugador = sum(flota_j)
# n_vidas_maquina = sum(flota_m)

tablero1[1:,:1] = np.reshape(marco,(11,1))
tablero1[1:2,:] = np.reshape(marco,(1,11))
tablero1[:1,:] = np.reshape(jugador1,(1,11))
tablero1[0,-1] = "_" + str(n_vidas_jugador)

tablero2[0:,:1] = np.reshape(marco,(11,1))
tablero2[:1,:] = np.reshape(marco,(1,11))

tablero3[1:,:1] = np.reshape(marco,(11,1))
tablero3[1:2,:] = np.reshape(marco,(1,11))
tablero3[:1,:] = np.reshape(jugador2,(1,11))

tablero4[0:,:1] = np.reshape(marco,(11,1))
tablero4[:1,:] = np.reshape(marco,(1,11))
"""Definición del tablero"""

#alternativa de orden para jugar

jugar = 1 #input("¿Quieres Jugar (S/N)?")
if jugar == 1:
    
#if jugar.lower() == "s":
    print("Genial! Pongamos nuestros barcos")
  
    while n_portaaviones_j < portaaviones_j:
        if np.random.randint(0,2,1):
            orientacion = "horizontal"
            coord1 = np.random.randint(2,11)
            coord2 = np.random.randint(1,11-4+1)
        
            if "_B_" in tablero1[coord1-1:coord1+2, coord2-1:coord2+5]:
                #tablero1[coord1, coord2:coord2+size] = "C"
                pass
            else: 
                tablero1[coord1, coord2:coord2+4] = "_B_"
                n_portaaviones_j += 1
                #print(elemento)
        else:
            orientacion = "vertical"

            coord1 = np.random.randint(2,11-4+1)
            coord2 = np.random.randint(1,11)
        
            if "_B_" in tablero1[coord1-1:coord1+5, coord2-1:coord2+2]:
                #tablero1[coord1, coord2:coord2+size] = "C"
                pass
            else: 
                tablero1[coord1:coord1+4, coord2] = "_B_"
                n_portaaviones_j += 1
                    #print(elemento)
    while n_acorazado_j < acorazado_j:
        if np.random.randint(0,2,1):
            orientacion = "horizontal"
            coord1 = np.random.randint(2,11)
            coord2 = np.random.randint(1,11-3+1)
        
            if "_B_" in tablero1[coord1-1:coord1+2, coord2-1:coord2+4]:
                #tablero1[coord1, coord2:coord2+size] = "C"
                pass
            else: 
                tablero1[coord1, coord2:coord2+3] = "_B_"
                n_acorazado_j += 1
                #print(elemento)
        else:
            orientacion = "vertical"

            coord1 = np.random.randint(2,11-3+1)
            coord2 = np.random.randint(1,11)
        
            if "_B_" in tablero1[coord1-1:coord1+4, coord2-1:coord2+2]:
                #tablero1[coord1, coord2:coord2+size] = "C"
                pass
            else: 
                tablero1[coord1:coord1+3, coord2] = "_B_"
                n_acorazado_j += 1
                    #print(elemento)
    while n_buque_j < buque_j:
        if np.random.randint(0,2,1):
            orientacion = "horizontal"
            coord1 = np.random.randint(2,11)
            coord2 = np.random.randint(1,11-2+1)
        
            if "_B_" in tablero1[coord1-1:coord1+2, coord2-1:coord2+3]:
                #tablero1[coord1, coord2:coord2+size] = "C"
                pass
            else: 
                tablero1[coord1, coord2:coord2+2] = "_B_"
                n_buque_j += 1
                #print(elemento)
        else:
            orientacion = "vertical"

            coord1 = np.random.randint(2,11-2+1)
            coord2 = np.random.randint(1,11)
        
            if "_B_" in tablero1[coord1-1:coord1+3, coord2-1:coord2+2]:
                #tablero1[coord1, coord2:coord2+size] = "C"
                pass
            else: 
                tablero1[coord1:coord1+2, coord2] = "_B_"
                n_buque_j += 1
                    #print(elemento)
    while n_fragata_j < fragata_j:
        if np.random.randint(0,2,1):
            orientacion = "horizontal"
            coord1 = np.random.randint(2,11)
            coord2 = np.random.randint(1,11)
        
            if "_B_" in tablero1[coord1-1:coord1+2, coord2-1:coord2+2]:
                #tablero1[coord1, coord2:coord2+size] = "C"
                pass
            else: 
                tablero1[coord1, coord2:coord2+1] = "_B_"
                n_fragata_j += 1
                #print(elemento)
        else:
            orientacion = "vertical"

            coord1 = np.random.randint(2,11)
            coord2 = np.random.randint(1,11)
        
            if "_B_" in tablero1[coord1-1:coord1+2, coord2-1:coord2+2]:
                #tablero1[coord1, coord2:coord2+size] = "C"
                pass
            else: 
                tablero1[coord1:coord1+1, coord2] = "_B_"
                n_fragata_j += 1
                    #print(elemento)  

    while n_portaaviones_m < portaaviones_m:
        if np.random.randint(0,2,1):
            orientacion = "horizontal"
            coord3 = np.random.randint(2,11)
            coord4 = np.random.randint(1,11-4+1)
        
            if "_B_" in tablero3[coord3-1:coord3+2, coord4-1:coord4+5]:
                #tablero1[coord3, coord4:coord4+size] = "C"
                pass
            else: 
                tablero3[coord3, coord4:coord4+4] = "_B_"
                n_portaaviones_m += 1
                #print(elemento)
        else:
            orientacion = "vertical"

            coord3 = np.random.randint(2,11-4+1)
            coord4 = np.random.randint(1,11)
        
            if "_B_" in tablero3[coord3-1:coord3+5, coord4-1:coord4+2]:
                #tablero1[coord3, coord4:coord4+size] = "C"
                pass
            else: 
                tablero3[coord3:coord3+4, coord4] = "_B_"
                n_portaaviones_m += 1
                    #print(elemento)
    while n_acorazado_m < acorazado_m:
        if np.random.randint(0,2,1):
            orientacion = "horizontal"
            coord3 = np.random.randint(2,11)
            coord4 = np.random.randint(1,11-3+1)
        
            if "_B_" in tablero3[coord3-1:coord3+2, coord4-1:coord4+4]:
                #tablero1[coord3, coord4:coord4+size] = "C"
                pass
            else: 
                tablero3[coord3, coord4:coord4+3] = "_B_"
                n_acorazado_m += 1
                #print(elemento)
        else:
            orientacion = "vertical"

            coord3 = np.random.randint(2,11-3+1)
            coord4 = np.random.randint(1,11)
        
            if "_B_" in tablero3[coord3-1:coord3+4, coord4-1:coord4+2]:
                #tablero1[coord3, coord4:coord4+size] = "C"
                pass
            else: 
                tablero3[coord3:coord3+3, coord4] = "_B_"
                n_acorazado_m += 1
                    #print(elemento)
    while n_buque_m < buque_m:
        if np.random.randint(0,2,1):
            orientacion = "horizontal"
            coord3 = np.random.randint(2,11)
            coord4 = np.random.randint(1,11-2+1)
        
            if "_B_" in tablero3[coord3-1:coord3+2, coord4-1:coord4+3]:
                #tablero1[coord3, coord4:coord4+size] = "C"
                pass
            else: 
                tablero3[coord3, coord4:coord4+2] = "_B_"
                n_buque_m += 1
                #print(elemento)
        else:
            orientacion = "vertical"

            coord3 = np.random.randint(2,11-2+1)
            coord4 = np.random.randint(1,11)
        
            if "_B_" in tablero3[coord3-1:coord3+3, coord4-1:coord4+2]:
                #tablero1[coord3, coord4:coord4+size] = "C"
                pass
            else: 
                tablero3[coord3:coord3+2, coord4] = "_B_"
                n_buque_m += 1
                    #print(elemento)
    while n_fragata_m < fragata_m:
        if np.random.randint(0,2,1):
            orientacion = "horizontal"
            coord3 = np.random.randint(2,11)
            coord4 = np.random.randint(1,11)
        
            if "_B_" in tablero3[coord3-1:coord3+2, coord4-1:coord4+2]:
                #tablero1[coord3, coord4:coord4+size] = "C"
                pass
            else: 
                tablero3[coord3, coord4:coord4+1] = "_B_"
                n_fragata_m += 1
                #print(elemento)
        else:
            orientacion = "vertical"

            coord3 = np.random.randint(2,11)
            coord4 = np.random.randint(1,11)
        
            if "_B_" in tablero3[coord3-1:coord3+2, coord4-1:coord4+2]:
                #tablero1[coord3, coord4:coord4+size] = "C"
                pass
            else: 
                tablero3[coord3:coord3+1, coord4] = "_B_"
                n_fragata_m += 1
                    #print(elemento)  

    clear_output(wait=True)
    time.sleep(3)# nos da 3 segundos de Genial! Pongamos nuestros barcos
    print(tablero1)
    print(tablero3)

    clear_output(wait=True)
    time.sleep(3)
    print("Veamos quien empieza")

#decisión de turno aleatoria

    if np.random.randint(0,2,1):
        clear_output(wait=True)
        time.sleep(2)
        print("Que suerte, eres el primero en empezar, empieza disparando!")
        a = 1
        
    else:
        clear_output(wait=True)
        time.sleep(2)
        print("Te toca esperar, empiezo disparando!")
        b = 1
        


while (ganador_m == 0) and (ganador_j == 0):
    enter = input("Presiona enter para continuar")  
    if enter == "":
        if a == 1 and focus == 0 and up == 0 and down == 0 and right == 0 and left == 0:
            coord1 = np.random.randint(2,12)
            coord2 = np.random.randint(1,11)
            if "_B_" in tablero1[coord1, coord2]:
                tablero1[coord1, coord2] = "_X_"
                tablero2[coord1-1, coord2] = "_X_"
                clear_output(wait=True)
                print(f"Me has dado en la fila {coord1}, columna {coord2}1")
                print(tablero1)
                print(tablero2)  
                a = 1
                b = 0
                n_vidas_maquina-=1
                focus = 1
                if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2]:
                    print("Has hundido mi fragata!")
                    a = 1
                    b = 0
                    focus = 0
                    # n_barcos -=1
                    aciertos = 1
                else:    
                    enter = input("Presiona enter para continuar") # disparo "inteligente"
                    if enter == "" and focus == 1 and up == 0 and down == 0 and right == 0 and left == 0:# derecha
                        up = 0
                        down = 0
                        right = 1
                        left = 0
                        if focus == 1 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: 
                            #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                            tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                            tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                            clear_output(wait=True)
                            print(f"Me has dado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus}!2")
                            print(tablero1)
                            print(tablero2)  
                            a = 1
                            b = 0
                            n_vidas_maquina-=1
                            focus = 2
                            aciertos = 2
                            if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2+focus]:
                                print("Has hundido mi buque!")
                                a = 1
                                b = 0
                                focus = 0
                                aciertos = 0
                                # n_barcos -=1
                                up = 0
                                down = 0
                                right = 0
                                left = 0
                            else:    # derecha
                                enter = input("Presiona enter para continuar") 
                                if enter == "" and focus == 2 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: 
                                    #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                                    tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                    tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                    clear_output(wait=True)
                                    print(f"Me has dado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus}!3")
                                    print(tablero1)
                                    print(tablero2)  
                                    a = 1
                                    b = 0
                                    n_vidas_maquina-=1
                                    focus = 3
                                    aciertos = 3
                                    if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2+focus]:
                                        print("Has hundido mi acorazado!")
                                        a = 1
                                        b = 0
                                        focus = 0
                                        aciertos = 0
                                        # n_barcos -=1
                                        up = 0
                                        down = 0
                                        right = 0
                                        left = 0
                                    else:    # derecha
                                        enter = input("Presiona enter para continuar") 
                                        if enter == "" and focus == 3 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: 
                                            #hacemos disparo en coordenada mas focus hacia la derecha, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                                            tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                            tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                            clear_output(wait=True)
                                            print(f"Me has dado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus}!4")
                                            print(tablero1)
                                            print(tablero2)  
                                            a = 1
                                            b = 0
                                            n_vidas_maquina-=1
                                            if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2+focus]:
                                                print("Has hundido mi portaaviones!")
                                                a = 1
                                                b = 0
                                                focus = 0
                                                aciertos = 0
                                                # n_barcos -=1
                                                up = 0
                                                down = 0
                                                right = 0
                                                left = 0                                                         
                                        elif enter == "" and focus == 3 and "_B_" not in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                                            tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                            tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                            clear_output(wait=True)
                                            a = 0
                                            b = 1
                                            acierto = 0
                                            focus = 1
                                            up = 0
                                            down = 0
                                            right = 0
                                            left = 1
                                            print(f"Has fallado en la fila {coord1-1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus}!, ahora me toca a mi4")
                                            print(tablero1)
                                            print(tablero2)  
                                            print(focus)
                                            print(right, left)
                                elif "_A_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                                    a = 1
                                    b = 0
                                    pass
                                else:
                                    tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                    tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                    acierto = 0
                                    clear_output(wait=True)
                                    a = 0
                                    b = 1
                                    acierto = 0
                                    focus = 1
                                    up = 0
                                    down = 0
                                    right = 0
                                    left = 1
                                    print(f"Has fallado en la fila {coord1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus}!, ahora me toca a mi3")
                                    print(tablero1)
                                    print(tablero2)  
                                    print(focus)
                                    print(right, left)
                                    print (a)
                        elif "_A_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                            a = 1
                            b = 0
                            pass
                        else:
                            tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                            tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                            acierto = 0
                            clear_output(wait=True)
                            a = 0
                            b = 1
                            acierto = 0
                            focus = 1
                            up = 0
                            down = 0
                            right = 0
                            left = 1
                            print(f"Has fallado en la fila {coord1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus}!, ahora me toca a mi2")
                            print(tablero1)
                            print(tablero2)  
                            print(focus)
                            print(right, left)
            elif "_A_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                a = 1
                b = 0
                pass
            else:
                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                # acierto = 0
                clear_output(wait=True)
                a = 0
                b = 1
                acierto = 0
                # focus = 1
                # up = 0
                # down = 0
                # right = 0
                # left = 1
                print(f"Has fallado en la fila {coord1+((down)-(up))*focus}, columna {coord2+((right)-(left))*focus}!, ahora me toca a mi1")
                print(tablero1)
                print(tablero2)  
                # print(focus)
                # print(right, left)
        elif a == 1 and focus == 1 and left == 1: # izquierda
            if "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: 
                #hacemos disparo en coordenada mas focus hacia la izquierda, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                clear_output(wait=True)
                print("Me has dado!izquierda2")
                print(tablero1)
                print(tablero2)  
                a = 1
                b = 0
                n_vidas_maquina-=1
                focus = 2
                aciertos = 2
                if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2, coord2-1-focus:coord2+2]:
                    print("Has hundido mi buque!12")
                    a = 1
                    b = 0
                    focus = 0
                    aciertos = 0
                    # n_barcos -=1
                    up = 0
                    down = 0
                    right = 0
                    left = 0
                else:    # izquierda
                    enter = input("Presiona enter para continuar") 
                    if enter == "" and focus == 2 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: 
                        #hacemos disparo en coordenada mas focus hacia la izquierda, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                        tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                        tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                        clear_output(wait=True)
                        print("Me has dado!13")
                        print(tablero1)
                        print(tablero2)  
                        a = 1
                        b = 0
                        n_vidas_maquina-=1
                        focus = 3
                        aciertos = 3
                        if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2, coord2-1-focus:coord2+2]:
                            print("Has hundido mi acorazado!izquierda3")
                            a = 1
                            b = 0
                            focus = 0
                            aciertos = 0
                            # n_barcos -=1
                            up = 0
                            down = 0
                            right = 0
                            left = 0
                        else:    #izquierda
                            enter = input("Presiona enter para continuar") 
                            if enter == "" and focus == 3 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: 
                                #hacemos disparo en coordenada mas focus hacia la izquierda, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                clear_output(wait=True)
                                print("Me has dado!izquierda4")
                                print(tablero1)
                                print(tablero2)  
                                a = 1
                                b = 0
                                n_vidas_maquina-=1
                                if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2, coord2-1-focus:coord2+2]:
                                    print("Has hundido mi portaaviones!14")
                                    a = 1
                                    b = 0
                                    focus = 0
                                    aciertos = 0
                                    # n_barcos -=1
                                    up = 0
                                    down = 0
                                    right = 0
                                    left = 0
                            elif enter == "" and focus == 3 and "_B_" not in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                acierto = 0
                                focus = 1
                                up = 0
                                down = 0
                                right = 0
                                left = 1
                                clear_output(wait=True)
                                #time.sleep(1)
                                print("Has fallado, ahora me toca a mi!izquierda4")
                                print(tablero1)
                                print(tablero2)  
                                # print(focus)
                                # print(right, left)
                                a = 0
                                b = 1
                    elif "_A_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                        a = 1
                        b = 0
                        pass
                    else:
                        tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                        tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                        acierto = 0
                        clear_output(wait=True)
                        #time.sleep(1)
                        a = 0
                        b = 1
                        acierto = 0
                        focus = 1
                        up = 0
                        down = 0
                        right = 0
                        left = 1
                        print("Has fallado, ahora me toca a mi!izquierda3")
                        print(tablero1)
                        print(tablero2)  
            elif "_A_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                a = 1
                b = 0
                pass
            else:
                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                clear_output(wait=True)
                a = 0
                b = 1
                acierto = 1
                focus = 1
                up = 0
                down = 1
                right = 0
                left = 0
                print("Has fallado, ahora me toca a mi!izquierda2")
                print(tablero1)
                print(tablero2)  
                print(focus)
                print(right, left, down, up)              
        elif a == 1 and focus == 1 and down == 1: # abajo
            if "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: 
                #hacemos disparo en coordenada mas focus hacia abajo, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                clear_output(wait=True)
                print("Me has dado!abajo1")
                print(tablero1)
                print(tablero2)  
                a = 1
                b = 0
                n_vidas_maquina-=1
                focus = 2
                aciertos = 2
                if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2+focus, coord2-1:coord2+2]:
                    print("Has hundido mi buque!abajo")
                    a = 1
                    b = 0
                    focus = 0
                    aciertos = 0
                    n_barcos -=1
                    up = 0
                    down = 0
                    right = 0
                    left = 0
                else:    # abajo
                    enter = input("Presiona enter para continuar") 
                    if enter == "" and focus == 2 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: 
                        #hacemos disparo en coordenada mas focus hacia abajo, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                        tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                        #disparo1 = tablero1[coord1, coord2]
                        tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                        clear_output(wait=True)
                        print("Me has dado!abajo2")
                        print(tablero1)
                        print(tablero2)  
                        a = 1
                        b = 0
                        n_vidas_maquina-=1
                        focus = 3
                        aciertos = 3
                        if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2+focus, coord2-1:coord2+2]:
                            print("Has hundido mi acorazado!abajo")
                            a = 1
                            b = 0
                            focus = 0
                            aciertos = 0
                            # n_barcos -=1
                            up = 0
                            down = 0
                            right = 0
                            left = 0
                        else:    #abajo
                            enter = input("Presiona enter para continuar") 
                            if enter == "" and focus == 3 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: 
                                #hacemos disparo en coordenada mas focus hacia abajo, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                #disparo1 = tablero1[coord1, coord2]
                                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                clear_output(wait=True)
                                print("Me has dado!abajo3")
                                print(tablero1)
                                print(tablero2)  
                                a = 1
                                b = 0
                                n_vidas_maquina-=1
                                if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1:coord1+2+focus, coord2-1:coord2+2]:
                                    print("Has hundido mi portaaviones!abajo")
                                    a = 1
                                    b = 0
                                    focus = 0
                                    aciertos = 0
                                    # n_barcos -=1
                                    up = 0
                                    down = 0
                                    right = 0
                                    left = 0
                                    # ganador_j = 1                                                           
                            elif enter == "" and focus == 3 and "_B_" not in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                acierto = 2
                                focus = 1
                                up = 1
                                down = 0
                                right = 0
                                left = 0
                                clear_output(wait=True)
                                #time.sleep(1)
                                print("Has fallado, ahora me toca a mi!abajo3")
                                print(tablero1)
                                print(tablero2)  
                                print(focus)
                                print(right, left)
                                a = 0
                                b = 1
                    elif "_A_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                        a = 1
                        b = 0
                        pass
                    else:
                        tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                        tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                        acierto = 1
                        clear_output(wait=True)
                        #time.sleep(1)
                        a = 0
                        b = 1
                        acierto = 0
                        focus = 1
                        up = 1
                        down = 0
                        right = 0
                        left = 0
                        print("Has fallado, ahora me toca a mi!abajo2")
                        print(tablero1)
                        print(tablero2)         
            elif "_A_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                a = 1
                b = 0
                pass
            else:
                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                acierto = 0
                focus = 1
                up = 1
                down = 0
                right = 0
                left = 0
                clear_output(wait=True)
                #time.sleep(1)
                print("Has fallado, ahora me toca a miabajo1")
                print(tablero1)
                print(tablero2) 
                # print(coord1)
                # print(coord2)
                # print 
                a = 0
                b = 1
        elif a == 1 and focus == 1 and up == 1: # arriba
            if "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: 
                #hacemos disparo en coordenada mas focus hacia arriba, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                clear_output(wait=True)
                print("Me has dado!arriba1")
                print(tablero1)
                print(tablero2)  
                a = 1
                b = 0
                n_vidas_maquina-=1
                focus = 2
                aciertos = 2
                if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1-focus:coord1+2, coord2-1:coord2+2]:
                    print("Has hundido mi buque!arriba")
                    a = 1
                    b = 0
                    focus = 0
                    aciertos = 0
                    # n_barcos -=1
                    up = 0
                    down = 0
                    right = 0
                    left = 0
                else:    # arriba
                    enter = input("Presiona enter para continuar") 
                    if enter == "" and focus == 2 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: 
                        #hacemos disparo en coordenada mas focus hacia arriba, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                        tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                        tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                        clear_output(wait=True)
                        print("Me has dado!arriba2")
                        print(tablero1)
                        print(tablero2)  
                        a = 1
                        b = 0
                        n_vidas_maquina-=1
                        focus = 3
                        aciertos = 3
                        if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1-focus:coord1+2, coord2-1:coord2+2]:
                            print("Has hundido mi acorazado!arriba")
                            a = 1
                            b = 0
                            focus = 0
                            aciertos = 0
                            # n_barcos -=1
                            up = 0
                            down = 0
                            right = 0
                            left = 0
                        else:    #arriba
                            enter = input("Presiona enter para continuar") 
                            if enter == "" and focus == 3 and "_B_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]: 
                                #hacemos disparo en coordenada mas focus hacia arriba, si funciona, subimos el focus en 1, revisamos si en la coord inicial se ven mas b, y si en la coord nueva se ven mas b, si no, hemos hundido barco, si si, seguimos buscando. 
                                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_X_"
                                clear_output(wait=True)
                                print("Me has dado!arriba3")
                                print(tablero1)
                                print(tablero2)  
                                a = 1
                                b = 0
                                n_vidas_maquina-=1
                                if "_B_" not in tablero1[coord1-1:coord1+2, coord2-1:coord2+2] and "_B_" not in tablero1[coord1-1-focus:coord1+2, coord2-1:coord2+2]:
                                    print("Has hundido mi portaaviones!arriba")
                                    a = 1
                                    b = 0
                                    focus = 0
                                    aciertos = 0
                                    # n_barcos -=1
                                    up = 0
                                    down = 0
                                    right = 0
                                    left = 0
                                    # ganador_j = 1                                                           
                            elif enter == "" and focus == 3 and "_B_" not in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                                acierto = 2
                                focus = 1
                                # up = 0
                                # down = 0
                                # right = 0
                                # left = 0
                                clear_output(wait=True)
                                #time.sleep(1)
                                print("Has fallado, ahora me toca a mi!arriba3")
                                print(tablero1)
                                print(tablero2)  
                                # print(focus)
                                # print(right, left)
                                a = 0
                                b = 1
                    elif "_A_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                        a = 1
                        b = 0
                        pass
                    else:
                        tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                        tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                        acierto = 1
                        clear_output(wait=True)
                        #time.sleep(1)
                        a = 0
                        b = 1
                        acierto = 0
                        focus = 1
                        # up = 1
                        # down = 0
                        # right = 0
                        # left = 0
                        print("Has fallado, ahora me toca a mi!arriba2")
                        print(tablero1)
                        print(tablero2)             
            elif "_A_" in tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus]:
                a = 1
                b = 0
                pass
            else:
                tablero1[coord1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                tablero2[coord1-1+((down)-(up))*focus,coord2+((right)-(left))*focus] = "_A_"
                acierto = 0
                focus = 1
                # up = 1
                # down = 0
                # right = 0
                # left = 0
                clear_output(wait=True)
                #time.sleep(1)
                print("Has fallado, ahora me toca a mi! arriba1")
                print(tablero1)
                print(tablero2) 
                print(coord1)
                print(coord2)
                print 
                a = 0
                b = 1     
        elif b == 1:
            coord3 = np.random.randint(1,11)
            coord4 = np.random.randint(1,11)
            if "_B_" in tablero3[coord3, coord4]:
                tablero3[coord3, coord4] = "_X_"
                #disparo1 = tablero3[coord1, coord2]
                tablero4[coord3-1, coord4] = "_X_"
                clear_output(wait=True)
                print("Te he dado!{coord3},{coord4}")
                print(tablero3)
                print(tablero4)  
                b = 1
                a = 0
                n_vidas_jugador-=1
                # if turno == 0:
                #     turno = 0
            elif "_A_" in tablero3[coord3, coord4]:
                b = 1
                a = 0
                pass
                
            else:
                tablero3[coord3, coord4] = "_A_"
                tablero4[coord3-1, coord4] = "_A_"
                acierto = 0
                clear_output(wait=True)
                #time.sleep(1)
                print("He fallado, ahora te toca a ti")
                print(tablero3)
                print(tablero4)  
                # print(focus)
                # print(right, left)
                # print(a)
                b = 0
                a = 1
        if n_vidas_jugador <= 0:
            ganador_m = 1
            #clear_output(wait=True)
            print("He ganado! Maquina")
            # print(tablero1)
        elif n_vidas_maquina <= 0:
            ganador_j = 1
            #clear_output(wait=True)
            print("Has ganado! Jugador")
            # print(tablero3)
# Out:
# Has fallado en la fila 4, columna 3!, ahora me toca a mi1
# [['___' '___' '_J_' '_U_' '_G_' '_A_' '_D_' '_O_' '_R_' '___' '_20']
#  ['=V=' '_1_' '_2_' '_3_' '_4_' '_5_' '_6_' '_7_' '_8_' '_9_' '_10']
#  ['_1_' '___' '___' '___' '_B_' '___' '___' '___' '___' '___' '_B_']
#  ['_2_' '___' '_B_' '___' '_B_' '___' '_B_' '___' '___' '___' '_B_']
#  ['_3_' '___' '_B_' '_A_' '___' '___' '___' '___' '_B_' '___' '_B_']
#  ['_4_' '___' '_B_' '___' '___' '___' '___' '___' '___' '___' '_B_']
#  ['_5_' '___' '___' '___' '___' '_B_' '___' '_B_' '___' '___' '___']
#  ['_6_' '___' '___' '___' '___' '___' '___' '_B_' '___' '___' '___']
#  ['_7_' '___' '___' '___' '___' '___' '___' '_B_' '___' '_B_' '___']
#  ['_8_' '___' '___' '___' '_B_' '___' '___' '___' '___' '_B_' '___']
#  ['_9_' '_B_' '___' '___' '_B_' '___' '___' '___' '___' '___' '___']
#  ['_10' '___' '___' '___' '___' '___' '___' '___' '___' '___' '___']]
# [['=V=' '_1_' '_2_' '_3_' '_4_' '_5_' '_6_' '_7_' '_8_' '_9_' '_10']
# ...
